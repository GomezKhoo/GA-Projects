# %% [markdown]
# # **Project 2**
#
# # Introduction:
#
# Any homeowner or homerbuyers can use this machine learning algorithm to determine the market worth of properties.
# Clients frequently expect realtors to provide quick back-of-the-envelope estimates of market value based on experience and market transactions in this age of digitization when efficiency comes at a cost.
# A thorough evaluation by a valuer requires some time and is frequently completed only when the buyer is prepared to commit.
# The estimation then forms the foundation of the negotiation with the seller. Expectations are not met and loan approval may be impacted when the actual valuation differs from the initial estimate, potentially resulting in deal loss.
#
# Source: https://www.globalpropertyguide.com/North-America/United-States/Price-History
#         https://www.bbc.com/news/business-57090421
#
#
# # Problem Statement:
#
# In this project, we would be making three supervised machine learning models; Linear Regression model, Ridge Regression model and Lasso regression model, using train data to test the model against the test data to predict the property sale price.
# Success of the model is determined by the Root Mean squared error (RMSE), which is the standard deviation of the residuals (prediction errors). Lower RMSE would determine a better model. The main objective of this model is to set a predicted valuation/price of a property in line with the market perceived value of the property, allowing valuators to set a fair price for the property and hence fair property taxes for everyone who would be paying property tax.
#
#
# # Data:
#
# - train.csv -- this data contains all of the training data for your model.
#   The target variable (SalePrice) is removed from the test set!
# - test.csv -- this data contains the test data for your model. You will feed this data into your regression model to make predictions.

# %% [markdown]
# # Importing Data and Packages

# %%
# Standard Imports
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import seaborn as sb
import matplotlib.pyplot as mp

# Libraries to use for Linear Regression Modeling
from sklearn.model_selection import train_test_split, cross_val_score
from sklearn.linear_model import LinearRegression, LassoCV, RidgeCV
from sklearn.preprocessing import StandardScaler, PolynomialFeatures, PowerTransformer
from sklearn.metrics import r2_score, mean_squared_error

# %matplotlib inline

# %%
ames_train = pd.read_csv('../datasets/train.csv')
ames_test = pd.read_csv('../datasets/test.csv')

# %%
ames_train.head()
# Out:
#     Id        PID  MS SubClass MS Zoning  Lot Frontage  Lot Area Street Alley  \
# 0  109  533352170           60        RL           NaN     13517   Pave   NaN
# 1  544  531379050           60        RL          43.0     11492   Pave   NaN
# 2  153  535304180           20        RL          68.0      7922   Pave   NaN
# 3  318  916386060           60        RL          73.0      9802   Pave   NaN
# 4  255  906425045           50        RL          82.0     14235   Pave   NaN
#
#   Lot Shape Land Contour Utilities Lot Config Land Slope Neighborhood  \
# 0       IR1          Lvl    AllPub    CulDSac        Gtl       Sawyer
# 1       IR1          Lvl    AllPub    CulDSac        Gtl      SawyerW
# 2       Reg          Lvl    AllPub     Inside        Gtl        NAmes
# 3       Reg          Lvl    AllPub     Inside        Gtl       Timber
# 4       IR1          Lvl    AllPub     Inside        Gtl      SawyerW
#
#   Condition 1 Condition 2 Bldg Type House Style  Overall Qual  Overall Cond  \
# 0        RRAe        Norm      1Fam      2Story             6             8
# 1        Norm        Norm      1Fam      2Story             7             5
# 2        Norm        Norm      1Fam      1Story             5             7
# 3        Norm        Norm      1Fam      2Story             5             5
# 4        Norm        Norm      1Fam      1.5Fin             6             8
#
#    Year Built  Year Remod/Add Roof Style Roof Matl Exterior 1st Exterior 2nd  \
# 0        1976            2005      Gable   CompShg      HdBoard      Plywood
# 1        1996            1997      Gable   CompShg      VinylSd      VinylSd
# 2        1953            2007      Gable   CompShg      VinylSd      VinylSd
# 3        2006            2007      Gable   CompShg      VinylSd      VinylSd
# 4        1900            1993      Gable   CompShg      Wd Sdng      Plywood
#
#   Mas Vnr Type  Mas Vnr Area Exter Qual Exter Cond Foundation Bsmt Qual  \
# 0      BrkFace         289.0         Gd         TA     CBlock        TA
# 1      BrkFace         132.0         Gd         TA      PConc        Gd
# 2         None           0.0         TA         Gd     CBlock        TA
# 3         None           0.0         TA         TA      PConc        Gd
# 4         None           0.0         TA         TA      PConc        Fa
#
#   Bsmt Cond Bsmt Exposure BsmtFin Type 1  BsmtFin SF 1 BsmtFin Type 2  \
# 0        TA            No            GLQ         533.0            Unf
# 1        TA            No            GLQ         637.0            Unf
# 2        TA            No            GLQ         731.0            Unf
# 3        TA            No            Unf           0.0            Unf
# 4        Gd            No            Unf           0.0            Unf
#
#    BsmtFin SF 2  Bsmt Unf SF  Total Bsmt SF Heating Heating QC Central Air  \
# 0           0.0        192.0          725.0    GasA         Ex           Y
# 1           0.0        276.0          913.0    GasA         Ex           Y
# 2           0.0        326.0         1057.0    GasA         TA           Y
# 3           0.0        384.0          384.0    GasA         Gd           Y
# 4           0.0        676.0          676.0    GasA         TA           Y
#
#   Electrical  1st Flr SF  2nd Flr SF  Low Qual Fin SF  Gr Liv Area  \
# 0      SBrkr         725         754                0         1479
# 1      SBrkr         913        1209                0         2122
# 2      SBrkr        1057           0                0         1057
# 3      SBrkr         744         700                0         1444
# 4      SBrkr         831         614                0         1445
#
#    Bsmt Full Bath  Bsmt Half Bath  Full Bath  Half Bath  Bedroom AbvGr  \
# 0             0.0             0.0          2          1              3
# 1             1.0             0.0          2          1              4
# 2             1.0             0.0          1          0              3
# 3             0.0             0.0          2          1              3
# 4             0.0             0.0          2          0              3
#
#    Kitchen AbvGr Kitchen Qual  TotRms AbvGrd Functional  Fireplaces  \
# 0              1           Gd              6        Typ           0
# 1              1           Gd              8        Typ           1
# 2              1           Gd              5        Typ           0
# 3              1           TA              7        Typ           0
# 4              1           TA              6        Typ           0
#
#   Fireplace Qu Garage Type  Garage Yr Blt Garage Finish  Garage Cars  \
# 0          NaN      Attchd         1976.0           RFn          2.0
# 1           TA      Attchd         1997.0           RFn          2.0
# 2          NaN      Detchd         1953.0           Unf          1.0
# 3          NaN     BuiltIn         2007.0           Fin          2.0
# 4          NaN      Detchd         1957.0           Unf          2.0
#
#    Garage Area Garage Qual Garage Cond Paved Drive  Wood Deck SF  \
# 0        475.0          TA          TA           Y             0
# 1        559.0          TA          TA           Y             0
# 2        246.0          TA          TA           Y             0
# 3        400.0          TA          TA           Y           100
# 4        484.0          TA          TA           N             0
#
#    Open Porch SF  Enclosed Porch  3Ssn Porch  Screen Porch  Pool Area Pool QC  \
# 0             44               0           0             0          0     NaN
# 1             74               0           0             0          0     NaN
# 2             52               0           0             0          0     NaN
# 3              0               0           0             0          0     NaN
# 4             59               0           0             0          0     NaN
#
#   Fence Misc Feature  Misc Val  Mo Sold  Yr Sold Sale Type  SalePrice
# 0   NaN          NaN         0        3     2010       WD      130500
# 1   NaN          NaN         0        4     2009       WD      220000
# 2   NaN          NaN         0        1     2010       WD      109000
# 3   NaN          NaN         0        4     2010       WD      174000
# 4   NaN          NaN         0        3     2010       WD      138500

# %%
# Increase display range for easier viewing - https://songhuiming.github.io/pages/2017/04/02/jupyter-and-pandas-display/
pd.options.display.max_columns = 400
pd.options.display.max_rows = 300

# %% [markdown]
# Taking a look at the basic information of the train dataset

# %%
ames_train.head(5)
# Out:
#     Id        PID  MS SubClass MS Zoning  Lot Frontage  Lot Area Street Alley  \
# 0  109  533352170           60        RL           NaN     13517   Pave   NaN
# 1  544  531379050           60        RL          43.0     11492   Pave   NaN
# 2  153  535304180           20        RL          68.0      7922   Pave   NaN
# 3  318  916386060           60        RL          73.0      9802   Pave   NaN
# 4  255  906425045           50        RL          82.0     14235   Pave   NaN
#
#   Lot Shape Land Contour Utilities Lot Config Land Slope Neighborhood  \
# 0       IR1          Lvl    AllPub    CulDSac        Gtl       Sawyer
# 1       IR1          Lvl    AllPub    CulDSac        Gtl      SawyerW
# 2       Reg          Lvl    AllPub     Inside        Gtl        NAmes
# 3       Reg          Lvl    AllPub     Inside        Gtl       Timber
# 4       IR1          Lvl    AllPub     Inside        Gtl      SawyerW
#
#   Condition 1 Condition 2 Bldg Type House Style  Overall Qual  Overall Cond  \
# 0        RRAe        Norm      1Fam      2Story             6             8
# 1        Norm        Norm      1Fam      2Story             7             5
# 2        Norm        Norm      1Fam      1Story             5             7
# 3        Norm        Norm      1Fam      2Story             5             5
# 4        Norm        Norm      1Fam      1.5Fin             6             8
#
#    Year Built  Year Remod/Add Roof Style Roof Matl Exterior 1st Exterior 2nd  \
# 0        1976            2005      Gable   CompShg      HdBoard      Plywood
# 1        1996            1997      Gable   CompShg      VinylSd      VinylSd
# 2        1953            2007      Gable   CompShg      VinylSd      VinylSd
# 3        2006            2007      Gable   CompShg      VinylSd      VinylSd
# 4        1900            1993      Gable   CompShg      Wd Sdng      Plywood
#
#   Mas Vnr Type  Mas Vnr Area Exter Qual Exter Cond Foundation Bsmt Qual  \
# 0      BrkFace         289.0         Gd         TA     CBlock        TA
# 1      BrkFace         132.0         Gd         TA      PConc        Gd
# 2         None           0.0         TA         Gd     CBlock        TA
# 3         None           0.0         TA         TA      PConc        Gd
# 4         None           0.0         TA         TA      PConc        Fa
#
#   Bsmt Cond Bsmt Exposure BsmtFin Type 1  BsmtFin SF 1 BsmtFin Type 2  \
# 0        TA            No            GLQ         533.0            Unf
# 1        TA            No            GLQ         637.0            Unf
# 2        TA            No            GLQ         731.0            Unf
# 3        TA            No            Unf           0.0            Unf
# 4        Gd            No            Unf           0.0            Unf
#
#    BsmtFin SF 2  Bsmt Unf SF  Total Bsmt SF Heating Heating QC Central Air  \
# 0           0.0        192.0          725.0    GasA         Ex           Y
# 1           0.0        276.0          913.0    GasA         Ex           Y
# 2           0.0        326.0         1057.0    GasA         TA           Y
# 3           0.0        384.0          384.0    GasA         Gd           Y
# 4           0.0        676.0          676.0    GasA         TA           Y
#
#   Electrical  1st Flr SF  2nd Flr SF  Low Qual Fin SF  Gr Liv Area  \
# 0      SBrkr         725         754                0         1479
# 1      SBrkr         913        1209                0         2122
# 2      SBrkr        1057           0                0         1057
# 3      SBrkr         744         700                0         1444
# 4      SBrkr         831         614                0         1445
#
#    Bsmt Full Bath  Bsmt Half Bath  Full Bath  Half Bath  Bedroom AbvGr  \
# 0             0.0             0.0          2          1              3
# 1             1.0             0.0          2          1              4
# 2             1.0             0.0          1          0              3
# 3             0.0             0.0          2          1              3
# 4             0.0             0.0          2          0              3
#
#    Kitchen AbvGr Kitchen Qual  TotRms AbvGrd Functional  Fireplaces  \
# 0              1           Gd              6        Typ           0
# 1              1           Gd              8        Typ           1
# 2              1           Gd              5        Typ           0
# 3              1           TA              7        Typ           0
# 4              1           TA              6        Typ           0
#
#   Fireplace Qu Garage Type  Garage Yr Blt Garage Finish  Garage Cars  \
# 0          NaN      Attchd         1976.0           RFn          2.0
# 1           TA      Attchd         1997.0           RFn          2.0
# 2          NaN      Detchd         1953.0           Unf          1.0
# 3          NaN     BuiltIn         2007.0           Fin          2.0
# 4          NaN      Detchd         1957.0           Unf          2.0
#
#    Garage Area Garage Qual Garage Cond Paved Drive  Wood Deck SF  \
# 0        475.0          TA          TA           Y             0
# 1        559.0          TA          TA           Y             0
# 2        246.0          TA          TA           Y             0
# 3        400.0          TA          TA           Y           100
# 4        484.0          TA          TA           N             0
#
#    Open Porch SF  Enclosed Porch  3Ssn Porch  Screen Porch  Pool Area Pool QC  \
# 0             44               0           0             0          0     NaN
# 1             74               0           0             0          0     NaN
# 2             52               0           0             0          0     NaN
# 3              0               0           0             0          0     NaN
# 4             59               0           0             0          0     NaN
#
#   Fence Misc Feature  Misc Val  Mo Sold  Yr Sold Sale Type  SalePrice
# 0   NaN          NaN         0        3     2010       WD      130500
# 1   NaN          NaN         0        4     2009       WD      220000
# 2   NaN          NaN         0        1     2010       WD      109000
# 3   NaN          NaN         0        4     2010       WD      174000
# 4   NaN          NaN         0        3     2010       WD      138500

# %%
ames_train.columns
# Out:
# Index(['Id', 'PID', 'MS SubClass', 'MS Zoning', 'Lot Frontage', 'Lot Area',
#        'Street', 'Alley', 'Lot Shape', 'Land Contour', 'Utilities',
#        'Lot Config', 'Land Slope', 'Neighborhood', 'Condition 1',
#        'Condition 2', 'Bldg Type', 'House Style', 'Overall Qual',
#        'Overall Cond', 'Year Built', 'Year Remod/Add', 'Roof Style',
#        'Roof Matl', 'Exterior 1st', 'Exterior 2nd', 'Mas Vnr Type',
#        'Mas Vnr Area', 'Exter Qual', 'Exter Cond', 'Foundation', 'Bsmt Qual',
#        'Bsmt Cond', 'Bsmt Exposure', 'BsmtFin Type 1', 'BsmtFin SF 1',
#        'BsmtFin Type 2', 'BsmtFin SF 2', 'Bsmt Unf SF', 'Total Bsmt SF',
#        'Heating', 'Heating QC', 'Central Air', 'Electrical', '1st Flr SF',
#        '2nd Flr SF', 'Low Qual Fin SF', 'Gr Liv Area', 'Bsmt Full Bath',
#        'Bsmt Half Bath', 'Full Bath', 'Half Bath', 'Bedroom AbvGr',
#        'Kitchen AbvGr', 'Kitchen Qual', 'TotRms AbvGrd', 'Functional',
#        'Fireplaces', 'Fireplace Qu', 'Garage Type', 'Garage Yr Blt',
#        'Garage Finish', 'Garage Cars', 'Garage Area', 'Garage Qual',
#        'Garage Cond', 'Paved Drive', 'Wood Deck SF', 'Open Porch SF',
#        'Enclosed Porch', '3Ssn Porch', 'Screen Porch', 'Pool Area', 'Pool QC',
#        'Fence', 'Misc Feature', 'Misc Val', 'Mo Sold', 'Yr Sold', 'Sale Type',
#        'SalePrice'],
#       dtype='object')

# %%
ames_train.shape
# Out:
# (2051, 81)

# %%
ames_train.info
# Out:
# <bound method DataFrame.info of         Id        PID  MS SubClass MS Zoning  Lot Frontage  Lot Area Street  \
# 0      109  533352170           60        RL           NaN     13517   Pave
# 1      544  531379050           60        RL          43.0     11492   Pave
# 2      153  535304180           20        RL          68.0      7922   Pave
# 3      318  916386060           60        RL          73.0      9802   Pave
# 4      255  906425045           50        RL          82.0     14235   Pave
# ...    ...        ...          ...       ...           ...       ...    ...
# 2046  1587  921126030           20        RL          79.0     11449   Pave
# 2047   785  905377130           30        RL           NaN     12342   Pave
# 2048   916  909253010           50        RL          57.0      7558   Pave
# 2049   639  535179160           20        RL          80.0     10400   Pave
# 2050    10  527162130           60        RL          60.0      7500   Pave
#
#      Alley Lot Shape Land Contour Utilities Lot Config Land Slope  \
# 0      NaN       IR1          Lvl    AllPub    CulDSac        Gtl
# 1      NaN       IR1          Lvl    AllPub    CulDSac        Gtl
# 2      NaN       Reg          Lvl    AllPub     Inside        Gtl
# 3      NaN       Reg          Lvl    AllPub     Inside        Gtl
# 4      NaN       IR1          Lvl    AllPub     Inside        Gtl
# ...    ...       ...          ...       ...        ...        ...
# 2046   NaN       IR1          HLS    AllPub     Inside        Gtl
# 2047   NaN       IR1          Lvl    AllPub     Inside        Gtl
# 2048   NaN       Reg          Bnk    AllPub     Inside        Gtl
# 2049   NaN       Reg          Lvl    AllPub     Corner        Gtl
# 2050   NaN       Reg          Lvl    AllPub     Inside        Gtl
#
#      Neighborhood Condition 1 Condition 2 Bldg Type House Style  Overall Qual  \
# 0          Sawyer        RRAe        Norm      1Fam      2Story             6
# 1         SawyerW        Norm        Norm      1Fam      2Story             7
# 2           NAmes        Norm        Norm      1Fam      1Story             5
# 3          Timber        Norm        Norm      1Fam      2Story             5
# 4         SawyerW        Norm        Norm      1Fam      1.5Fin             6
# ...           ...         ...         ...       ...         ...           ...
# 2046       Timber        Norm        Norm      1Fam      1Story             8
# 2047      Edwards        Norm        Norm      1Fam      1Story             4
# 2048      Crawfor        Norm        Norm      1Fam      1.5Fin             6
# 2049        NAmes        Norm        Norm      1Fam      1Story             4
# 2050      Gilbert        Norm        Norm      1Fam      2Story             7
#
#       Overall Cond  Year Built  Year Remod/Add Roof Style Roof Matl  \
# 0                8        1976            2005      Gable   CompShg
# 1                5        1996            1997      Gable   CompShg
# 2                7        1953            2007      Gable   CompShg
# 3                5        2006            2007      Gable   CompShg
# 4                8        1900            1993      Gable   CompShg
# ...            ...         ...             ...        ...       ...
# 2046             5        2007            2007      Gable   CompShg
# 2047             5        1940            1950      Gable   CompShg
# 2048             6        1928            1950      Gable   CompShg
# 2049             5        1956            1956      Gable   CompShg
# 2050             5        1999            1999      Gable   CompShg
#
#      Exterior 1st Exterior 2nd Mas Vnr Type  Mas Vnr Area Exter Qual  \
# 0         HdBoard      Plywood      BrkFace         289.0         Gd
# 1         VinylSd      VinylSd      BrkFace         132.0         Gd
# 2         VinylSd      VinylSd         None           0.0         TA
# 3         VinylSd      VinylSd         None           0.0         TA
# 4         Wd Sdng      Plywood         None           0.0         TA
# ...           ...          ...          ...           ...        ...
# 2046      VinylSd      VinylSd         None           0.0         Gd
# 2047      VinylSd      VinylSd         None           0.0         TA
# 2048      BrkFace        Stone         None           0.0         TA
# 2049      Plywood      Plywood         None           0.0         TA
# 2050      VinylSd      VinylSd         None           0.0         TA
#
#      Exter Cond Foundation Bsmt Qual Bsmt Cond Bsmt Exposure BsmtFin Type 1  \
# 0            TA     CBlock        TA        TA            No            GLQ
# 1            TA      PConc        Gd        TA            No            GLQ
# 2            Gd     CBlock        TA        TA            No            GLQ
# 3            TA      PConc        Gd        TA            No            Unf
# 4            TA      PConc        Fa        Gd            No            Unf
# ...         ...        ...       ...       ...           ...            ...
# 2046         TA      PConc        Gd        TA            Av            GLQ
# 2047         TA     CBlock        TA        TA            No            BLQ
# 2048         TA     BrkTil        TA        TA            No            Unf
# 2049         TA     CBlock        TA        TA            No            Rec
# 2050         TA      PConc        TA        TA            No            Unf
#
#       BsmtFin SF 1 BsmtFin Type 2  BsmtFin SF 2  Bsmt Unf SF  Total Bsmt SF  \
# 0            533.0            Unf           0.0        192.0          725.0
# 1            637.0            Unf           0.0        276.0          913.0
# 2            731.0            Unf           0.0        326.0         1057.0
# 3              0.0            Unf           0.0        384.0          384.0
# 4              0.0            Unf           0.0        676.0          676.0
# ...            ...            ...           ...          ...            ...
# 2046        1011.0            Unf           0.0        873.0         1884.0
# 2047         262.0            Unf           0.0        599.0          861.0
# 2048           0.0            Unf           0.0        896.0          896.0
# 2049         155.0            LwQ         750.0        295.0         1200.0
# 2050           0.0            Unf           0.0        994.0          994.0
#
#      Heating Heating QC Central Air Electrical  1st Flr SF  2nd Flr SF  \
# 0       GasA         Ex           Y      SBrkr         725         754
# 1       GasA         Ex           Y      SBrkr         913        1209
# 2       GasA         TA           Y      SBrkr        1057           0
# 3       GasA         Gd           Y      SBrkr         744         700
# 4       GasA         TA           Y      SBrkr         831         614
# ...      ...        ...         ...        ...         ...         ...
# 2046    GasA         Ex           Y      SBrkr        1728           0
# 2047    GasA         Ex           Y      SBrkr         861           0
# 2048    GasA         Gd           Y      SBrkr        1172         741
# 2049    GasA         TA           Y      SBrkr        1200           0
# 2050    GasA         Gd           Y      SBrkr        1028         776
#
#       Low Qual Fin SF  Gr Liv Area  Bsmt Full Bath  Bsmt Half Bath  Full Bath  \
# 0                   0         1479             0.0             0.0          2
# 1                   0         2122             1.0             0.0          2
# 2                   0         1057             1.0             0.0          1
# 3                   0         1444             0.0             0.0          2
# 4                   0         1445             0.0             0.0          2
# ...               ...          ...             ...             ...        ...
# 2046                0         1728             1.0             0.0          2
# 2047                0          861             0.0             0.0          1
# 2048                0         1913             0.0             0.0          1
# 2049                0         1200             1.0             0.0          1
# 2050                0         1804             0.0             0.0          2
#
#       Half Bath  Bedroom AbvGr  Kitchen AbvGr Kitchen Qual  TotRms AbvGrd  \
# 0             1              3              1           Gd              6
# 1             1              4              1           Gd              8
# 2             0              3              1           Gd              5
# 3             1              3              1           TA              7
# 4             0              3              1           TA              6
# ...         ...            ...            ...          ...            ...
# 2046          0              3              1           Gd              7
# 2047          0              1              1           TA              4
# 2048          1              3              1           TA              9
# 2049          0              3              1           TA              6
# 2050          1              3              1           Gd              7
#
#      Functional  Fireplaces Fireplace Qu Garage Type  Garage Yr Blt  \
# 0           Typ           0          NaN      Attchd         1976.0
# 1           Typ           1           TA      Attchd         1997.0
# 2           Typ           0          NaN      Detchd         1953.0
# 3           Typ           0          NaN     BuiltIn         2007.0
# 4           Typ           0          NaN      Detchd         1957.0
# ...         ...         ...          ...         ...            ...
# 2046        Typ           1           Gd      Attchd         2007.0
# 2047        Typ           0          NaN      Detchd         1961.0
# 2048        Typ           1           TA      Detchd         1929.0
# 2049        Typ           2           Gd      Attchd         1956.0
# 2050        Typ           1           TA      Attchd         1999.0
#
#      Garage Finish  Garage Cars  Garage Area Garage Qual Garage Cond  \
# 0              RFn          2.0        475.0          TA          TA
# 1              RFn          2.0        559.0          TA          TA
# 2              Unf          1.0        246.0          TA          TA
# 3              Fin          2.0        400.0          TA          TA
# 4              Unf          2.0        484.0          TA          TA
# ...            ...          ...          ...         ...         ...
# 2046           Fin          2.0        520.0          TA          TA
# 2047           Unf          2.0        539.0          TA          TA
# 2048           Unf          2.0        342.0          Fa          Fa
# 2049           Unf          1.0        294.0          TA          TA
# 2050           Fin          2.0        442.0          TA          TA
#
#      Paved Drive  Wood Deck SF  Open Porch SF  Enclosed Porch  3Ssn Porch  \
# 0              Y             0             44               0           0
# 1              Y             0             74               0           0
# 2              Y             0             52               0           0
# 3              Y           100              0               0           0
# 4              N             0             59               0           0
# ...          ...           ...            ...             ...         ...
# 2046           Y             0            276               0           0
# 2047           Y           158              0               0           0
# 2048           Y             0              0               0           0
# 2049           Y             0            189             140           0
# 2050           Y           140             60               0           0
#
#       Screen Porch  Pool Area Pool QC Fence Misc Feature  Misc Val  Mo Sold  \
# 0                0          0     NaN   NaN          NaN         0        3
# 1                0          0     NaN   NaN          NaN         0        4
# 2                0          0     NaN   NaN          NaN         0        1
# 3                0          0     NaN   NaN          NaN         0        4
# 4                0          0     NaN   NaN          NaN         0        3
# ...            ...        ...     ...   ...          ...       ...      ...
# 2046             0          0     NaN   NaN          NaN         0        1
# 2047             0          0     NaN   NaN          NaN         0        3
# 2048             0          0     NaN   NaN          NaN         0        3
# 2049             0          0     NaN   NaN          NaN         0       11
# 2050             0          0     NaN   NaN          NaN         0        6
#
#       Yr Sold Sale Type  SalePrice
# 0        2010       WD      130500
# 1        2009       WD      220000
# 2        2010       WD      109000
# 3        2010       WD      174000
# 4        2010       WD      138500
# ...       ...       ...        ...
# 2046     2008       WD      298751
# 2047     2009       WD       82500
# 2048     2009       WD      177000
# 2049     2009       WD      144000
# 2050     2010       WD      189000
#
# [2051 rows x 81 columns]>

# %%
ames_train.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2051 entries, 0 to 2050
# Data columns (total 81 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   Id               2051 non-null   int64
#  1   PID              2051 non-null   int64
#  2   MS SubClass      2051 non-null   int64
#  3   MS Zoning        2051 non-null   object
#  4   Lot Frontage     1721 non-null   float64
#  5   Lot Area         2051 non-null   int64
#  6   Street           2051 non-null   object
#  7   Alley            140 non-null    object
#  8   Lot Shape        2051 non-null   object
#  9   Land Contour     2051 non-null   object
#  10  Utilities        2051 non-null   object
#  11  Lot Config       2051 non-null   object
#  12  Land Slope       2051 non-null   object
#  13  Neighborhood     2051 non-null   object
#  14  Condition 1      2051 non-null   object
#  15  Condition 2      2051 non-null   object
#  16  Bldg Type        2051 non-null   object
#  17  House Style      2051 non-null   object
#  18  Overall Qual     2051 non-null   int64
#  19  Overall Cond     2051 non-null   int64
#  20  Year Built       2051 non-null   int64
#  21  Year Remod/Add   2051 non-null   int64
#  22  Roof Style       2051 non-null   object
#  23  Roof Matl        2051 non-null   object
#  24  Exterior 1st     2051 non-null   object
#  25  Exterior 2nd     2051 non-null   object
#  26  Mas Vnr Type     2029 non-null   object
#  27  Mas Vnr Area     2029 non-null   float64
#  28  Exter Qual       2051 non-null   object
#  29  Exter Cond       2051 non-null   object
#  30  Foundation       2051 non-null   object
#  31  Bsmt Qual        1996 non-null   object
#  32  Bsmt Cond        1996 non-null   object
#  33  Bsmt Exposure    1993 non-null   object
#  34  BsmtFin Type 1   1996 non-null   object
#  35  BsmtFin SF 1     2050 non-null   float64
#  36  BsmtFin Type 2   1995 non-null   object
#  37  BsmtFin SF 2     2050 non-null   float64
#  38  Bsmt Unf SF      2050 non-null   float64
#  39  Total Bsmt SF    2050 non-null   float64
#  40  Heating          2051 non-null   object
#  41  Heating QC       2051 non-null   object
#  42  Central Air      2051 non-null   object
#  43  Electrical       2051 non-null   object
#  44  1st Flr SF       2051 non-null   int64
#  45  2nd Flr SF       2051 non-null   int64
#  46  Low Qual Fin SF  2051 non-null   int64
#  47  Gr Liv Area      2051 non-null   int64
#  48  Bsmt Full Bath   2049 non-null   float64
#  49  Bsmt Half Bath   2049 non-null   float64
#  50  Full Bath        2051 non-null   int64
#  51  Half Bath        2051 non-null   int64
#  52  Bedroom AbvGr    2051 non-null   int64
#  53  Kitchen AbvGr    2051 non-null   int64
#  54  Kitchen Qual     2051 non-null   object
#  55  TotRms AbvGrd    2051 non-null   int64
#  56  Functional       2051 non-null   object
#  57  Fireplaces       2051 non-null   int64
#  58  Fireplace Qu     1051 non-null   object
#  59  Garage Type      1938 non-null   object
#  60  Garage Yr Blt    1937 non-null   float64
#  61  Garage Finish    1937 non-null   object
#  62  Garage Cars      2050 non-null   float64
#  63  Garage Area      2050 non-null   float64
#  64  Garage Qual      1937 non-null   object
#  65  Garage Cond      1937 non-null   object
#  66  Paved Drive      2051 non-null   object
#  67  Wood Deck SF     2051 non-null   int64
#  68  Open Porch SF    2051 non-null   int64
#  69  Enclosed Porch   2051 non-null   int64
#  70  3Ssn Porch       2051 non-null   int64
#  71  Screen Porch     2051 non-null   int64
#  72  Pool Area        2051 non-null   int64
#  73  Pool QC          9 non-null      object
#  74  Fence            400 non-null    object
#  75  Misc Feature     65 non-null     object
#  76  Misc Val         2051 non-null   int64
#  77  Mo Sold          2051 non-null   int64
#  78  Yr Sold          2051 non-null   int64
#  79  Sale Type        2051 non-null   object
#  80  SalePrice        2051 non-null   int64
# dtypes: float64(11), int64(28), object(42)
# memory usage: 1.3+ MB

# %% [markdown]
# Taking a look at the basic information of the test dataset

# %%
ames_test.head()
# Out:
#      Id        PID  MS SubClass MS Zoning  Lot Frontage  Lot Area Street  \
# 0  2658  902301120          190        RM          69.0      9142   Pave
# 1  2718  905108090           90        RL           NaN      9662   Pave
# 2  2414  528218130           60        RL          58.0     17104   Pave
# 3  1989  902207150           30        RM          60.0      8520   Pave
# 4   625  535105100           20        RL           NaN      9500   Pave
#
#   Alley Lot Shape Land Contour Utilities Lot Config Land Slope Neighborhood  \
# 0  Grvl       Reg          Lvl    AllPub     Inside        Gtl      OldTown
# 1   NaN       IR1          Lvl    AllPub     Inside        Gtl       Sawyer
# 2   NaN       IR1          Lvl    AllPub     Inside        Gtl      Gilbert
# 3   NaN       Reg          Lvl    AllPub     Inside        Gtl      OldTown
# 4   NaN       IR1          Lvl    AllPub     Inside        Gtl        NAmes
#
#   Condition 1 Condition 2 Bldg Type House Style  Overall Qual  Overall Cond  \
# 0        Norm        Norm    2fmCon      2Story             6             8
# 1        Norm        Norm    Duplex      1Story             5             4
# 2        Norm        Norm      1Fam      2Story             7             5
# 3        Norm        Norm      1Fam      1Story             5             6
# 4        Norm        Norm      1Fam      1Story             6             5
#
#    Year Built  Year Remod/Add Roof Style Roof Matl Exterior 1st Exterior 2nd  \
# 0        1910            1950      Gable   CompShg      AsbShng      AsbShng
# 1        1977            1977      Gable   CompShg      Plywood      Plywood
# 2        2006            2006      Gable   CompShg      VinylSd      VinylSd
# 3        1923            2006      Gable   CompShg      Wd Sdng      Wd Sdng
# 4        1963            1963      Gable   CompShg      Plywood      Plywood
#
#   Mas Vnr Type  Mas Vnr Area Exter Qual Exter Cond Foundation Bsmt Qual  \
# 0         None           0.0         TA         Fa      Stone        Fa
# 1         None           0.0         TA         TA     CBlock        Gd
# 2         None           0.0         Gd         TA      PConc        Gd
# 3         None           0.0         Gd         TA     CBlock        TA
# 4      BrkFace         247.0         TA         TA     CBlock        Gd
#
#   Bsmt Cond Bsmt Exposure BsmtFin Type 1  BsmtFin SF 1 BsmtFin Type 2  \
# 0        TA            No            Unf             0            Unf
# 1        TA            No            Unf             0            Unf
# 2        Gd            Av            GLQ           554            Unf
# 3        TA            No            Unf             0            Unf
# 4        TA            No            BLQ           609            Unf
#
#    BsmtFin SF 2  Bsmt Unf SF  Total Bsmt SF Heating Heating QC Central Air  \
# 0             0         1020           1020    GasA         Gd           N
# 1             0         1967           1967    GasA         TA           Y
# 2             0          100            654    GasA         Ex           Y
# 3             0          968            968    GasA         TA           Y
# 4             0          785           1394    GasA         Gd           Y
#
#   Electrical  1st Flr SF  2nd Flr SF  Low Qual Fin SF  Gr Liv Area  \
# 0      FuseP         908        1020                0         1928
# 1      SBrkr        1967           0                0         1967
# 2      SBrkr         664         832                0         1496
# 3      SBrkr         968           0                0          968
# 4      SBrkr        1394           0                0         1394
#
#    Bsmt Full Bath  Bsmt Half Bath  Full Bath  Half Bath  Bedroom AbvGr  \
# 0               0               0          2          0              4
# 1               0               0          2          0              6
# 2               1               0          2          1              3
# 3               0               0          1          0              2
# 4               1               0          1          1              3
#
#    Kitchen AbvGr Kitchen Qual  TotRms AbvGrd Functional  Fireplaces  \
# 0              2           Fa              9        Typ           0
# 1              2           TA             10        Typ           0
# 2              1           Gd              7        Typ           1
# 3              1           TA              5        Typ           0
# 4              1           TA              6        Typ           2
#
#   Fireplace Qu Garage Type  Garage Yr Blt Garage Finish  Garage Cars  \
# 0          NaN      Detchd         1910.0           Unf            1
# 1          NaN      Attchd         1977.0           Fin            2
# 2           Gd      Attchd         2006.0           RFn            2
# 3          NaN      Detchd         1935.0           Unf            2
# 4           Gd      Attchd         1963.0           RFn            2
#
#    Garage Area Garage Qual Garage Cond Paved Drive  Wood Deck SF  \
# 0          440          Po          Po           Y             0
# 1          580          TA          TA           Y           170
# 2          426          TA          TA           Y           100
# 3          480          Fa          TA           N             0
# 4          514          TA          TA           Y             0
#
#    Open Porch SF  Enclosed Porch  3Ssn Porch  Screen Porch  Pool Area Pool QC  \
# 0             60             112           0             0          0     NaN
# 1              0               0           0             0          0     NaN
# 2             24               0           0             0          0     NaN
# 3              0             184           0             0          0     NaN
# 4             76               0           0           185          0     NaN
#
#   Fence Misc Feature  Misc Val  Mo Sold  Yr Sold Sale Type
# 0   NaN          NaN         0        4     2006       WD
# 1   NaN          NaN         0        8     2006       WD
# 2   NaN          NaN         0        9     2006       New
# 3   NaN          NaN         0        7     2007       WD
# 4   NaN          NaN         0        7     2009       WD

# %%
ames_test.columns
# Out:
# Index(['Id', 'PID', 'MS SubClass', 'MS Zoning', 'Lot Frontage', 'Lot Area',
#        'Street', 'Alley', 'Lot Shape', 'Land Contour', 'Utilities',
#        'Lot Config', 'Land Slope', 'Neighborhood', 'Condition 1',
#        'Condition 2', 'Bldg Type', 'House Style', 'Overall Qual',
#        'Overall Cond', 'Year Built', 'Year Remod/Add', 'Roof Style',
#        'Roof Matl', 'Exterior 1st', 'Exterior 2nd', 'Mas Vnr Type',
#        'Mas Vnr Area', 'Exter Qual', 'Exter Cond', 'Foundation', 'Bsmt Qual',
#        'Bsmt Cond', 'Bsmt Exposure', 'BsmtFin Type 1', 'BsmtFin SF 1',
#        'BsmtFin Type 2', 'BsmtFin SF 2', 'Bsmt Unf SF', 'Total Bsmt SF',
#        'Heating', 'Heating QC', 'Central Air', 'Electrical', '1st Flr SF',
#        '2nd Flr SF', 'Low Qual Fin SF', 'Gr Liv Area', 'Bsmt Full Bath',
#        'Bsmt Half Bath', 'Full Bath', 'Half Bath', 'Bedroom AbvGr',
#        'Kitchen AbvGr', 'Kitchen Qual', 'TotRms AbvGrd', 'Functional',
#        'Fireplaces', 'Fireplace Qu', 'Garage Type', 'Garage Yr Blt',
#        'Garage Finish', 'Garage Cars', 'Garage Area', 'Garage Qual',
#        'Garage Cond', 'Paved Drive', 'Wood Deck SF', 'Open Porch SF',
#        'Enclosed Porch', '3Ssn Porch', 'Screen Porch', 'Pool Area', 'Pool QC',
#        'Fence', 'Misc Feature', 'Misc Val', 'Mo Sold', 'Yr Sold', 'Sale Type'],
#       dtype='object')

# %%
ames_test.info
# Out:
# <bound method DataFrame.info of        Id        PID  MS SubClass MS Zoning  Lot Frontage  Lot Area Street  \
# 0    2658  902301120          190        RM          69.0      9142   Pave
# 1    2718  905108090           90        RL           NaN      9662   Pave
# 2    2414  528218130           60        RL          58.0     17104   Pave
# 3    1989  902207150           30        RM          60.0      8520   Pave
# 4     625  535105100           20        RL           NaN      9500   Pave
# ..    ...        ...          ...       ...           ...       ...    ...
# 873  1662  527377110           60        RL          80.0      8000   Pave
# 874  1234  535126140           60        RL          90.0     14670   Pave
# 875  1373  904100040           20        RL          55.0      8250   Pave
# 876  1672  527425140           20        RL          60.0      9000   Pave
# 877  1939  535327160           20        RL          70.0      8400   Pave
#
#     Alley Lot Shape Land Contour Utilities Lot Config Land Slope Neighborhood  \
# 0    Grvl       Reg          Lvl    AllPub     Inside        Gtl      OldTown
# 1     NaN       IR1          Lvl    AllPub     Inside        Gtl       Sawyer
# 2     NaN       IR1          Lvl    AllPub     Inside        Gtl      Gilbert
# 3     NaN       Reg          Lvl    AllPub     Inside        Gtl      OldTown
# 4     NaN       IR1          Lvl    AllPub     Inside        Gtl        NAmes
# ..    ...       ...          ...       ...        ...        ...          ...
# 873   NaN       Reg          Lvl    AllPub     Inside        Gtl       NWAmes
# 874   NaN       Reg          Lvl    AllPub     Inside        Gtl        NAmes
# 875   NaN       Reg          Lvl    AllPub     Inside        Gtl       Sawyer
# 876   NaN       Reg          Lvl    AllPub        FR2        Gtl        NAmes
# 877   NaN       Reg          Lvl    AllPub     Corner        Gtl        NAmes
#
#     Condition 1 Condition 2 Bldg Type House Style  Overall Qual  Overall Cond  \
# 0          Norm        Norm    2fmCon      2Story             6             8
# 1          Norm        Norm    Duplex      1Story             5             4
# 2          Norm        Norm      1Fam      2Story             7             5
# 3          Norm        Norm      1Fam      1Story             5             6
# 4          Norm        Norm      1Fam      1Story             6             5
# ..          ...         ...       ...         ...           ...           ...
# 873        PosN        Norm      1Fam      2Story             6             6
# 874        Norm        Norm      1Fam      2Story             6             7
# 875       Feedr        Norm      1Fam      1Story             5             5
# 876        Norm        Norm      1Fam      1Story             4             6
# 877        Norm        Norm      1Fam      1Story             5             5
#
#      Year Built  Year Remod/Add Roof Style Roof Matl Exterior 1st  \
# 0          1910            1950      Gable   CompShg      AsbShng
# 1          1977            1977      Gable   CompShg      Plywood
# 2          2006            2006      Gable   CompShg      VinylSd
# 3          1923            2006      Gable   CompShg      Wd Sdng
# 4          1963            1963      Gable   CompShg      Plywood
# ..          ...             ...        ...       ...          ...
# 873        1974            1974      Gable   CompShg      HdBoard
# 874        1966            1999      Gable   CompShg      VinylSd
# 875        1968            1968        Hip   CompShg      HdBoard
# 876        1971            1971      Gable   CompShg      HdBoard
# 877        1955            1955      Gable   CompShg      MetalSd
#
#     Exterior 2nd Mas Vnr Type  Mas Vnr Area Exter Qual Exter Cond Foundation  \
# 0        AsbShng         None           0.0         TA         Fa      Stone
# 1        Plywood         None           0.0         TA         TA     CBlock
# 2        VinylSd         None           0.0         Gd         TA      PConc
# 3        Wd Sdng         None           0.0         Gd         TA     CBlock
# 4        Plywood      BrkFace         247.0         TA         TA     CBlock
# ..           ...          ...           ...        ...        ...        ...
# 873      HdBoard         None           0.0         TA         TA     CBlock
# 874      VinylSd      BrkFace         410.0         Gd         Gd     CBlock
# 875      HdBoard         None           0.0         TA         TA     CBlock
# 876      HdBoard         None           0.0         TA         TA      PConc
# 877      MetalSd         None           0.0         TA         Gd     CBlock
#
#     Bsmt Qual Bsmt Cond Bsmt Exposure BsmtFin Type 1  BsmtFin SF 1  \
# 0          Fa        TA            No            Unf             0
# 1          Gd        TA            No            Unf             0
# 2          Gd        Gd            Av            GLQ           554
# 3          TA        TA            No            Unf             0
# 4          Gd        TA            No            BLQ           609
# ..        ...       ...           ...            ...           ...
# 873        TA        TA            No            ALQ           931
# 874        TA        TA            No            BLQ           575
# 875        TA        TA            No            BLQ           250
# 876        TA        TA            No            ALQ           616
# 877        TA        TA            No            BLQ           793
#
#     BsmtFin Type 2  BsmtFin SF 2  Bsmt Unf SF  Total Bsmt SF Heating  \
# 0              Unf             0         1020           1020    GasA
# 1              Unf             0         1967           1967    GasA
# 2              Unf             0          100            654    GasA
# 3              Unf             0          968            968    GasA
# 4              Unf             0          785           1394    GasA
# ..             ...           ...          ...            ...     ...
# 873            LwQ           153            0           1084    GasA
# 874            Unf             0          529           1104    GasA
# 875            LwQ           492          210            952    GasA
# 876            Unf             0          248            864    GasA
# 877            Unf             0          130            923    GasA
#
#     Heating QC Central Air Electrical  1st Flr SF  2nd Flr SF  \
# 0           Gd           N      FuseP         908        1020
# 1           TA           Y      SBrkr        1967           0
# 2           Ex           Y      SBrkr         664         832
# 3           TA           Y      SBrkr         968           0
# 4           Gd           Y      SBrkr        1394           0
# ..         ...         ...        ...         ...         ...
# 873         TA           Y      SBrkr        1084         793
# 874         Ex           Y      SBrkr        1104         884
# 875         Ex           Y      SBrkr        1211           0
# 876         TA           Y      SBrkr         864           0
# 877         TA           Y      SBrkr         925           0
#
#      Low Qual Fin SF  Gr Liv Area  Bsmt Full Bath  Bsmt Half Bath  Full Bath  \
# 0                  0         1928               0               0          2
# 1                  0         1967               0               0          2
# 2                  0         1496               1               0          2
# 3                  0          968               0               0          1
# 4                  0         1394               1               0          1
# ..               ...          ...             ...             ...        ...
# 873                0         1877               1               0          2
# 874                0         1988               0               0          2
# 875                0         1211               0               0          1
# 876                0          864               0               0          1
# 877                0          925               1               0          1
#
#      Half Bath  Bedroom AbvGr  Kitchen AbvGr Kitchen Qual  TotRms AbvGrd  \
# 0            0              4              2           Fa              9
# 1            0              6              2           TA             10
# 2            1              3              1           Gd              7
# 3            0              2              1           TA              5
# 4            1              3              1           TA              6
# ..         ...            ...            ...          ...            ...
# 873          1              4              1           TA              8
# 874          1              4              1           Gd              9
# 875          0              3              1           TA              5
# 876          0              3              1           TA              5
# 877          0              3              1           TA              5
#
#     Functional  Fireplaces Fireplace Qu Garage Type  Garage Yr Blt  \
# 0          Typ           0          NaN      Detchd         1910.0
# 1          Typ           0          NaN      Attchd         1977.0
# 2          Typ           1           Gd      Attchd         2006.0
# 3          Typ           0          NaN      Detchd         1935.0
# 4          Typ           2           Gd      Attchd         1963.0
# ..         ...         ...          ...         ...            ...
# 873        Typ           1           TA      Attchd         1974.0
# 874        Typ           1           Gd      Attchd         1966.0
# 875        Typ           1           TA      Attchd         1968.0
# 876        Typ           0          NaN      Detchd         1974.0
# 877        Typ           2           TA      Attchd         1955.0
#
#     Garage Finish  Garage Cars  Garage Area Garage Qual Garage Cond  \
# 0             Unf            1          440          Po          Po
# 1             Fin            2          580          TA          TA
# 2             RFn            2          426          TA          TA
# 3             Unf            2          480          Fa          TA
# 4             RFn            2          514          TA          TA
# ..            ...          ...          ...         ...         ...
# 873           Unf            2          488          TA          TA
# 874           RFn            2          480          TA          TA
# 875           Unf            1          322          TA          TA
# 876           Unf            2          528          TA          TA
# 877           Unf            1          390          TA          TA
#
#     Paved Drive  Wood Deck SF  Open Porch SF  Enclosed Porch  3Ssn Porch  \
# 0             Y             0             60             112           0
# 1             Y           170              0               0           0
# 2             Y           100             24               0           0
# 3             N             0              0             184           0
# 4             Y             0             76               0           0
# ..          ...           ...            ...             ...         ...
# 873           Y             0             96               0           0
# 874           Y             0            230               0           0
# 875           Y             0             63               0           0
# 876           Y             0              0               0           0
# 877           Y            81              0               0           0
#
#      Screen Porch  Pool Area Pool QC  Fence Misc Feature  Misc Val  Mo Sold  \
# 0               0          0     NaN    NaN          NaN         0        4
# 1               0          0     NaN    NaN          NaN         0        8
# 2               0          0     NaN    NaN          NaN         0        9
# 3               0          0     NaN    NaN          NaN         0        7
# 4             185          0     NaN    NaN          NaN         0        7
# ..            ...        ...     ...    ...          ...       ...      ...
# 873             0          0     NaN    NaN          NaN         0       11
# 874             0          0     NaN  MnPrv          NaN         0        8
# 875             0          0     NaN    NaN          NaN         0        8
# 876             0          0     NaN   GdWo          NaN         0        5
# 877             0          0     NaN   GdWo          NaN         0        3
#
#      Yr Sold Sale Type
# 0       2006       WD
# 1       2006       WD
# 2       2006       New
# 3       2007       WD
# 4       2009       WD
# ..       ...       ...
# 873     2007       WD
# 874     2008       WD
# 875     2008       WD
# 876     2007       WD
# 877     2007       WD
#
# [878 rows x 80 columns]>

# %%
ames_test.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 878 entries, 0 to 877
# Data columns (total 80 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   Id               878 non-null    int64
#  1   PID              878 non-null    int64
#  2   MS SubClass      878 non-null    int64
#  3   MS Zoning        878 non-null    object
#  4   Lot Frontage     718 non-null    float64
#  5   Lot Area         878 non-null    int64
#  6   Street           878 non-null    object
#  7   Alley            58 non-null     object
#  8   Lot Shape        878 non-null    object
#  9   Land Contour     878 non-null    object
#  10  Utilities        878 non-null    object
#  11  Lot Config       878 non-null    object
#  12  Land Slope       878 non-null    object
#  13  Neighborhood     878 non-null    object
#  14  Condition 1      878 non-null    object
#  15  Condition 2      878 non-null    object
#  16  Bldg Type        878 non-null    object
#  17  House Style      878 non-null    object
#  18  Overall Qual     878 non-null    int64
#  19  Overall Cond     878 non-null    int64
#  20  Year Built       878 non-null    int64
#  21  Year Remod/Add   878 non-null    int64
#  22  Roof Style       878 non-null    object
#  23  Roof Matl        878 non-null    object
#  24  Exterior 1st     878 non-null    object
#  25  Exterior 2nd     878 non-null    object
#  26  Mas Vnr Type     877 non-null    object
#  27  Mas Vnr Area     877 non-null    float64
#  28  Exter Qual       878 non-null    object
#  29  Exter Cond       878 non-null    object
#  30  Foundation       878 non-null    object
#  31  Bsmt Qual        853 non-null    object
#  32  Bsmt Cond        853 non-null    object
#  33  Bsmt Exposure    853 non-null    object
#  34  BsmtFin Type 1   853 non-null    object
#  35  BsmtFin SF 1     878 non-null    int64
#  36  BsmtFin Type 2   853 non-null    object
#  37  BsmtFin SF 2     878 non-null    int64
#  38  Bsmt Unf SF      878 non-null    int64
#  39  Total Bsmt SF    878 non-null    int64
#  40  Heating          878 non-null    object
#  41  Heating QC       878 non-null    object
#  42  Central Air      878 non-null    object
#  43  Electrical       877 non-null    object
#  44  1st Flr SF       878 non-null    int64
#  45  2nd Flr SF       878 non-null    int64
#  46  Low Qual Fin SF  878 non-null    int64
#  47  Gr Liv Area      878 non-null    int64
#  48  Bsmt Full Bath   878 non-null    int64
#  49  Bsmt Half Bath   878 non-null    int64
#  50  Full Bath        878 non-null    int64
#  51  Half Bath        878 non-null    int64
#  52  Bedroom AbvGr    878 non-null    int64
#  53  Kitchen AbvGr    878 non-null    int64
#  54  Kitchen Qual     878 non-null    object
#  55  TotRms AbvGrd    878 non-null    int64
#  56  Functional       878 non-null    object
#  57  Fireplaces       878 non-null    int64
#  58  Fireplace Qu     456 non-null    object
#  59  Garage Type      834 non-null    object
#  60  Garage Yr Blt    833 non-null    float64
#  61  Garage Finish    833 non-null    object
#  62  Garage Cars      878 non-null    int64
#  63  Garage Area      878 non-null    int64
#  64  Garage Qual      833 non-null    object
#  65  Garage Cond      833 non-null    object
#  66  Paved Drive      878 non-null    object
#  67  Wood Deck SF     878 non-null    int64
#  68  Open Porch SF    878 non-null    int64
#  69  Enclosed Porch   878 non-null    int64
#  70  3Ssn Porch       878 non-null    int64
#  71  Screen Porch     878 non-null    int64
#  72  Pool Area        878 non-null    int64
#  73  Pool QC          4 non-null      object
#  74  Fence            172 non-null    object
#  75  Misc Feature     41 non-null     object
#  76  Misc Val         878 non-null    int64
#  77  Mo Sold          878 non-null    int64
#  78  Yr Sold          878 non-null    int64
#  79  Sale Type        878 non-null    object
# dtypes: float64(3), int64(35), object(42)
# memory usage: 548.9+ KB

# %%
ames_test.shape
# Out:
# (878, 80)

# %% [markdown]
# # Data Cleaning:
#
# 1. Formatting the columns to lowercase
# 2. After checking all the columns with null values and do the relavant action on it

# %%
ames_train.columns = [i.lower().replace(' ','_') for i in ames_train.columns]

# %%
ames_train.head()
# Out:
#     id        pid  ms_subclass ms_zoning  lot_frontage  lot_area street alley  \
# 0  109  533352170           60        RL           NaN     13517   Pave   NaN
# 1  544  531379050           60        RL          43.0     11492   Pave   NaN
# 2  153  535304180           20        RL          68.0      7922   Pave   NaN
# 3  318  916386060           60        RL          73.0      9802   Pave   NaN
# 4  255  906425045           50        RL          82.0     14235   Pave   NaN
#
#   lot_shape land_contour utilities lot_config land_slope neighborhood  \
# 0       IR1          Lvl    AllPub    CulDSac        Gtl       Sawyer
# 1       IR1          Lvl    AllPub    CulDSac        Gtl      SawyerW
# 2       Reg          Lvl    AllPub     Inside        Gtl        NAmes
# 3       Reg          Lvl    AllPub     Inside        Gtl       Timber
# 4       IR1          Lvl    AllPub     Inside        Gtl      SawyerW
#
#   condition_1 condition_2 bldg_type house_style  overall_qual  overall_cond  \
# 0        RRAe        Norm      1Fam      2Story             6             8
# 1        Norm        Norm      1Fam      2Story             7             5
# 2        Norm        Norm      1Fam      1Story             5             7
# 3        Norm        Norm      1Fam      2Story             5             5
# 4        Norm        Norm      1Fam      1.5Fin             6             8
#
#    year_built  year_remod/add roof_style roof_matl exterior_1st exterior_2nd  \
# 0        1976            2005      Gable   CompShg      HdBoard      Plywood
# 1        1996            1997      Gable   CompShg      VinylSd      VinylSd
# 2        1953            2007      Gable   CompShg      VinylSd      VinylSd
# 3        2006            2007      Gable   CompShg      VinylSd      VinylSd
# 4        1900            1993      Gable   CompShg      Wd Sdng      Plywood
#
#   mas_vnr_type  mas_vnr_area exter_qual exter_cond foundation bsmt_qual  \
# 0      BrkFace         289.0         Gd         TA     CBlock        TA
# 1      BrkFace         132.0         Gd         TA      PConc        Gd
# 2         None           0.0         TA         Gd     CBlock        TA
# 3         None           0.0         TA         TA      PConc        Gd
# 4         None           0.0         TA         TA      PConc        Fa
#
#   bsmt_cond bsmt_exposure bsmtfin_type_1  bsmtfin_sf_1 bsmtfin_type_2  \
# 0        TA            No            GLQ         533.0            Unf
# 1        TA            No            GLQ         637.0            Unf
# 2        TA            No            GLQ         731.0            Unf
# 3        TA            No            Unf           0.0            Unf
# 4        Gd            No            Unf           0.0            Unf
#
#    bsmtfin_sf_2  bsmt_unf_sf  total_bsmt_sf heating heating_qc central_air  \
# 0           0.0        192.0          725.0    GasA         Ex           Y
# 1           0.0        276.0          913.0    GasA         Ex           Y
# 2           0.0        326.0         1057.0    GasA         TA           Y
# 3           0.0        384.0          384.0    GasA         Gd           Y
# 4           0.0        676.0          676.0    GasA         TA           Y
#
#   electrical  1st_flr_sf  2nd_flr_sf  low_qual_fin_sf  gr_liv_area  \
# 0      SBrkr         725         754                0         1479
# 1      SBrkr         913        1209                0         2122
# 2      SBrkr        1057           0                0         1057
# 3      SBrkr         744         700                0         1444
# 4      SBrkr         831         614                0         1445
#
#    bsmt_full_bath  bsmt_half_bath  full_bath  half_bath  bedroom_abvgr  \
# 0             0.0             0.0          2          1              3
# 1             1.0             0.0          2          1              4
# 2             1.0             0.0          1          0              3
# 3             0.0             0.0          2          1              3
# 4             0.0             0.0          2          0              3
#
#    kitchen_abvgr kitchen_qual  totrms_abvgrd functional  fireplaces  \
# 0              1           Gd              6        Typ           0
# 1              1           Gd              8        Typ           1
# 2              1           Gd              5        Typ           0
# 3              1           TA              7        Typ           0
# 4              1           TA              6        Typ           0
#
#   fireplace_qu garage_type  garage_yr_blt garage_finish  garage_cars  \
# 0          NaN      Attchd         1976.0           RFn          2.0
# 1           TA      Attchd         1997.0           RFn          2.0
# 2          NaN      Detchd         1953.0           Unf          1.0
# 3          NaN     BuiltIn         2007.0           Fin          2.0
# 4          NaN      Detchd         1957.0           Unf          2.0
#
#    garage_area garage_qual garage_cond paved_drive  wood_deck_sf  \
# 0        475.0          TA          TA           Y             0
# 1        559.0          TA          TA           Y             0
# 2        246.0          TA          TA           Y             0
# 3        400.0          TA          TA           Y           100
# 4        484.0          TA          TA           N             0
#
#    open_porch_sf  enclosed_porch  3ssn_porch  screen_porch  pool_area pool_qc  \
# 0             44               0           0             0          0     NaN
# 1             74               0           0             0          0     NaN
# 2             52               0           0             0          0     NaN
# 3              0               0           0             0          0     NaN
# 4             59               0           0             0          0     NaN
#
#   fence misc_feature  misc_val  mo_sold  yr_sold sale_type  saleprice
# 0   NaN          NaN         0        3     2010       WD      130500
# 1   NaN          NaN         0        4     2009       WD      220000
# 2   NaN          NaN         0        1     2010       WD      109000
# 3   NaN          NaN         0        4     2010       WD      174000
# 4   NaN          NaN         0        3     2010       WD      138500

# %%
ames_test.columns = [i.lower().replace(' ','_') for i in ames_test.columns]

# %%
ames_test.head()
# Out:
#      id        pid  ms_subclass ms_zoning  lot_frontage  lot_area street  \
# 0  2658  902301120          190        RM          69.0      9142   Pave
# 1  2718  905108090           90        RL           NaN      9662   Pave
# 2  2414  528218130           60        RL          58.0     17104   Pave
# 3  1989  902207150           30        RM          60.0      8520   Pave
# 4   625  535105100           20        RL           NaN      9500   Pave
#
#   alley lot_shape land_contour utilities lot_config land_slope neighborhood  \
# 0  Grvl       Reg          Lvl    AllPub     Inside        Gtl      OldTown
# 1   NaN       IR1          Lvl    AllPub     Inside        Gtl       Sawyer
# 2   NaN       IR1          Lvl    AllPub     Inside        Gtl      Gilbert
# 3   NaN       Reg          Lvl    AllPub     Inside        Gtl      OldTown
# 4   NaN       IR1          Lvl    AllPub     Inside        Gtl        NAmes
#
#   condition_1 condition_2 bldg_type house_style  overall_qual  overall_cond  \
# 0        Norm        Norm    2fmCon      2Story             6             8
# 1        Norm        Norm    Duplex      1Story             5             4
# 2        Norm        Norm      1Fam      2Story             7             5
# 3        Norm        Norm      1Fam      1Story             5             6
# 4        Norm        Norm      1Fam      1Story             6             5
#
#    year_built  year_remod/add roof_style roof_matl exterior_1st exterior_2nd  \
# 0        1910            1950      Gable   CompShg      AsbShng      AsbShng
# 1        1977            1977      Gable   CompShg      Plywood      Plywood
# 2        2006            2006      Gable   CompShg      VinylSd      VinylSd
# 3        1923            2006      Gable   CompShg      Wd Sdng      Wd Sdng
# 4        1963            1963      Gable   CompShg      Plywood      Plywood
#
#   mas_vnr_type  mas_vnr_area exter_qual exter_cond foundation bsmt_qual  \
# 0         None           0.0         TA         Fa      Stone        Fa
# 1         None           0.0         TA         TA     CBlock        Gd
# 2         None           0.0         Gd         TA      PConc        Gd
# 3         None           0.0         Gd         TA     CBlock        TA
# 4      BrkFace         247.0         TA         TA     CBlock        Gd
#
#   bsmt_cond bsmt_exposure bsmtfin_type_1  bsmtfin_sf_1 bsmtfin_type_2  \
# 0        TA            No            Unf             0            Unf
# 1        TA            No            Unf             0            Unf
# 2        Gd            Av            GLQ           554            Unf
# 3        TA            No            Unf             0            Unf
# 4        TA            No            BLQ           609            Unf
#
#    bsmtfin_sf_2  bsmt_unf_sf  total_bsmt_sf heating heating_qc central_air  \
# 0             0         1020           1020    GasA         Gd           N
# 1             0         1967           1967    GasA         TA           Y
# 2             0          100            654    GasA         Ex           Y
# 3             0          968            968    GasA         TA           Y
# 4             0          785           1394    GasA         Gd           Y
#
#   electrical  1st_flr_sf  2nd_flr_sf  low_qual_fin_sf  gr_liv_area  \
# 0      FuseP         908        1020                0         1928
# 1      SBrkr        1967           0                0         1967
# 2      SBrkr         664         832                0         1496
# 3      SBrkr         968           0                0          968
# 4      SBrkr        1394           0                0         1394
#
#    bsmt_full_bath  bsmt_half_bath  full_bath  half_bath  bedroom_abvgr  \
# 0               0               0          2          0              4
# 1               0               0          2          0              6
# 2               1               0          2          1              3
# 3               0               0          1          0              2
# 4               1               0          1          1              3
#
#    kitchen_abvgr kitchen_qual  totrms_abvgrd functional  fireplaces  \
# 0              2           Fa              9        Typ           0
# 1              2           TA             10        Typ           0
# 2              1           Gd              7        Typ           1
# 3              1           TA              5        Typ           0
# 4              1           TA              6        Typ           2
#
#   fireplace_qu garage_type  garage_yr_blt garage_finish  garage_cars  \
# 0          NaN      Detchd         1910.0           Unf            1
# 1          NaN      Attchd         1977.0           Fin            2
# 2           Gd      Attchd         2006.0           RFn            2
# 3          NaN      Detchd         1935.0           Unf            2
# 4           Gd      Attchd         1963.0           RFn            2
#
#    garage_area garage_qual garage_cond paved_drive  wood_deck_sf  \
# 0          440          Po          Po           Y             0
# 1          580          TA          TA           Y           170
# 2          426          TA          TA           Y           100
# 3          480          Fa          TA           N             0
# 4          514          TA          TA           Y             0
#
#    open_porch_sf  enclosed_porch  3ssn_porch  screen_porch  pool_area pool_qc  \
# 0             60             112           0             0          0     NaN
# 1              0               0           0             0          0     NaN
# 2             24               0           0             0          0     NaN
# 3              0             184           0             0          0     NaN
# 4             76               0           0           185          0     NaN
#
#   fence misc_feature  misc_val  mo_sold  yr_sold sale_type
# 0   NaN          NaN         0        4     2006       WD
# 1   NaN          NaN         0        8     2006       WD
# 2   NaN          NaN         0        9     2006       New
# 3   NaN          NaN         0        7     2007       WD
# 4   NaN          NaN         0        7     2009       WD

# %%
ames_train[ames_train.duplicated()]
# Out:
# Empty DataFrame
# Columns: [id, pid, ms_subclass, ms_zoning, lot_frontage, lot_area, street, alley, lot_shape, land_contour, utilities, lot_config, land_slope, neighborhood, condition_1, condition_2, bldg_type, house_style, overall_qual, overall_cond, year_built, year_remod/add, roof_style, roof_matl, exterior_1st, exterior_2nd, mas_vnr_type, mas_vnr_area, exter_qual, exter_cond, foundation, bsmt_qual, bsmt_cond, bsmt_exposure, bsmtfin_type_1, bsmtfin_sf_1, bsmtfin_type_2, bsmtfin_sf_2, bsmt_unf_sf, total_bsmt_sf, heating, heating_qc, central_air, electrical, 1st_flr_sf, 2nd_flr_sf, low_qual_fin_sf, gr_liv_area, bsmt_full_bath, bsmt_half_bath, full_bath, half_bath, bedroom_abvgr, kitchen_abvgr, kitchen_qual, totrms_abvgrd, functional, fireplaces, fireplace_qu, garage_type, garage_yr_blt, garage_finish, garage_cars, garage_area, garage_qual, garage_cond, paved_drive, wood_deck_sf, open_porch_sf, enclosed_porch, 3ssn_porch, screen_porch, pool_area, pool_qc, fence, misc_feature, misc_val, mo_sold, yr_sold, sale_type, saleprice]
# Index: []

# %%
# Checking which column with at least one null
ames_train.isnull().sum()[ames_train.isnull().sum()>0]
# Out:
# lot_frontage       330
# alley             1911
# mas_vnr_type        22
# mas_vnr_area        22
# bsmt_qual           55
# bsmt_cond           55
# bsmt_exposure       58
# bsmtfin_type_1      55
# bsmtfin_sf_1         1
# bsmtfin_type_2      56
# bsmtfin_sf_2         1
# bsmt_unf_sf          1
# total_bsmt_sf        1
# bsmt_full_bath       2
# bsmt_half_bath       2
# fireplace_qu      1000
# garage_type        113
# garage_yr_blt      114
# garage_finish      114
# garage_cars          1
# garage_area          1
# garage_qual        114
# garage_cond        114
# pool_qc           2042
# fence             1651
# misc_feature      1986
# dtype: int64

# %%
ames_test.isnull().sum()[ames_test.isnull().sum()>0]
# Out:
# lot_frontage      160
# alley             820
# mas_vnr_type        1
# mas_vnr_area        1
# bsmt_qual          25
# bsmt_cond          25
# bsmt_exposure      25
# bsmtfin_type_1     25
# bsmtfin_type_2     25
# electrical          1
# fireplace_qu      422
# garage_type        44
# garage_yr_blt      45
# garage_finish      45
# garage_qual        45
# garage_cond        45
# pool_qc           874
# fence             706
# misc_feature      837
# dtype: int64

# %% [markdown]
# Based on the intial null finding, can deduce that pool qc are not significant enough due to too little data and. Therefore, pool qc and pool area will be drop.

# %%
ames_train1 = ames_train.drop(columns=['pool_qc','pool_area'])

# %%
# Removing outliers as suggested by http://jse.amstat.org/v19n3/decock/DataDocumentation.txt 
sns.pairplot(ames_train1,y_vars = ['gr_liv_area'], x_vars = ['saleprice']);
ames_train1[ames_train1['gr_liv_area']>3999]
# Out:
#         id        pid  ms_subclass ms_zoning  lot_frontage  lot_area street  \
# 960   1499  908154235           60        RL         313.0     63887   Pave
# 1885  2181  908154195           20        RL         128.0     39290   Pave
#
#      alley lot_shape land_contour utilities lot_config land_slope  \
# 960    NaN       IR3          Bnk    AllPub     Corner        Gtl
# 1885   NaN       IR1          Bnk    AllPub     Inside        Gtl
#
#      neighborhood condition_1 condition_2 bldg_type house_style  overall_qual  \
# 960       Edwards       Feedr        Norm      1Fam      2Story            10
# 1885      Edwards        Norm        Norm      1Fam      1Story            10
#
#       overall_cond  year_built  year_remod/add roof_style roof_matl  \
# 960              5        2008            2008        Hip   ClyTile
# 1885             5        2008            2009        Hip   CompShg
#
#      exterior_1st exterior_2nd mas_vnr_type  mas_vnr_area exter_qual  \
# 960        Stucco       Stucco        Stone         796.0         Ex
# 1885      CemntBd      CmentBd        Stone        1224.0         Ex
#
#      exter_cond foundation bsmt_qual bsmt_cond bsmt_exposure bsmtfin_type_1  \
# 960          TA      PConc        Ex        TA            Gd            GLQ
# 1885         TA      PConc        Ex        TA            Gd            GLQ
#
#       bsmtfin_sf_1 bsmtfin_type_2  bsmtfin_sf_2  bsmt_unf_sf  total_bsmt_sf  \
# 960         5644.0            Unf           0.0        466.0         6110.0
# 1885        4010.0            Unf           0.0       1085.0         5095.0
#
#      heating heating_qc central_air electrical  1st_flr_sf  2nd_flr_sf  \
# 960     GasA         Ex           Y      SBrkr        4692         950
# 1885    GasA         Ex           Y      SBrkr        5095           0
#
#       low_qual_fin_sf  gr_liv_area  bsmt_full_bath  bsmt_half_bath  full_bath  \
# 960                 0         5642             2.0             0.0          2
# 1885                0         5095             1.0             1.0          2
#
#       half_bath  bedroom_abvgr  kitchen_abvgr kitchen_qual  totrms_abvgrd  \
# 960           1              3              1           Ex             12
# 1885          1              2              1           Ex             15
#
#      functional  fireplaces fireplace_qu garage_type  garage_yr_blt  \
# 960         Typ           3           Gd      Attchd         2008.0
# 1885        Typ           2           Gd      Attchd         2008.0
#
#      garage_finish  garage_cars  garage_area garage_qual garage_cond  \
# 960            Fin          2.0       1418.0          TA          TA
# 1885           Fin          3.0       1154.0          TA          TA
#
#      paved_drive  wood_deck_sf  open_porch_sf  enclosed_porch  3ssn_porch  \
# 960            Y           214            292               0           0
# 1885           Y           546            484               0           0
#
#       screen_porch fence misc_feature  misc_val  mo_sold  yr_sold sale_type  \
# 960              0   NaN          NaN         0        1     2008       New
# 1885             0   NaN         Elev     17000       10     2007       New
#
#       saleprice
# 960      160000
# 1885     183850

# %%
ames_train2 = ames_train1[ames_train1['gr_liv_area']<4000]
ames_train2
# Out:
#         id        pid  ms_subclass ms_zoning  lot_frontage  lot_area street  \
# 0      109  533352170           60        RL           NaN     13517   Pave
# 1      544  531379050           60        RL          43.0     11492   Pave
# 2      153  535304180           20        RL          68.0      7922   Pave
# 3      318  916386060           60        RL          73.0      9802   Pave
# 4      255  906425045           50        RL          82.0     14235   Pave
# ...    ...        ...          ...       ...           ...       ...    ...
# 2046  1587  921126030           20        RL          79.0     11449   Pave
# 2047   785  905377130           30        RL           NaN     12342   Pave
# 2048   916  909253010           50        RL          57.0      7558   Pave
# 2049   639  535179160           20        RL          80.0     10400   Pave
# 2050    10  527162130           60        RL          60.0      7500   Pave
#
#      alley lot_shape land_contour utilities lot_config land_slope  \
# 0      NaN       IR1          Lvl    AllPub    CulDSac        Gtl
# 1      NaN       IR1          Lvl    AllPub    CulDSac        Gtl
# 2      NaN       Reg          Lvl    AllPub     Inside        Gtl
# 3      NaN       Reg          Lvl    AllPub     Inside        Gtl
# 4      NaN       IR1          Lvl    AllPub     Inside        Gtl
# ...    ...       ...          ...       ...        ...        ...
# 2046   NaN       IR1          HLS    AllPub     Inside        Gtl
# 2047   NaN       IR1          Lvl    AllPub     Inside        Gtl
# 2048   NaN       Reg          Bnk    AllPub     Inside        Gtl
# 2049   NaN       Reg          Lvl    AllPub     Corner        Gtl
# 2050   NaN       Reg          Lvl    AllPub     Inside        Gtl
#
#      neighborhood condition_1 condition_2 bldg_type house_style  overall_qual  \
# 0          Sawyer        RRAe        Norm      1Fam      2Story             6
# 1         SawyerW        Norm        Norm      1Fam      2Story             7
# 2           NAmes        Norm        Norm      1Fam      1Story             5
# 3          Timber        Norm        Norm      1Fam      2Story             5
# 4         SawyerW        Norm        Norm      1Fam      1.5Fin             6
# ...           ...         ...         ...       ...         ...           ...
# 2046       Timber        Norm        Norm      1Fam      1Story             8
# 2047      Edwards        Norm        Norm      1Fam      1Story             4
# 2048      Crawfor        Norm        Norm      1Fam      1.5Fin             6
# 2049        NAmes        Norm        Norm      1Fam      1Story             4
# 2050      Gilbert        Norm        Norm      1Fam      2Story             7
#
#       overall_cond  year_built  year_remod/add roof_style roof_matl  \
# 0                8        1976            2005      Gable   CompShg
# 1                5        1996            1997      Gable   CompShg
# 2                7        1953            2007      Gable   CompShg
# 3                5        2006            2007      Gable   CompShg
# 4                8        1900            1993      Gable   CompShg
# ...            ...         ...             ...        ...       ...
# 2046             5        2007            2007      Gable   CompShg
# 2047             5        1940            1950      Gable   CompShg
# 2048             6        1928            1950      Gable   CompShg
# 2049             5        1956            1956      Gable   CompShg
# 2050             5        1999            1999      Gable   CompShg
#
#      exterior_1st exterior_2nd mas_vnr_type  mas_vnr_area exter_qual  \
# 0         HdBoard      Plywood      BrkFace         289.0         Gd
# 1         VinylSd      VinylSd      BrkFace         132.0         Gd
# 2         VinylSd      VinylSd         None           0.0         TA
# 3         VinylSd      VinylSd         None           0.0         TA
# 4         Wd Sdng      Plywood         None           0.0         TA
# ...           ...          ...          ...           ...        ...
# 2046      VinylSd      VinylSd         None           0.0         Gd
# 2047      VinylSd      VinylSd         None           0.0         TA
# 2048      BrkFace        Stone         None           0.0         TA
# 2049      Plywood      Plywood         None           0.0         TA
# 2050      VinylSd      VinylSd         None           0.0         TA
#
#      exter_cond foundation bsmt_qual bsmt_cond bsmt_exposure bsmtfin_type_1  \
# 0            TA     CBlock        TA        TA            No            GLQ
# 1            TA      PConc        Gd        TA            No            GLQ
# 2            Gd     CBlock        TA        TA            No            GLQ
# 3            TA      PConc        Gd        TA            No            Unf
# 4            TA      PConc        Fa        Gd            No            Unf
# ...         ...        ...       ...       ...           ...            ...
# 2046         TA      PConc        Gd        TA            Av            GLQ
# 2047         TA     CBlock        TA        TA            No            BLQ
# 2048         TA     BrkTil        TA        TA            No            Unf
# 2049         TA     CBlock        TA        TA            No            Rec
# 2050         TA      PConc        TA        TA            No            Unf
#
#       bsmtfin_sf_1 bsmtfin_type_2  bsmtfin_sf_2  bsmt_unf_sf  total_bsmt_sf  \
# 0            533.0            Unf           0.0        192.0          725.0
# 1            637.0            Unf           0.0        276.0          913.0
# 2            731.0            Unf           0.0        326.0         1057.0
# 3              0.0            Unf           0.0        384.0          384.0
# 4              0.0            Unf           0.0        676.0          676.0
# ...            ...            ...           ...          ...            ...
# 2046        1011.0            Unf           0.0        873.0         1884.0
# 2047         262.0            Unf           0.0        599.0          861.0
# 2048           0.0            Unf           0.0        896.0          896.0
# 2049         155.0            LwQ         750.0        295.0         1200.0
# 2050           0.0            Unf           0.0        994.0          994.0
#
#      heating heating_qc central_air electrical  1st_flr_sf  2nd_flr_sf  \
# 0       GasA         Ex           Y      SBrkr         725         754
# 1       GasA         Ex           Y      SBrkr         913        1209
# 2       GasA         TA           Y      SBrkr        1057           0
# 3       GasA         Gd           Y      SBrkr         744         700
# 4       GasA         TA           Y      SBrkr         831         614
# ...      ...        ...         ...        ...         ...         ...
# 2046    GasA         Ex           Y      SBrkr        1728           0
# 2047    GasA         Ex           Y      SBrkr         861           0
# 2048    GasA         Gd           Y      SBrkr        1172         741
# 2049    GasA         TA           Y      SBrkr        1200           0
# 2050    GasA         Gd           Y      SBrkr        1028         776
#
#       low_qual_fin_sf  gr_liv_area  bsmt_full_bath  bsmt_half_bath  full_bath  \
# 0                   0         1479             0.0             0.0          2
# 1                   0         2122             1.0             0.0          2
# 2                   0         1057             1.0             0.0          1
# 3                   0         1444             0.0             0.0          2
# 4                   0         1445             0.0             0.0          2
# ...               ...          ...             ...             ...        ...
# 2046                0         1728             1.0             0.0          2
# 2047                0          861             0.0             0.0          1
# 2048                0         1913             0.0             0.0          1
# 2049                0         1200             1.0             0.0          1
# 2050                0         1804             0.0             0.0          2
#
#       half_bath  bedroom_abvgr  kitchen_abvgr kitchen_qual  totrms_abvgrd  \
# 0             1              3              1           Gd              6
# 1             1              4              1           Gd              8
# 2             0              3              1           Gd              5
# 3             1              3              1           TA              7
# 4             0              3              1           TA              6
# ...         ...            ...            ...          ...            ...
# 2046          0              3              1           Gd              7
# 2047          0              1              1           TA              4
# 2048          1              3              1           TA              9
# 2049          0              3              1           TA              6
# 2050          1              3              1           Gd              7
#
#      functional  fireplaces fireplace_qu garage_type  garage_yr_blt  \
# 0           Typ           0          NaN      Attchd         1976.0
# 1           Typ           1           TA      Attchd         1997.0
# 2           Typ           0          NaN      Detchd         1953.0
# 3           Typ           0          NaN     BuiltIn         2007.0
# 4           Typ           0          NaN      Detchd         1957.0
# ...         ...         ...          ...         ...            ...
# 2046        Typ           1           Gd      Attchd         2007.0
# 2047        Typ           0          NaN      Detchd         1961.0
# 2048        Typ           1           TA      Detchd         1929.0
# 2049        Typ           2           Gd      Attchd         1956.0
# 2050        Typ           1           TA      Attchd         1999.0
#
#      garage_finish  garage_cars  garage_area garage_qual garage_cond  \
# 0              RFn          2.0        475.0          TA          TA
# 1              RFn          2.0        559.0          TA          TA
# 2              Unf          1.0        246.0          TA          TA
# 3              Fin          2.0        400.0          TA          TA
# 4              Unf          2.0        484.0          TA          TA
# ...            ...          ...          ...         ...         ...
# 2046           Fin          2.0        520.0          TA          TA
# 2047           Unf          2.0        539.0          TA          TA
# 2048           Unf          2.0        342.0          Fa          Fa
# 2049           Unf          1.0        294.0          TA          TA
# 2050           Fin          2.0        442.0          TA          TA
#
#      paved_drive  wood_deck_sf  open_porch_sf  enclosed_porch  3ssn_porch  \
# 0              Y             0             44               0           0
# 1              Y             0             74               0           0
# 2              Y             0             52               0           0
# 3              Y           100              0               0           0
# 4              N             0             59               0           0
# ...          ...           ...            ...             ...         ...
# 2046           Y             0            276               0           0
# 2047           Y           158              0               0           0
# 2048           Y             0              0               0           0
# 2049           Y             0            189             140           0
# 2050           Y           140             60               0           0
#
#       screen_porch fence misc_feature  misc_val  mo_sold  yr_sold sale_type  \
# 0                0   NaN          NaN         0        3     2010       WD
# 1                0   NaN          NaN         0        4     2009       WD
# 2                0   NaN          NaN         0        1     2010       WD
# 3                0   NaN          NaN         0        4     2010       WD
# 4                0   NaN          NaN         0        3     2010       WD
# ...            ...   ...          ...       ...      ...      ...       ...
# 2046             0   NaN          NaN         0        1     2008       WD
# 2047             0   NaN          NaN         0        3     2009       WD
# 2048             0   NaN          NaN         0        3     2009       WD
# 2049             0   NaN          NaN         0       11     2009       WD
# 2050             0   NaN          NaN         0        6     2010       WD
#
#       saleprice
# 0        130500
# 1        220000
# 2        109000
# 3        174000
# 4        138500
# ...         ...
# 2046     298751
# 2047      82500
# 2048     177000
# 2049     144000
# 2050     189000
#
# [2049 rows x 79 columns]

# %%
ames_train2.isnull().sum()[ames_train2.isnull().sum()>0]
# Out:
# lot_frontage       330
# alley             1909
# mas_vnr_type        22
# mas_vnr_area        22
# bsmt_qual           55
# bsmt_cond           55
# bsmt_exposure       58
# bsmtfin_type_1      55
# bsmtfin_sf_1         1
# bsmtfin_type_2      56
# bsmtfin_sf_2         1
# bsmt_unf_sf          1
# total_bsmt_sf        1
# bsmt_full_bath       2
# bsmt_half_bath       2
# fireplace_qu      1000
# garage_type        113
# garage_yr_blt      114
# garage_finish      114
# garage_cars          1
# garage_area          1
# garage_qual        114
# garage_cond        114
# fence             1649
# misc_feature      1985
# dtype: int64

# %% [markdown]
# Since there is only 22 of null values in Mas Vnr Type and Mas Vnr Area, we can drop those rows with null values

# %%
ames_train3 = ames_train2

# %%
ames_train3 = ames_train3[ames_train3['mas_vnr_area'].notna()]
ames_train3 = ames_train3[ames_train3['mas_vnr_type'].notna()]

# %%
ames_train3.isnull().sum()[ames_train2.isnull().sum()>0]
# Out:
# lot_frontage       324
# alley             1889
# mas_vnr_type         0
# mas_vnr_area         0
# bsmt_qual           55
# bsmt_cond           55
# bsmt_exposure       58
# bsmtfin_type_1      55
# bsmtfin_sf_1         1
# bsmtfin_type_2      56
# bsmtfin_sf_2         1
# bsmt_unf_sf          1
# total_bsmt_sf        1
# bsmt_full_bath       2
# bsmt_half_bath       2
# fireplace_qu       992
# garage_type        112
# garage_yr_blt      113
# garage_finish      113
# garage_cars          1
# garage_area          1
# garage_qual        113
# garage_cond        113
# fence             1627
# misc_feature      1963
# dtype: int64

# %%
# Fill frontage null data with 0 instead of just blank
ames_train3['lot_frontage'] = ames_train3['lot_frontage'].fillna(0)

# %%
ames_train3.isnull().sum()[ames_train3.isnull().sum()>0]
# Out:
# alley             1889
# bsmt_qual           55
# bsmt_cond           55
# bsmt_exposure       58
# bsmtfin_type_1      55
# bsmtfin_sf_1         1
# bsmtfin_type_2      56
# bsmtfin_sf_2         1
# bsmt_unf_sf          1
# total_bsmt_sf        1
# bsmt_full_bath       2
# bsmt_half_bath       2
# fireplace_qu       992
# garage_type        112
# garage_yr_blt      113
# garage_finish      113
# garage_cars          1
# garage_area          1
# garage_qual        113
# garage_cond        113
# fence             1627
# misc_feature      1963
# dtype: int64

# %%
ames_train4 = ames_train3

# %%
# Regarding that no basement is equal as null 
ames_train4['bsmt_qual'].fillna('None', inplace=True)
ames_train4['bsmt_cond'].fillna('None', inplace=True)
ames_train4['bsmt_exposure'].fillna('None', inplace=True)
ames_train4['bsmtfin_type_1'].fillna('None', inplace=True)
ames_train4['bsmtfin_type_2'].fillna('None', inplace=True)

# %%
ames_train4.isnull().sum()[ames_train4.isnull().sum()>0]
# Out:
# alley             1889
# bsmtfin_sf_1         1
# bsmtfin_sf_2         1
# bsmt_unf_sf          1
# total_bsmt_sf        1
# bsmt_full_bath       2
# bsmt_half_bath       2
# fireplace_qu       992
# garage_type        112
# garage_yr_blt      113
# garage_finish      113
# garage_cars          1
# garage_area          1
# garage_qual        113
# garage_cond        113
# fence             1627
# misc_feature      1963
# dtype: int64

# %%
ames_train4['alley'].fillna('None', inplace=True)
ames_train4['fireplace_qu'].fillna('None', inplace=True)

# %%
ames_train4.isnull().sum()[ames_train4.isnull().sum()>0]
# Out:
# bsmtfin_sf_1         1
# bsmtfin_sf_2         1
# bsmt_unf_sf          1
# total_bsmt_sf        1
# bsmt_full_bath       2
# bsmt_half_bath       2
# garage_type        112
# garage_yr_blt      113
# garage_finish      113
# garage_cars          1
# garage_area          1
# garage_qual        113
# garage_cond        113
# fence             1627
# misc_feature      1963
# dtype: int64

# %%
ames_train4['bsmtfin_sf_1'] = ames_train4['bsmtfin_sf_1'].fillna(0)
ames_train4['bsmtfin_sf_2'] = ames_train4['bsmtfin_sf_2'].fillna(0)
ames_train4['bsmt_unf_sf'] = ames_train4['bsmt_unf_sf'].fillna(0)
ames_train4['total_bsmt_sf'] = ames_train4['total_bsmt_sf'].fillna(0)

# %%
ames_train4.isnull().sum()[ames_train4.isnull().sum()>0]
# Out:
# bsmt_full_bath       2
# bsmt_half_bath       2
# garage_type        112
# garage_yr_blt      113
# garage_finish      113
# garage_cars          1
# garage_area          1
# garage_qual        113
# garage_cond        113
# fence             1627
# misc_feature      1963
# dtype: int64

# %%
ames_train4.dropna(subset = ['bsmt_full_bath'], inplace=True)
ames_train4.dropna(subset = ['bsmt_half_bath'], inplace=True)

# %%
ames_train4.isnull().sum()[ames_train4.isnull().sum()>0]
# Out:
# garage_type       112
# garage_yr_blt     113
# garage_finish     113
# garage_cars         1
# garage_area         1
# garage_qual       113
# garage_cond       113
# fence            1626
# misc_feature     1961
# dtype: int64

# %%
ames_train5 = ames_train4

# %%
ames_train5['garage_type'].fillna('None', inplace=True)
ames_train5['garage_yr_blt'].fillna('None', inplace=True)
ames_train5['garage_finish'].fillna('None', inplace=True)
ames_train5['garage_qual'].fillna('None', inplace=True)
ames_train5['garage_cond'].fillna('None', inplace=True)
ames_train5['fence'].fillna('None', inplace=True)
ames_train5['misc_feature'].fillna('None', inplace=True)

# %%
ames_train.dtypes
# Out:
# id                   int64
# pid                  int64
# ms_subclass          int64
# ms_zoning           object
# lot_frontage       float64
# lot_area             int64
# street              object
# alley               object
# lot_shape           object
# land_contour        object
# utilities           object
# lot_config          object
# land_slope          object
# neighborhood        object
# condition_1         object
# condition_2         object
# bldg_type           object
# house_style         object
# overall_qual         int64
# overall_cond         int64
# year_built           int64
# year_remod/add       int64
# roof_style          object
# roof_matl           object
# exterior_1st        object
# exterior_2nd        object
# mas_vnr_type        object
# mas_vnr_area       float64
# exter_qual          object
# exter_cond          object
# foundation          object
# bsmt_qual           object
# bsmt_cond           object
# bsmt_exposure       object
# bsmtfin_type_1      object
# bsmtfin_sf_1       float64
# bsmtfin_type_2      object
# bsmtfin_sf_2       float64
# bsmt_unf_sf        float64
# total_bsmt_sf      float64
# heating             object
# heating_qc          object
# central_air         object
# electrical          object
# 1st_flr_sf           int64
# 2nd_flr_sf           int64
# low_qual_fin_sf      int64
# gr_liv_area          int64
# bsmt_full_bath     float64
# bsmt_half_bath     float64
# full_bath            int64
# half_bath            int64
# bedroom_abvgr        int64
# kitchen_abvgr        int64
# kitchen_qual        object
# totrms_abvgrd        int64
# functional          object
# fireplaces           int64
# fireplace_qu        object
# garage_type         object
# garage_yr_blt      float64
# garage_finish       object
# garage_cars        float64
# garage_area        float64
# garage_qual         object
# garage_cond         object
# paved_drive         object
# wood_deck_sf         int64
# open_porch_sf        int64
# enclosed_porch       int64
# 3ssn_porch           int64
# screen_porch         int64
# pool_area            int64
# pool_qc             object
# fence               object
# misc_feature        object
# misc_val             int64
# mo_sold              int64
# yr_sold              int64
# sale_type           object
# saleprice            int64
# dtype: object

# %%
ames_train5.dropna(subset = ['garage_cars'], inplace=True)
ames_train5.dropna(subset = ['garage_area'], inplace=True)

# %%
ames_train5.isnull().sum()[ames_train5.isnull().sum()>0]
# Out:
# Series([], dtype: int64)

# %%
ames_train5.to_csv('../datasets/ames_train5.csv')

# %% [markdown]
# * ames_train5 = train dataset with all relevant null rows
# * Now that we have clean the null values, we will tackle the categorial features.

# %%
ames_train5
# Out:
#         id        pid  ms_subclass ms_zoning  lot_frontage  lot_area street  \
# 0      109  533352170           60        RL           0.0     13517   Pave
# 1      544  531379050           60        RL          43.0     11492   Pave
# 2      153  535304180           20        RL          68.0      7922   Pave
# 3      318  916386060           60        RL          73.0      9802   Pave
# 4      255  906425045           50        RL          82.0     14235   Pave
# ...    ...        ...          ...       ...           ...       ...    ...
# 2046  1587  921126030           20        RL          79.0     11449   Pave
# 2047   785  905377130           30        RL           0.0     12342   Pave
# 2048   916  909253010           50        RL          57.0      7558   Pave
# 2049   639  535179160           20        RL          80.0     10400   Pave
# 2050    10  527162130           60        RL          60.0      7500   Pave
#
#      alley lot_shape land_contour utilities lot_config land_slope  \
# 0     None       IR1          Lvl    AllPub    CulDSac        Gtl
# 1     None       IR1          Lvl    AllPub    CulDSac        Gtl
# 2     None       Reg          Lvl    AllPub     Inside        Gtl
# 3     None       Reg          Lvl    AllPub     Inside        Gtl
# 4     None       IR1          Lvl    AllPub     Inside        Gtl
# ...    ...       ...          ...       ...        ...        ...
# 2046  None       IR1          HLS    AllPub     Inside        Gtl
# 2047  None       IR1          Lvl    AllPub     Inside        Gtl
# 2048  None       Reg          Bnk    AllPub     Inside        Gtl
# 2049  None       Reg          Lvl    AllPub     Corner        Gtl
# 2050  None       Reg          Lvl    AllPub     Inside        Gtl
#
#      neighborhood condition_1 condition_2 bldg_type house_style  overall_qual  \
# 0          Sawyer        RRAe        Norm      1Fam      2Story             6
# 1         SawyerW        Norm        Norm      1Fam      2Story             7
# 2           NAmes        Norm        Norm      1Fam      1Story             5
# 3          Timber        Norm        Norm      1Fam      2Story             5
# 4         SawyerW        Norm        Norm      1Fam      1.5Fin             6
# ...           ...         ...         ...       ...         ...           ...
# 2046       Timber        Norm        Norm      1Fam      1Story             8
# 2047      Edwards        Norm        Norm      1Fam      1Story             4
# 2048      Crawfor        Norm        Norm      1Fam      1.5Fin             6
# 2049        NAmes        Norm        Norm      1Fam      1Story             4
# 2050      Gilbert        Norm        Norm      1Fam      2Story             7
#
#       overall_cond  year_built  year_remod/add roof_style roof_matl  \
# 0                8        1976            2005      Gable   CompShg
# 1                5        1996            1997      Gable   CompShg
# 2                7        1953            2007      Gable   CompShg
# 3                5        2006            2007      Gable   CompShg
# 4                8        1900            1993      Gable   CompShg
# ...            ...         ...             ...        ...       ...
# 2046             5        2007            2007      Gable   CompShg
# 2047             5        1940            1950      Gable   CompShg
# 2048             6        1928            1950      Gable   CompShg
# 2049             5        1956            1956      Gable   CompShg
# 2050             5        1999            1999      Gable   CompShg
#
#      exterior_1st exterior_2nd mas_vnr_type  mas_vnr_area exter_qual  \
# 0         HdBoard      Plywood      BrkFace         289.0         Gd
# 1         VinylSd      VinylSd      BrkFace         132.0         Gd
# 2         VinylSd      VinylSd         None           0.0         TA
# 3         VinylSd      VinylSd         None           0.0         TA
# 4         Wd Sdng      Plywood         None           0.0         TA
# ...           ...          ...          ...           ...        ...
# 2046      VinylSd      VinylSd         None           0.0         Gd
# 2047      VinylSd      VinylSd         None           0.0         TA
# 2048      BrkFace        Stone         None           0.0         TA
# 2049      Plywood      Plywood         None           0.0         TA
# 2050      VinylSd      VinylSd         None           0.0         TA
#
#      exter_cond foundation bsmt_qual bsmt_cond bsmt_exposure bsmtfin_type_1  \
# 0            TA     CBlock        TA        TA            No            GLQ
# 1            TA      PConc        Gd        TA            No            GLQ
# 2            Gd     CBlock        TA        TA            No            GLQ
# 3            TA      PConc        Gd        TA            No            Unf
# 4            TA      PConc        Fa        Gd            No            Unf
# ...         ...        ...       ...       ...           ...            ...
# 2046         TA      PConc        Gd        TA            Av            GLQ
# 2047         TA     CBlock        TA        TA            No            BLQ
# 2048         TA     BrkTil        TA        TA            No            Unf
# 2049         TA     CBlock        TA        TA            No            Rec
# 2050         TA      PConc        TA        TA            No            Unf
#
#       bsmtfin_sf_1 bsmtfin_type_2  bsmtfin_sf_2  bsmt_unf_sf  total_bsmt_sf  \
# 0            533.0            Unf           0.0        192.0          725.0
# 1            637.0            Unf           0.0        276.0          913.0
# 2            731.0            Unf           0.0        326.0         1057.0
# 3              0.0            Unf           0.0        384.0          384.0
# 4              0.0            Unf           0.0        676.0          676.0
# ...            ...            ...           ...          ...            ...
# 2046        1011.0            Unf           0.0        873.0         1884.0
# 2047         262.0            Unf           0.0        599.0          861.0
# 2048           0.0            Unf           0.0        896.0          896.0
# 2049         155.0            LwQ         750.0        295.0         1200.0
# 2050           0.0            Unf           0.0        994.0          994.0
#
#      heating heating_qc central_air electrical  1st_flr_sf  2nd_flr_sf  \
# 0       GasA         Ex           Y      SBrkr         725         754
# 1       GasA         Ex           Y      SBrkr         913        1209
# 2       GasA         TA           Y      SBrkr        1057           0
# 3       GasA         Gd           Y      SBrkr         744         700
# 4       GasA         TA           Y      SBrkr         831         614
# ...      ...        ...         ...        ...         ...         ...
# 2046    GasA         Ex           Y      SBrkr        1728           0
# 2047    GasA         Ex           Y      SBrkr         861           0
# 2048    GasA         Gd           Y      SBrkr        1172         741
# 2049    GasA         TA           Y      SBrkr        1200           0
# 2050    GasA         Gd           Y      SBrkr        1028         776
#
#       low_qual_fin_sf  gr_liv_area  bsmt_full_bath  bsmt_half_bath  full_bath  \
# 0                   0         1479             0.0             0.0          2
# 1                   0         2122             1.0             0.0          2
# 2                   0         1057             1.0             0.0          1
# 3                   0         1444             0.0             0.0          2
# 4                   0         1445             0.0             0.0          2
# ...               ...          ...             ...             ...        ...
# 2046                0         1728             1.0             0.0          2
# 2047                0          861             0.0             0.0          1
# 2048                0         1913             0.0             0.0          1
# 2049                0         1200             1.0             0.0          1
# 2050                0         1804             0.0             0.0          2
#
#       half_bath  bedroom_abvgr  kitchen_abvgr kitchen_qual  totrms_abvgrd  \
# 0             1              3              1           Gd              6
# 1             1              4              1           Gd              8
# 2             0              3              1           Gd              5
# 3             1              3              1           TA              7
# 4             0              3              1           TA              6
# ...         ...            ...            ...          ...            ...
# 2046          0              3              1           Gd              7
# 2047          0              1              1           TA              4
# 2048          1              3              1           TA              9
# 2049          0              3              1           TA              6
# 2050          1              3              1           Gd              7
#
#      functional  fireplaces fireplace_qu garage_type garage_yr_blt  \
# 0           Typ           0         None      Attchd        1976.0
# 1           Typ           1           TA      Attchd        1997.0
# 2           Typ           0         None      Detchd        1953.0
# 3           Typ           0         None     BuiltIn        2007.0
# 4           Typ           0         None      Detchd        1957.0
# ...         ...         ...          ...         ...           ...
# 2046        Typ           1           Gd      Attchd        2007.0
# 2047        Typ           0         None      Detchd        1961.0
# 2048        Typ           1           TA      Detchd        1929.0
# 2049        Typ           2           Gd      Attchd        1956.0
# 2050        Typ           1           TA      Attchd        1999.0
#
#      garage_finish  garage_cars  garage_area garage_qual garage_cond  \
# 0              RFn          2.0        475.0          TA          TA
# 1              RFn          2.0        559.0          TA          TA
# 2              Unf          1.0        246.0          TA          TA
# 3              Fin          2.0        400.0          TA          TA
# 4              Unf          2.0        484.0          TA          TA
# ...            ...          ...          ...         ...         ...
# 2046           Fin          2.0        520.0          TA          TA
# 2047           Unf          2.0        539.0          TA          TA
# 2048           Unf          2.0        342.0          Fa          Fa
# 2049           Unf          1.0        294.0          TA          TA
# 2050           Fin          2.0        442.0          TA          TA
#
#      paved_drive  wood_deck_sf  open_porch_sf  enclosed_porch  3ssn_porch  \
# 0              Y             0             44               0           0
# 1              Y             0             74               0           0
# 2              Y             0             52               0           0
# 3              Y           100              0               0           0
# 4              N             0             59               0           0
# ...          ...           ...            ...             ...         ...
# 2046           Y             0            276               0           0
# 2047           Y           158              0               0           0
# 2048           Y             0              0               0           0
# 2049           Y             0            189             140           0
# 2050           Y           140             60               0           0
#
#       screen_porch fence misc_feature  misc_val  mo_sold  yr_sold sale_type  \
# 0                0  None         None         0        3     2010       WD
# 1                0  None         None         0        4     2009       WD
# 2                0  None         None         0        1     2010       WD
# 3                0  None         None         0        4     2010       WD
# 4                0  None         None         0        3     2010       WD
# ...            ...   ...          ...       ...      ...      ...       ...
# 2046             0  None         None         0        1     2008       WD
# 2047             0  None         None         0        3     2009       WD
# 2048             0  None         None         0        3     2009       WD
# 2049             0  None         None         0       11     2009       WD
# 2050             0  None         None         0        6     2010       WD
#
#       saleprice
# 0        130500
# 1        220000
# 2        109000
# 3        174000
# 4        138500
# ...         ...
# 2046     298751
# 2047      82500
# 2048     177000
# 2049     144000
# 2050     189000
#
# [2024 rows x 79 columns]

# %%
ames_train5.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 2024 entries, 0 to 2050
# Data columns (total 79 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   id               2024 non-null   int64
#  1   pid              2024 non-null   int64
#  2   ms_subclass      2024 non-null   int64
#  3   ms_zoning        2024 non-null   object
#  4   lot_frontage     2024 non-null   float64
#  5   lot_area         2024 non-null   int64
#  6   street           2024 non-null   object
#  7   alley            2024 non-null   object
#  8   lot_shape        2024 non-null   object
#  9   land_contour     2024 non-null   object
#  10  utilities        2024 non-null   object
#  11  lot_config       2024 non-null   object
#  12  land_slope       2024 non-null   object
#  13  neighborhood     2024 non-null   object
#  14  condition_1      2024 non-null   object
#  15  condition_2      2024 non-null   object
#  16  bldg_type        2024 non-null   object
#  17  house_style      2024 non-null   object
#  18  overall_qual     2024 non-null   int64
#  19  overall_cond     2024 non-null   int64
#  20  year_built       2024 non-null   int64
#  21  year_remod/add   2024 non-null   int64
#  22  roof_style       2024 non-null   object
#  23  roof_matl        2024 non-null   object
#  24  exterior_1st     2024 non-null   object
#  25  exterior_2nd     2024 non-null   object
#  26  mas_vnr_type     2024 non-null   object
#  27  mas_vnr_area     2024 non-null   float64
#  28  exter_qual       2024 non-null   object
#  29  exter_cond       2024 non-null   object
#  30  foundation       2024 non-null   object
#  31  bsmt_qual        2024 non-null   object
#  32  bsmt_cond        2024 non-null   object
#  33  bsmt_exposure    2024 non-null   object
#  34  bsmtfin_type_1   2024 non-null   object
#  35  bsmtfin_sf_1     2024 non-null   float64
#  36  bsmtfin_type_2   2024 non-null   object
#  37  bsmtfin_sf_2     2024 non-null   float64
#  38  bsmt_unf_sf      2024 non-null   float64
#  39  total_bsmt_sf    2024 non-null   float64
#  40  heating          2024 non-null   object
#  41  heating_qc       2024 non-null   object
#  42  central_air      2024 non-null   object
#  43  electrical       2024 non-null   object
#  44  1st_flr_sf       2024 non-null   int64
#  45  2nd_flr_sf       2024 non-null   int64
#  46  low_qual_fin_sf  2024 non-null   int64
#  47  gr_liv_area      2024 non-null   int64
#  48  bsmt_full_bath   2024 non-null   float64
#  49  bsmt_half_bath   2024 non-null   float64
#  50  full_bath        2024 non-null   int64
#  51  half_bath        2024 non-null   int64
#  52  bedroom_abvgr    2024 non-null   int64
#  53  kitchen_abvgr    2024 non-null   int64
#  54  kitchen_qual     2024 non-null   object
#  55  totrms_abvgrd    2024 non-null   int64
#  56  functional       2024 non-null   object
#  57  fireplaces       2024 non-null   int64
#  58  fireplace_qu     2024 non-null   object
#  59  garage_type      2024 non-null   object
#  60  garage_yr_blt    2024 non-null   object
#  61  garage_finish    2024 non-null   object
#  62  garage_cars      2024 non-null   float64
#  63  garage_area      2024 non-null   float64
#  64  garage_qual      2024 non-null   object
#  65  garage_cond      2024 non-null   object
#  66  paved_drive      2024 non-null   object
#  67  wood_deck_sf     2024 non-null   int64
#  68  open_porch_sf    2024 non-null   int64
#  69  enclosed_porch   2024 non-null   int64
#  70  3ssn_porch       2024 non-null   int64
#  71  screen_porch     2024 non-null   int64
#  72  fence            2024 non-null   object
#  73  misc_feature     2024 non-null   object
#  74  misc_val         2024 non-null   int64
#  75  mo_sold          2024 non-null   int64
#  76  yr_sold          2024 non-null   int64
#  77  sale_type        2024 non-null   object
#  78  saleprice        2024 non-null   int64
# dtypes: float64(10), int64(27), object(42)
# memory usage: 1.2+ MB

# %%
ames_train6 = ames_train5

# %%
ames_train6['ms_zoning'].unique()
# Out:
# array(['RL', 'RM', 'FV', 'C (all)', 'A (agr)', 'RH', 'I (all)'],
#       dtype=object)

# %%
ames_train6['ms_zoning']= ames_train6['ms_zoning'].map({'A (agr)':1, 'C (all)': 2, 'FV': 3, 'I (all)': 4,'RH': 5, 'RL': 6,'RP': 7, 'RM': 8})

# %%
ames_train6['ms_zoning'].unique()
# Out:
# array([6, 8, 3, 2, 1, 5, 4])

# %%
ames_train6['street'].unique()
# Out:
# array(['Pave', 'Grvl'], dtype=object)

# %%
ames_train6['street'] = ames_train6['street'].map({'Pave': 1, 'Grvl':2})

# %%
ames_train6['street'].unique()
# Out:
# array([1, 2])

# %%
ames_train6['land_contour'].unique()
# Out:
# array(['Lvl', 'HLS', 'Bnk', 'Low'], dtype=object)

# %%
ames_train6['land_contour'] = ames_train6['land_contour'].map({'Lvl': 1, 'HLS':3, 'Bnk':2, 'Low':4})

# %%
ames_train6['land_contour'].unique()
# Out:
# array([1, 3, 2, 4])

# %%
ames_train6['utilities'].unique()
# Out:
# array(['AllPub', 'NoSeWa', 'NoSewr'], dtype=object)

# %%
ames_train6['utilities'] = ames_train6['utilities'].map({'AllPub': 1, 'NoSeWa':3, 'NoSewr':2, 'ELO':4})

# %%
ames_train6['utilities'].unique()
# Out:
# array([1, 3, 2])

# %%
ames_train6.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 2024 entries, 0 to 2050
# Data columns (total 79 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   id               2024 non-null   int64
#  1   pid              2024 non-null   int64
#  2   ms_subclass      2024 non-null   int64
#  3   ms_zoning        2024 non-null   int64
#  4   lot_frontage     2024 non-null   float64
#  5   lot_area         2024 non-null   int64
#  6   street           2024 non-null   int64
#  7   alley            2024 non-null   object
#  8   lot_shape        2024 non-null   object
#  9   land_contour     2024 non-null   int64
#  10  utilities        2024 non-null   int64
#  11  lot_config       2024 non-null   object
#  12  land_slope       2024 non-null   object
#  13  neighborhood     2024 non-null   object
#  14  condition_1      2024 non-null   object
#  15  condition_2      2024 non-null   object
#  16  bldg_type        2024 non-null   object
#  17  house_style      2024 non-null   object
#  18  overall_qual     2024 non-null   int64
#  19  overall_cond     2024 non-null   int64
#  20  year_built       2024 non-null   int64
#  21  year_remod/add   2024 non-null   int64
#  22  roof_style       2024 non-null   object
#  23  roof_matl        2024 non-null   object
#  24  exterior_1st     2024 non-null   object
#  25  exterior_2nd     2024 non-null   object
#  26  mas_vnr_type     2024 non-null   object
#  27  mas_vnr_area     2024 non-null   float64
#  28  exter_qual       2024 non-null   object
#  29  exter_cond       2024 non-null   object
#  30  foundation       2024 non-null   object
#  31  bsmt_qual        2024 non-null   object
#  32  bsmt_cond        2024 non-null   object
#  33  bsmt_exposure    2024 non-null   object
#  34  bsmtfin_type_1   2024 non-null   object
#  35  bsmtfin_sf_1     2024 non-null   float64
#  36  bsmtfin_type_2   2024 non-null   object
#  37  bsmtfin_sf_2     2024 non-null   float64
#  38  bsmt_unf_sf      2024 non-null   float64
#  39  total_bsmt_sf    2024 non-null   float64
#  40  heating          2024 non-null   object
#  41  heating_qc       2024 non-null   object
#  42  central_air      2024 non-null   object
#  43  electrical       2024 non-null   object
#  44  1st_flr_sf       2024 non-null   int64
#  45  2nd_flr_sf       2024 non-null   int64
#  46  low_qual_fin_sf  2024 non-null   int64
#  47  gr_liv_area      2024 non-null   int64
#  48  bsmt_full_bath   2024 non-null   float64
#  49  bsmt_half_bath   2024 non-null   float64
#  50  full_bath        2024 non-null   int64
#  51  half_bath        2024 non-null   int64
#  52  bedroom_abvgr    2024 non-null   int64
#  53  kitchen_abvgr    2024 non-null   int64
#  54  kitchen_qual     2024 non-null   object
#  55  totrms_abvgrd    2024 non-null   int64
#  56  functional       2024 non-null   object
#  57  fireplaces       2024 non-null   int64
#  58  fireplace_qu     2024 non-null   object
#  59  garage_type      2024 non-null   object
#  60  garage_yr_blt    2024 non-null   object
#  61  garage_finish    2024 non-null   object
#  62  garage_cars      2024 non-null   float64
#  63  garage_area      2024 non-null   float64
#  64  garage_qual      2024 non-null   object
#  65  garage_cond      2024 non-null   object
#  66  paved_drive      2024 non-null   object
#  67  wood_deck_sf     2024 non-null   int64
#  68  open_porch_sf    2024 non-null   int64
#  69  enclosed_porch   2024 non-null   int64
#  70  3ssn_porch       2024 non-null   int64
#  71  screen_porch     2024 non-null   int64
#  72  fence            2024 non-null   object
#  73  misc_feature     2024 non-null   object
#  74  misc_val         2024 non-null   int64
#  75  mo_sold          2024 non-null   int64
#  76  yr_sold          2024 non-null   int64
#  77  sale_type        2024 non-null   object
#  78  saleprice        2024 non-null   int64
# dtypes: float64(10), int64(31), object(38)
# memory usage: 1.2+ MB

# %%
ames_train6['lot_config'].unique()
# Out:
# array(['CulDSac', 'Inside', 'Corner', 'FR2', 'FR3'], dtype=object)

# %%
ames_train6['lot_config'] = ames_train6['lot_config'].map({'CulDSac': 3, 'Inside':1, 'Corner':2, 'FR2':4, 'FR3':5})

# %%
ames_train6['lot_config'].unique()
# Out:
# array([3, 1, 2, 4, 5])

# %%
ames_train6['land_slope'].unique()
# Out:
# array(['Gtl', 'Sev', 'Mod'], dtype=object)

# %%
ames_train6['land_slope'] = ames_train6['land_slope'].map({'Gtl': 1, 'Sev':3, 'Mod':2})

# %%
ames_train6['land_slope'].unique()
# Out:
# array([1, 3, 2])

# %%
ames_train6['neighborhood'].unique()
# Out:
# array(['Sawyer', 'SawyerW', 'NAmes', 'Timber', 'Edwards', 'OldTown',
#        'BrDale', 'CollgCr', 'Somerst', 'Mitchel', 'StoneBr', 'Gilbert',
#        'Crawfor', 'IDOTRR', 'NWAmes', 'Veenker', 'MeadowV', 'NridgHt',
#        'SWISU', 'NoRidge', 'ClearCr', 'Blmngtn', 'BrkSide', 'NPkVill',
#        'Blueste', 'GrnHill', 'Greens', 'Landmrk'], dtype=object)

# %%
ames_train6['neighborhood'] = ames_train6['neighborhood'].map({
    'Blmngtn':1,
    'Blueste':2,
    'BrDale':3,
    'BrkSide':4,
    'ClearCr':5,
    'CollgCr':6,
    'Crawfor':7,
    'Edwards':8,
    'Gilbert':9,
    'Greens':10,
    'GrnHill':11,
    'IDOTRR':12,
    'Landmrk':13,
    'MeadowV':14,
    'Mitchel':15,
    'NAmes':16,
    'NoRidge':17,
    'NPkVill':18,
    'NridgHt':19,
    'NWAmes':20,
    'OldTown':21,
    'SWISU':22,
    'Sawyer':23,
    'SawyerW':24,
    'Somerst':25,
    'StoneBr':26,
    'Timber':27,
    'Veenker':28})

# %%
sns.pairplot(ames_train6, y_vars= ['neighborhood'], x_vars = ['saleprice'])

# %%
ames_train6['neighborhood'].hist(figsize=(4,4))
# Out:
# <AxesSubplot:>

# %%
ames_train6['neighborhood'].value_counts()
# Out:
# 16    310
# 6     179
# 21    163
# 8     139
# 25    120
# 19    120
# 23    111
# 9     111
# 20     87
# 24     86
# 15     82
# 4      75
# 7      70
# 12     68
# 17     48
# 27     47
# 26     38
# 22     32
# 5      27
# 14     24
# 1      22
# 3      19
# 28     17
# 18     17
# 2       6
# 10      3
# 11      2
# 13      1
# Name: neighborhood, dtype: int64

# %% [markdown]
# Observations:
# Using the histogram we are able to detect the rough value counts for each neighborhood and using value.counts(), we were able to deduce that:
# 1. Model based on neighborhood 2,10,11,13 might perform badly due to too little of data.
# 2. Model based on neighborhood 16 might perform better due to very high amount of data.

# %%
ames_train7 = ames_train6

# %%
ames_train7.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 2024 entries, 0 to 2050
# Data columns (total 79 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   id               2024 non-null   int64
#  1   pid              2024 non-null   int64
#  2   ms_subclass      2024 non-null   int64
#  3   ms_zoning        2024 non-null   int64
#  4   lot_frontage     2024 non-null   float64
#  5   lot_area         2024 non-null   int64
#  6   street           2024 non-null   int64
#  7   alley            2024 non-null   object
#  8   lot_shape        2024 non-null   object
#  9   land_contour     2024 non-null   int64
#  10  utilities        2024 non-null   int64
#  11  lot_config       2024 non-null   int64
#  12  land_slope       2024 non-null   int64
#  13  neighborhood     2024 non-null   int64
#  14  condition_1      2024 non-null   object
#  15  condition_2      2024 non-null   object
#  16  bldg_type        2024 non-null   object
#  17  house_style      2024 non-null   object
#  18  overall_qual     2024 non-null   int64
#  19  overall_cond     2024 non-null   int64
#  20  year_built       2024 non-null   int64
#  21  year_remod/add   2024 non-null   int64
#  22  roof_style       2024 non-null   object
#  23  roof_matl        2024 non-null   object
#  24  exterior_1st     2024 non-null   object
#  25  exterior_2nd     2024 non-null   object
#  26  mas_vnr_type     2024 non-null   object
#  27  mas_vnr_area     2024 non-null   float64
#  28  exter_qual       2024 non-null   object
#  29  exter_cond       2024 non-null   object
#  30  foundation       2024 non-null   object
#  31  bsmt_qual        2024 non-null   object
#  32  bsmt_cond        2024 non-null   object
#  33  bsmt_exposure    2024 non-null   object
#  34  bsmtfin_type_1   2024 non-null   object
#  35  bsmtfin_sf_1     2024 non-null   float64
#  36  bsmtfin_type_2   2024 non-null   object
#  37  bsmtfin_sf_2     2024 non-null   float64
#  38  bsmt_unf_sf      2024 non-null   float64
#  39  total_bsmt_sf    2024 non-null   float64
#  40  heating          2024 non-null   object
#  41  heating_qc       2024 non-null   object
#  42  central_air      2024 non-null   object
#  43  electrical       2024 non-null   object
#  44  1st_flr_sf       2024 non-null   int64
#  45  2nd_flr_sf       2024 non-null   int64
#  46  low_qual_fin_sf  2024 non-null   int64
#  47  gr_liv_area      2024 non-null   int64
#  48  bsmt_full_bath   2024 non-null   float64
#  49  bsmt_half_bath   2024 non-null   float64
#  50  full_bath        2024 non-null   int64
#  51  half_bath        2024 non-null   int64
#  52  bedroom_abvgr    2024 non-null   int64
#  53  kitchen_abvgr    2024 non-null   int64
#  54  kitchen_qual     2024 non-null   object
#  55  totrms_abvgrd    2024 non-null   int64
#  56  functional       2024 non-null   object
#  57  fireplaces       2024 non-null   int64
#  58  fireplace_qu     2024 non-null   object
#  59  garage_type      2024 non-null   object
#  60  garage_yr_blt    2024 non-null   object
#  61  garage_finish    2024 non-null   object
#  62  garage_cars      2024 non-null   float64
#  63  garage_area      2024 non-null   float64
#  64  garage_qual      2024 non-null   object
#  65  garage_cond      2024 non-null   object
#  66  paved_drive      2024 non-null   object
#  67  wood_deck_sf     2024 non-null   int64
#  68  open_porch_sf    2024 non-null   int64
#  69  enclosed_porch   2024 non-null   int64
#  70  3ssn_porch       2024 non-null   int64
#  71  screen_porch     2024 non-null   int64
#  72  fence            2024 non-null   object
#  73  misc_feature     2024 non-null   object
#  74  misc_val         2024 non-null   int64
#  75  mo_sold          2024 non-null   int64
#  76  yr_sold          2024 non-null   int64
#  77  sale_type        2024 non-null   object
#  78  saleprice        2024 non-null   int64
# dtypes: float64(10), int64(34), object(35)
# memory usage: 1.2+ MB

# %% [markdown]
# Trying to understand the relationship for:
# 1. condition_1
# 2. condition_2

# %%
assignindex = dict(enumerate(ames_train7['condition_1'].sort_values(ascending=True).unique(),1))
assignindex = {v: i for i, v in assignindex.items()}
ames_train7 = ames_train7.replace({'condition_1': assignindex})

ames_train7['condition_1'].hist(figsize=(5,5))
# Out:
# <AxesSubplot:>

# %%
assignindex = dict(enumerate(ames_train7['condition_2'].sort_values(ascending=True).unique(),1))
assignindex = {v: i for i, v in assignindex.items()}
ames_train7 = ames_train7.replace({'condition_2': assignindex})

ames_train7['condition_2'].hist(figsize=(5,5))
# Out:
# <AxesSubplot:>

# %%
assignindex = dict(enumerate(ames_train7['bldg_type'].sort_values(ascending=True).unique(),1))
assignindex = {v: i for i, v in assignindex.items()}
ames_train7 = ames_train7.replace({'bldg_type': assignindex})

ames_train7['bldg_type'].hist(figsize=(5,5))
# Out:
# <AxesSubplot:>

# %%
assignindex = {
    1: '1Story',
    2: '1.5Fin',
    3: '1.5Unf',
    4: '2Story',
    5: '2.5Fin',
    6: '2.5Unf',
    7: 'SFoyer',
    8: 'SLvl'}
assignindex = {v: i for i, v in assignindex.items()}
ames_train7 = ames_train7.replace({'house_style': assignindex})

ames_train7['house_style'].hist(figsize=(5,5))
# Out:
# <AxesSubplot:>

# %%
assignindex = dict(enumerate(ames_train7['roof_style'].sort_values(ascending=True).unique(),1))
assignindex = {v: i for i, v in assignindex.items()}
ames_train7 = ames_train7.replace({'roof_style': assignindex})

ames_train7['roof_style'].hist(figsize=(5,5))
# Out:
# <AxesSubplot:>

# %%
assignindex = dict(enumerate(ames_train7['roof_matl'].sort_values(ascending=True).unique(),1))
assignindex = {v: i for i, v in assignindex.items()}
ames_train7 = ames_train7.replace({'roof_matl': assignindex})

ames_train7['roof_matl'].hist(figsize=(5,5))
# Out:
# <AxesSubplot:>

# %%
assignindex = dict(enumerate(ames_train7['exterior_1st'].sort_values(ascending=True).unique(),1))
assignindex = {v: i for i, v in assignindex.items()}
ames_train7 = ames_train7.replace({'exterior_1st': assignindex})

ames_train7['exterior_1st'].hist(figsize=(5,5))
# Out:
# <AxesSubplot:>

# %%
assignindex = dict(enumerate(ames_train7['exterior_2nd'].sort_values(ascending=True).unique(),1))
assignindex = {v: i for i, v in assignindex.items()}
ames_train7 = ames_train7.replace({'exterior_2nd': assignindex})

ames_train7['exterior_2nd'].hist(figsize=(5,5))
# Out:
# <AxesSubplot:>

# %%
assignindex = dict(enumerate(ames_train7['mas_vnr_type'].sort_values(ascending=True).unique(),1))
assignindex = {v: i for i, v in assignindex.items()}
ames_train7 = ames_train7.replace({'mas_vnr_type': assignindex})

ames_train7['mas_vnr_type'].hist(figsize=(5,5))
# Out:
# <AxesSubplot:>

# %%
assignindex = {
    5: 'Ex',
    4: 'Gd',
    3: 'TA',
    2: 'Fa',
    1: 'Po'}
assignindex = {v: i for i, v in assignindex.items()}
ames_train7 = ames_train7.replace({'exter_qual': assignindex})

ames_train7['exter_qual'].hist(figsize=(5,5))
# Out:
# <AxesSubplot:>

# %%
assignindex = {
    5: 'Ex',
    4: 'Gd',
    3: 'TA',
    2: 'Fa',
    1: 'Po'}
assignindex = {v: i for i, v in assignindex.items()}
ames_train7 = ames_train7.replace({'exter_cond': assignindex})

ames_train7['exter_cond'].hist(figsize=(5,5))
# Out:
# <AxesSubplot:>

# %%
assignindex = dict(enumerate(ames_train7['foundation'].sort_values(ascending=True).unique(),1))
assignindex = {v: i for i, v in assignindex.items()}
ames_train7 = ames_train7.replace({'foundation': assignindex})

ames_train7['foundation'].hist(figsize=(5,5))
# Out:
# <AxesSubplot:>

# %%
assignindex = {
    5: 'Ex',
    4: 'Gd',
    3: 'TA',
    2: 'Fa',
    1: 'Po',
    0: 'None'}
assignindex = {v: i for i, v in assignindex.items()}
ames_train7 = ames_train7.replace({'bsmt_qual': assignindex})

ames_train7['bsmt_qual'].hist(figsize=(5,5))
# Out:
# <AxesSubplot:>

# %%
assignindex = {
    4: 'Gd',
    3: 'Av',
    2: 'Mn',
    1: 'No',
    0: 'None'}
assignindex = {v: i for i, v in assignindex.items()}
ames_train7 = ames_train7.replace({'bsmt_exposure': assignindex})

ames_train7['bsmt_exposure'].hist(figsize=(5,5))
# Out:
# /Users/khooqixiang/opt/anaconda3/lib/python3.9/site-packages/IPython/core/displayhook.py:275: UserWarning: Output cache limit (currently 1000 entries) hit.
# Flushing oldest 200 entries.
#   warn('Output cache limit (currently {sz} entries) hit.\n'
# <AxesSubplot:>

# %%
assignindex = {
    6: 'GLQ',
    5: 'ALQ',
    4: 'BLQ',
    3: 'Rec',
    2: 'LwQ',
    1: 'Unf',
    0: 'None'}
assignindex = {v: i for i, v in assignindex.items()}
ames_train7 = ames_train7.replace({'bsmtfin_type_1': assignindex})

ames_train7['bsmtfin_type_1'].hist(figsize=(5,5))
# Out:
# <AxesSubplot:>

# %%
assignindex = {
    6: 'GLQ',
    5: 'ALQ',
    4: 'BLQ',
    3: 'Rec',
    2: 'LwQ',
    1: 'Unf',
    0: 'None'}
assignindex = {v: i for i, v in assignindex.items()}
ames_train7 = ames_train7.replace({'bsmtfin_type_2': assignindex})

ames_train7['bsmtfin_type_2'].hist(figsize=(5,5))
# Out:
# <AxesSubplot:>

# %%
assignindex = {
    5: 'Ex',
    4: 'Gd',
    3: 'TA',
    2: 'Fa',
    1: 'Po',
    0: 'None'}
assignindex = {v: i for i, v in assignindex.items()}
ames_train7 = ames_train7.replace({'heating_qc': assignindex})

ames_train7['heating_qc'].hist(figsize=(5,5))
# Out:
# <AxesSubplot:>

# %%
assignindex = dict(enumerate(ames_train7['heating'].sort_values(ascending=True).unique(),1))
assignindex = {v: i for i, v in assignindex.items()}
ames_train7 = ames_train7.replace({'heating': assignindex})

ames_train7['heating'].hist(figsize=(5,5))
# Out:
# <AxesSubplot:>

# %%
ames_train7['heating'].sort_values(ascending=True).unique()
# Out:
# array([1, 2, 3, 4, 5])

# %%
ames_train7['central_air'] = ames_train7['central_air'].map({'Y':1, 'N':0})
ames_train7['central_air'].hist(figsize=(5,5))
# Out:
# <AxesSubplot:>

# %%
ames_train8 = ames_train7

# %%
assignindex = {
    5: 'SBrkr',
    4: 'FuseA',
    3: 'FuseF',
    2: 'FuseP',
    1: 'Mix'}
assignindex = {v: i for i, v in assignindex.items()}
ames_train8 = ames_train8.replace({'electrical': assignindex})

ames_train8['electrical'].hist(figsize=(5,5))
# Out:
# <AxesSubplot:>

# %%
# Checking whats the value count for electrical since there is a high concentration between the SBrkr
ames_train8['electrical'].value_counts()
# Out:
# 5    1842
# 4     139
# 3      35
# 2       7
# 1       1
# Name: electrical, dtype: int64

# %%
assignindex = {
    5: 'Ex',
    4: 'Gd',
    3: 'TA',
    2: 'Fa',
    1: 'Po'}
assignindex = {v: i for i, v in assignindex.items()}
ames_train8 = ames_train8.replace({'kitchen_qual': assignindex})

ames_train8['kitchen_qual'].hist(figsize=(5,5))
# Out:
# <AxesSubplot:>

# %%
assignindex = {
    8: 'Typ',
    7: 'Min1',
    6: 'Min2',
    5: 'Mod',
    4: 'Maj1',
    3: 'Maj2',
    2: 'Sev',
    1: 'Sal'}
assignindex = {v: i for i, v in assignindex.items()}
ames_train8 = ames_train8.replace({'functional': assignindex})

ames_train8['functional'].hist(figsize=(5,5))
# Out:
# <AxesSubplot:>

# %%
# Checking the value count in between Typ to Min2
ames_train8['functional'].value_counts()
# Out:
# 8    1889
# 6      42
# 7      42
# 5      29
# 4      11
# 3       7
# 2       2
# 1       2
# Name: functional, dtype: int64

# %%
assignindex = {
    5: 'Ex',
    4: 'Gd',
    3: 'TA',
    2: 'Fa',
    1: 'Po',
    0: 'None'}
assignindex = {v: i for i, v in assignindex.items()}
ames_train8 = ames_train8.replace({'fireplace_qu': assignindex})

ames_train8['fireplace_qu'].hist(figsize=(5,5))
# Out:
# <AxesSubplot:>

# %%
ames_train8['fireplace_qu'].value_counts()
# Out:
# 0    990
# 4    511
# 3    402
# 2     59
# 1     31
# 5     31
# Name: fireplace_qu, dtype: int64

# %%
assignindex = dict(enumerate(ames_train8['garage_type'].sort_values(ascending=True).unique(),1))
assignindex = {v: i for i, v in assignindex.items()}
ames_train8 = ames_train8.replace({'garage_type': assignindex})

ames_train8['garage_type'].hist(figsize=(5,5))
# Out:
# <AxesSubplot:>

# %%
ames_train8['garage_type'].value_counts()
# Out:
# 2    1192
# 6     534
# 4     129
# 7     112
# 3      27
# 1      19
# 5      11
# Name: garage_type, dtype: int64

# %%
assignindex = {
    3: 'Fin',
    2: 'RFn',
    1: 'Unf',
    0: 'None'}
assignindex = {v: i for i, v in assignindex.items()}
ames_train8 = ames_train8.replace({'garage_finish': assignindex})

ames_train8['garage_finish'].hist(figsize=(5,5))
# Out:
# <AxesSubplot:>

# %%
assignindex = {
    5: 'Ex',
    4: 'Gd',
    3: 'TA',
    2: 'Fa',
    1: 'Po',
    0: 'None'}
assignindex = {v: i for i, v in assignindex.items()}
ames_train8 = ames_train8.replace({'garage_qual': assignindex})

ames_train8['garage_qual'].hist(figsize=(5,5))
# Out:
# <AxesSubplot:>

# %%
ames_train8.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 2024 entries, 0 to 2050
# Data columns (total 79 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   id               2024 non-null   int64
#  1   pid              2024 non-null   int64
#  2   ms_subclass      2024 non-null   int64
#  3   ms_zoning        2024 non-null   int64
#  4   lot_frontage     2024 non-null   float64
#  5   lot_area         2024 non-null   int64
#  6   street           2024 non-null   int64
#  7   alley            2024 non-null   object
#  8   lot_shape        2024 non-null   object
#  9   land_contour     2024 non-null   int64
#  10  utilities        2024 non-null   int64
#  11  lot_config       2024 non-null   int64
#  12  land_slope       2024 non-null   int64
#  13  neighborhood     2024 non-null   int64
#  14  condition_1      2024 non-null   int64
#  15  condition_2      2024 non-null   int64
#  16  bldg_type        2024 non-null   int64
#  17  house_style      2024 non-null   int64
#  18  overall_qual     2024 non-null   int64
#  19  overall_cond     2024 non-null   int64
#  20  year_built       2024 non-null   int64
#  21  year_remod/add   2024 non-null   int64
#  22  roof_style       2024 non-null   int64
#  23  roof_matl        2024 non-null   int64
#  24  exterior_1st     2024 non-null   int64
#  25  exterior_2nd     2024 non-null   int64
#  26  mas_vnr_type     2024 non-null   int64
#  27  mas_vnr_area     2024 non-null   float64
#  28  exter_qual       2024 non-null   int64
#  29  exter_cond       2024 non-null   int64
#  30  foundation       2024 non-null   int64
#  31  bsmt_qual        2024 non-null   int64
#  32  bsmt_cond        2024 non-null   object
#  33  bsmt_exposure    2024 non-null   int64
#  34  bsmtfin_type_1   2024 non-null   int64
#  35  bsmtfin_sf_1     2024 non-null   float64
#  36  bsmtfin_type_2   2024 non-null   int64
#  37  bsmtfin_sf_2     2024 non-null   float64
#  38  bsmt_unf_sf      2024 non-null   float64
#  39  total_bsmt_sf    2024 non-null   float64
#  40  heating          2024 non-null   int64
#  41  heating_qc       2024 non-null   int64
#  42  central_air      2024 non-null   int64
#  43  electrical       2024 non-null   int64
#  44  1st_flr_sf       2024 non-null   int64
#  45  2nd_flr_sf       2024 non-null   int64
#  46  low_qual_fin_sf  2024 non-null   int64
#  47  gr_liv_area      2024 non-null   int64
#  48  bsmt_full_bath   2024 non-null   float64
#  49  bsmt_half_bath   2024 non-null   float64
#  50  full_bath        2024 non-null   int64
#  51  half_bath        2024 non-null   int64
#  52  bedroom_abvgr    2024 non-null   int64
#  53  kitchen_abvgr    2024 non-null   int64
#  54  kitchen_qual     2024 non-null   int64
#  55  totrms_abvgrd    2024 non-null   int64
#  56  functional       2024 non-null   int64
#  57  fireplaces       2024 non-null   int64
#  58  fireplace_qu     2024 non-null   int64
#  59  garage_type      2024 non-null   int64
#  60  garage_yr_blt    2024 non-null   object
#  61  garage_finish    2024 non-null   int64
#  62  garage_cars      2024 non-null   float64
#  63  garage_area      2024 non-null   float64
#  64  garage_qual      2024 non-null   int64
#  65  garage_cond      2024 non-null   object
#  66  paved_drive      2024 non-null   object
#  67  wood_deck_sf     2024 non-null   int64
#  68  open_porch_sf    2024 non-null   int64
#  69  enclosed_porch   2024 non-null   int64
#  70  3ssn_porch       2024 non-null   int64
#  71  screen_porch     2024 non-null   int64
#  72  fence            2024 non-null   object
#  73  misc_feature     2024 non-null   object
#  74  misc_val         2024 non-null   int64
#  75  mo_sold          2024 non-null   int64
#  76  yr_sold          2024 non-null   int64
#  77  sale_type        2024 non-null   object
#  78  saleprice        2024 non-null   int64
# dtypes: float64(10), int64(60), object(9)
# memory usage: 1.2+ MB

# %%
ames_train8['paved_drive'] = ames_train8['paved_drive'].map({'Y':3, 'P':2, 'N':1})
ames_train8['paved_drive'].value_counts()
# Out:
# 3    1835
# 1     150
# 2      39
# Name: paved_drive, dtype: int64

# %%
assignindex = {
    4: 'GdPrv',
    3: 'MnPrv',
    2: 'GdWo',
    1: 'MnWw',
    0: 'None'}
assignindex = {v: i for i, v in assignindex.items()}
ames_train8 = ames_train8.replace({'fence': assignindex})

ames_train8['fence'].hist(figsize=(5,5))
# Out:
# <AxesSubplot:>

# %%
ames_train8['fence'].value_counts()
# Out:
# 0    1626
# 3     225
# 4      83
# 2      80
# 1      10
# Name: fence, dtype: int64

# %%
assignindex = {
    5: 'Elev',
    4: 'Gar2',
    3: 'Othr',
    2: 'Shed',
    1: 'TenC',
    0: 'None'}
assignindex = {v: i for i, v in assignindex.items()}
ames_train8 = ames_train8.replace({'misc_feature': assignindex})

ames_train8['misc_feature'].hist(figsize=(5,5))
# Out:
# <AxesSubplot:>

# %%
ames_train8['misc_feature'].value_counts()
# Out:
# 0    1960
# 2      56
# 4       4
# 3       3
# 1       1
# Name: misc_feature, dtype: int64

# %%
assignindex = {
    2: 'Grvl',
    1: 'Pave',
    0: 'None'}
assignindex = {v: i for i, v in assignindex.items()}
ames_train8 = ames_train8.replace({'alley': assignindex})

ames_train8['alley'].hist(figsize=(5,5))
# Out:
# <AxesSubplot:>

# %%
ames_train8['alley'].value_counts()
# Out:
# 0    1886
# 2      85
# 1      53
# Name: alley, dtype: int64

# %%
assignindex = {
    3: 'Reg',
    2: 'IR1',
    1: 'IR2',
    0: 'IR3'}
assignindex = {v: i for i, v in assignindex.items()}
ames_train8 = ames_train8.replace({'lot_shape': assignindex})

ames_train8['lot_shape'].hist(figsize=(5,5))
# Out:
# <AxesSubplot:>

# %%
ames_train8 = ames_train8.drop(columns=['id','pid'])

# %%
for n in ames_train8:
    print(f'{n} {ames_train8[n].isnull().sum()}')
# Out:
# ms_subclass 0
# ms_zoning 0
# lot_frontage 0
# lot_area 0
# street 0
# alley 0
# lot_shape 0
# land_contour 0
# utilities 0
# lot_config 0
# land_slope 0
# neighborhood 0
# condition_1 0
# condition_2 0
# bldg_type 0
# house_style 0
# overall_qual 0
# overall_cond 0
# year_built 0
# year_remod/add 0
# roof_style 0
# roof_matl 0
# exterior_1st 0
# exterior_2nd 0
# mas_vnr_type 0
# mas_vnr_area 0
# exter_qual 0
# exter_cond 0
# foundation 0
# bsmt_qual 0
# bsmt_cond 0
# bsmt_exposure 0
# bsmtfin_type_1 0
# bsmtfin_sf_1 0
# bsmtfin_type_2 0
# bsmtfin_sf_2 0
# bsmt_unf_sf 0
# total_bsmt_sf 0
# heating 0
# heating_qc 0
# central_air 0
# electrical 0
# 1st_flr_sf 0
# 2nd_flr_sf 0
# low_qual_fin_sf 0
# gr_liv_area 0
# bsmt_full_bath 0
# bsmt_half_bath 0
# full_bath 0
# half_bath 0
# bedroom_abvgr 0
# kitchen_abvgr 0
# kitchen_qual 0
# totrms_abvgrd 0
# functional 0
# fireplaces 0
# fireplace_qu 0
# garage_type 0
# garage_yr_blt 0
# garage_finish 0
# garage_cars 0
# garage_area 0
# garage_qual 0
# garage_cond 0
# paved_drive 0
# wood_deck_sf 0
# open_porch_sf 0
# enclosed_porch 0
# 3ssn_porch 0
# screen_porch 0
# fence 0
# misc_feature 0
# misc_val 0
# mo_sold 0
# yr_sold 0
# sale_type 0
# saleprice 0

# %%
ames_train8.to_csv('../datasets/ames_train8.csv')

# %%
ames_train8.hist(figsize=(30,30))
# Out:
# array([[<AxesSubplot:title={'center':'ms_subclass'}>,
#         <AxesSubplot:title={'center':'ms_zoning'}>,
#         <AxesSubplot:title={'center':'lot_frontage'}>,
#         <AxesSubplot:title={'center':'lot_area'}>,
#         <AxesSubplot:title={'center':'street'}>,
#         <AxesSubplot:title={'center':'alley'}>,
#         <AxesSubplot:title={'center':'lot_shape'}>,
#         <AxesSubplot:title={'center':'land_contour'}>,
#         <AxesSubplot:title={'center':'utilities'}>],
#        [<AxesSubplot:title={'center':'lot_config'}>,
#         <AxesSubplot:title={'center':'land_slope'}>,
#         <AxesSubplot:title={'center':'neighborhood'}>,
#         <AxesSubplot:title={'center':'condition_1'}>,
#         <AxesSubplot:title={'center':'condition_2'}>,
#         <AxesSubplot:title={'center':'bldg_type'}>,
#         <AxesSubplot:title={'center':'house_style'}>,
#         <AxesSubplot:title={'center':'overall_qual'}>,
#         <AxesSubplot:title={'center':'overall_cond'}>],
#        [<AxesSubplot:title={'center':'year_built'}>,
#         <AxesSubplot:title={'center':'year_remod/add'}>,
#         <AxesSubplot:title={'center':'roof_style'}>,
#         <AxesSubplot:title={'center':'roof_matl'}>,
#         <AxesSubplot:title={'center':'exterior_1st'}>,
#         <AxesSubplot:title={'center':'exterior_2nd'}>,
#         <AxesSubplot:title={'center':'mas_vnr_type'}>,
#         <AxesSubplot:title={'center':'mas_vnr_area'}>,
#         <AxesSubplot:title={'center':'exter_qual'}>],
#        [<AxesSubplot:title={'center':'exter_cond'}>,
#         <AxesSubplot:title={'center':'foundation'}>,
#         <AxesSubplot:title={'center':'bsmt_qual'}>,
#         <AxesSubplot:title={'center':'bsmt_exposure'}>,
#         <AxesSubplot:title={'center':'bsmtfin_type_1'}>,
#         <AxesSubplot:title={'center':'bsmtfin_sf_1'}>,
#         <AxesSubplot:title={'center':'bsmtfin_type_2'}>,
#         <AxesSubplot:title={'center':'bsmtfin_sf_2'}>,
#         <AxesSubplot:title={'center':'bsmt_unf_sf'}>],
#        [<AxesSubplot:title={'center':'total_bsmt_sf'}>,
#         <AxesSubplot:title={'center':'heating'}>,
#         <AxesSubplot:title={'center':'heating_qc'}>,
#         <AxesSubplot:title={'center':'central_air'}>,
#         <AxesSubplot:title={'center':'electrical'}>,
#         <AxesSubplot:title={'center':'1st_flr_sf'}>,
#         <AxesSubplot:title={'center':'2nd_flr_sf'}>,
#         <AxesSubplot:title={'center':'low_qual_fin_sf'}>,
#         <AxesSubplot:title={'center':'gr_liv_area'}>],
#        [<AxesSubplot:title={'center':'bsmt_full_bath'}>,
#         <AxesSubplot:title={'center':'bsmt_half_bath'}>,
#         <AxesSubplot:title={'center':'full_bath'}>,
#         <AxesSubplot:title={'center':'half_bath'}>,
#         <AxesSubplot:title={'center':'bedroom_abvgr'}>,
#         <AxesSubplot:title={'center':'kitchen_abvgr'}>,
#         <AxesSubplot:title={'center':'kitchen_qual'}>,
#         <AxesSubplot:title={'center':'totrms_abvgrd'}>,
#         <AxesSubplot:title={'center':'functional'}>],
#        [<AxesSubplot:title={'center':'fireplaces'}>,
#         <AxesSubplot:title={'center':'fireplace_qu'}>,
#         <AxesSubplot:title={'center':'garage_type'}>,
#         <AxesSubplot:title={'center':'garage_finish'}>,
#         <AxesSubplot:title={'center':'garage_cars'}>,
#         <AxesSubplot:title={'center':'garage_area'}>,
#         <AxesSubplot:title={'center':'garage_qual'}>,
#         <AxesSubplot:title={'center':'paved_drive'}>,
#         <AxesSubplot:title={'center':'wood_deck_sf'}>],
#        [<AxesSubplot:title={'center':'open_porch_sf'}>,
#         <AxesSubplot:title={'center':'enclosed_porch'}>,
#         <AxesSubplot:title={'center':'3ssn_porch'}>,
#         <AxesSubplot:title={'center':'screen_porch'}>,
#         <AxesSubplot:title={'center':'fence'}>,
#         <AxesSubplot:title={'center':'misc_feature'}>,
#         <AxesSubplot:title={'center':'misc_val'}>,
#         <AxesSubplot:title={'center':'mo_sold'}>,
#         <AxesSubplot:title={'center':'yr_sold'}>],
#        [<AxesSubplot:title={'center':'saleprice'}>, <AxesSubplot:>,
#         <AxesSubplot:>, <AxesSubplot:>, <AxesSubplot:>, <AxesSubplot:>,
#         <AxesSubplot:>, <AxesSubplot:>, <AxesSubplot:>]], dtype=object)

# %% [markdown]
# Some observations from the data cleaning:
# A high number of the data in catagorial feature is skewed which means more data in one catagory as compared to the others. There is a possibility that some of the features may be used to form a new feature which might give a higher correlation to sale price and this could help the model to generate better prediction.We can foresee some category with assign index might pose problem for EDA.

# %% [markdown]
# # Exploratory Data Analysis
#
# Approach : Using the backward selection method to try to identify key features for the model.

# %%
print(ames_train8.corr()['saleprice'].sort_values())
# Out:
# garage_type       -0.425665
# lot_shape         -0.298196
# ms_zoning         -0.188820
# fence             -0.155463
# alley             -0.155262
# enclosed_porch    -0.138103
# kitchen_abvgr     -0.126260
# heating           -0.104077
# overall_cond      -0.094304
# ms_subclass       -0.085332
# street            -0.069989
# mas_vnr_type      -0.050046
# misc_feature      -0.049582
# bsmt_half_bath    -0.044108
# low_qual_fin_sf   -0.041166
# bldg_type         -0.040010
# utilities         -0.026406
# yr_sold           -0.011014
# misc_val          -0.009688
# bsmtfin_type_2     0.018000
# bsmtfin_sf_2       0.019355
# mo_sold            0.025971
# exter_cond         0.038355
# 3ssn_porch         0.049854
# house_style        0.051979
# condition_2        0.054013
# land_slope         0.060002
# condition_1        0.084804
# roof_matl          0.094299
# lot_config         0.098356
# exterior_1st       0.107351
# exterior_2nd       0.111134
# functional         0.126803
# land_contour       0.135224
# screen_porch       0.137777
# bedroom_abvgr      0.138419
# neighborhood       0.179686
# lot_frontage       0.183445
# bsmt_unf_sf        0.191294
# electrical         0.246662
# roof_style         0.250378
# 2nd_flr_sf         0.251325
# central_air        0.277816
# half_bath          0.278854
# garage_qual        0.285459
# bsmt_full_bath     0.285615
# paved_drive        0.290136
# lot_area           0.303137
# wood_deck_sf       0.329865
# open_porch_sf      0.330726
# bsmtfin_type_1     0.353104
# foundation         0.418062
# bsmt_exposure      0.427511
# bsmtfin_sf_1       0.446922
# heating_qc         0.458679
# fireplaces         0.473933
# totrms_abvgrd      0.511007
# mas_vnr_area       0.520501
# fireplace_qu       0.537845
# full_bath          0.538732
# year_remod/add     0.549903
# garage_finish      0.559005
# year_built         0.572423
# bsmt_qual          0.616228
# garage_cars        0.647460
# garage_area        0.653894
# 1st_flr_sf         0.654694
# total_bsmt_sf      0.668507
# kitchen_qual       0.693022
# exter_qual         0.714759
# gr_liv_area        0.721925
# overall_qual       0.803276
# saleprice          1.000000
# Name: saleprice, dtype: float64

# %%
# Heatmap to find out how all the attributes are related to each other.
matrix = ames_train8.corr()

# Creating mask
mask = np.triu(np.ones_like(matrix.corr()))
 
# plotting a triangle correlation heatmap
plt.figure(figsize=(52,52))
dataplot = sb.heatmap(matrix.corr(), cmap="YlGnBu", annot=True, mask=mask).set(title= 'Heatmap for Correlations between variables')
 
# displaying heatmap
mp.show()

# %%
print(ames_train8.corr()['saleprice'].sort_values()>0.5)
# Out:
# garage_type        False
# lot_shape          False
# ms_zoning          False
# fence              False
# alley              False
# enclosed_porch     False
# kitchen_abvgr      False
# heating            False
# overall_cond       False
# ms_subclass        False
# street             False
# mas_vnr_type       False
# misc_feature       False
# bsmt_half_bath     False
# low_qual_fin_sf    False
# bldg_type          False
# utilities          False
# yr_sold            False
# misc_val           False
# bsmtfin_type_2     False
# bsmtfin_sf_2       False
# mo_sold            False
# exter_cond         False
# 3ssn_porch         False
# house_style        False
# condition_2        False
# land_slope         False
# condition_1        False
# roof_matl          False
# lot_config         False
# exterior_1st       False
# exterior_2nd       False
# functional         False
# land_contour       False
# screen_porch       False
# bedroom_abvgr      False
# neighborhood       False
# lot_frontage       False
# bsmt_unf_sf        False
# electrical         False
# roof_style         False
# 2nd_flr_sf         False
# central_air        False
# half_bath          False
# garage_qual        False
# bsmt_full_bath     False
# paved_drive        False
# lot_area           False
# wood_deck_sf       False
# open_porch_sf      False
# bsmtfin_type_1     False
# foundation         False
# bsmt_exposure      False
# bsmtfin_sf_1       False
# heating_qc         False
# fireplaces         False
# totrms_abvgrd       True
# mas_vnr_area        True
# fireplace_qu        True
# full_bath           True
# year_remod/add      True
# garage_finish       True
# year_built          True
# bsmt_qual           True
# garage_cars         True
# garage_area         True
# 1st_flr_sf          True
# total_bsmt_sf       True
# kitchen_qual        True
# exter_qual          True
# gr_liv_area         True
# overall_qual        True
# saleprice           True
# Name: saleprice, dtype: bool

# %% [markdown]
# Would plot all the feature against saleprice to see if we can get:
# - A rough gauge of the data ranges, outliers, lower and upper range for all features
# - For categorial features we will be using boxplots
# - For numerical features we will be using scatter plots

# %%
ames_train1.boxplot(by = 'ms_subclass', column = ['saleprice'], grid=False)
# Out:
# <AxesSubplot:title={'center':'saleprice'}, xlabel='ms_subclass'>

# %%
ames_train1.boxplot(by = 'ms_zoning', column = ['saleprice'], grid=False)
# Out:
# <AxesSubplot:title={'center':'saleprice'}, xlabel='ms_zoning'>

# %%
ames_train1.boxplot(by = 'lot_frontage', column = ['saleprice'], grid=False)
# Out:
# <AxesSubplot:title={'center':'saleprice'}, xlabel='lot_frontage'>

# %%
ames_train1['lot_frontage'].value_counts()
# Out:
# 60.0     179
# 70.0      96
# 80.0      94
# 50.0      90
# 65.0      71
# 75.0      68
# 85.0      52
# 63.0      38
# 24.0      33
# 78.0      33
# 21.0      32
# 64.0      31
# 90.0      31
# 74.0      31
# 72.0      30
# 62.0      28
# 68.0      28
# 73.0      25
# 100.0     23
# 82.0      21
# 52.0      20
# 57.0      20
# 43.0      20
# 66.0      19
# 79.0      19
# 67.0      18
# 53.0      18
# 59.0      18
# 51.0      16
# 76.0      16
# 88.0      16
# 56.0      15
# 84.0      14
# 69.0      14
# 81.0      14
# 55.0      14
# 58.0      13
# 92.0      13
# 35.0      13
# 71.0      13
# 40.0      13
# 91.0      13
# 44.0      12
# 96.0      11
# 95.0      11
# 34.0      11
# 48.0      11
# 77.0      11
# 41.0      11
# 30.0      11
# 61.0      10
# 83.0      10
# 105.0      9
# 107.0      9
# 93.0       9
# 110.0      9
# 42.0       8
# 94.0       8
# 120.0      8
# 87.0       8
# 45.0       8
# 86.0       7
# 98.0       7
# 102.0      7
# 32.0       6
# 89.0       6
# 54.0       6
# 47.0       6
# 37.0       6
# 36.0       5
# 103.0      5
# 129.0      4
# 97.0       4
# 108.0      4
# 114.0      4
# 39.0       4
# 38.0       4
# 109.0      4
# 104.0      3
# 99.0       3
# 106.0      3
# 112.0      3
# 128.0      3
# 26.0       3
# 49.0       3
# 134.0      3
# 125.0      3
# 313.0      2
# 46.0       2
# 101.0      2
# 140.0      2
# 113.0      2
# 130.0      2
# 123.0      1
# 155.0      1
# 116.0      1
# 153.0      1
# 117.0      1
# 150.0      1
# 200.0      1
# 33.0       1
# 25.0       1
# 111.0      1
# 138.0      1
# 144.0      1
# 160.0      1
# 174.0      1
# 22.0       1
# 141.0      1
# 122.0      1
# 124.0      1
# 121.0      1
# 119.0      1
# 118.0      1
# 137.0      1
# 195.0      1
# 115.0      1
# 135.0      1
# Name: lot_frontage, dtype: int64

# %%
plt.figure(figsize=(8,5))
sns.regplot('saleprice', 'lot_area', ames_train8, ci=None,
           scatter_kws = {'s':1},
           line_kws = {'color': 'red'})
plt.xlabel('Salesprice')
plt.ylabel('Lot Area')
plt.title('Lot Area against Sales Price')
# Out:
# /Users/khooqixiang/opt/anaconda3/lib/python3.9/site-packages/seaborn/_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y, data. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# Text(0.5, 1.0, 'Lot Area against Sales Price')

# %%
ames_train1.boxplot(by = 'alley', column = ['saleprice'], grid=False)
# Out:
# <AxesSubplot:title={'center':'saleprice'}, xlabel='alley'>

# %%
ames_train1.boxplot(by = 'street', column = ['saleprice'], grid=False)
# Out:
# <AxesSubplot:title={'center':'saleprice'}, xlabel='street'>

# %%
ames_train1.boxplot(by = 'lot_shape', column = ['saleprice'], grid=False)
# Out:
# <AxesSubplot:title={'center':'saleprice'}, xlabel='lot_shape'>

# %%
ames_train1.boxplot(by = 'land_contour', column = ['saleprice'], grid=False)
# Out:
# <AxesSubplot:title={'center':'saleprice'}, xlabel='land_contour'>

# %%
ames_train1['land_contour'].value_counts()
# Out:
# Lvl    1843
# HLS      85
# Bnk      80
# Low      43
# Name: land_contour, dtype: int64

# %%
ames_train1.boxplot(by = 'utilities', column = ['saleprice'], grid=False)
# Out:
# <AxesSubplot:title={'center':'saleprice'}, xlabel='utilities'>

# %%
ames_train1['utilities'].value_counts()
# Out:
# AllPub    2049
# NoSeWa       1
# NoSewr       1
# Name: utilities, dtype: int64

# %%
ames_train1.boxplot(by = 'lot_config', column = ['saleprice'], grid=False)
# Out:
# <AxesSubplot:title={'center':'saleprice'}, xlabel='lot_config'>

# %%
ames_train1['lot_config'].value_counts()
# Out:
# Inside     1503
# Corner      348
# CulDSac     131
# FR2          60
# FR3           9
# Name: lot_config, dtype: int64

# %%
ames_train1.boxplot(by = 'land_slope', column = ['saleprice'], grid=False)
# Out:
# <AxesSubplot:title={'center':'saleprice'}, xlabel='land_slope'>

# %%
ames_train1['land_slope'].value_counts()
# Out:
# Gtl    1953
# Mod      88
# Sev      10
# Name: land_slope, dtype: int64

# %%
ames_train8.boxplot(by = 'neighborhood', column = ['saleprice'], grid=False)
# Out:
# <AxesSubplot:title={'center':'saleprice'}, xlabel='neighborhood'>

# %%
ames_train1.boxplot(by = 'condition_1', column = ['saleprice'], grid=False)
# Out:
# <AxesSubplot:title={'center':'saleprice'}, xlabel='condition_1'>

# %%
ames_train1['condition_1'].value_counts()
# Out:
# Norm      1767
# Feedr      109
# Artery      70
# RRAn        36
# PosN        27
# RRAe        21
# PosA        12
# RRNn         6
# RRNe         3
# Name: condition_1, dtype: int64

# %%
ames_train1.boxplot(by = 'condition_2', column = ['saleprice'], grid=False)
# Out:
# <AxesSubplot:title={'center':'saleprice'}, xlabel='condition_2'>

# %%
ames_train1['condition_2'].value_counts()
# Out:
# Norm      2025
# Feedr       11
# Artery       5
# PosA         3
# PosN         3
# RRNn         2
# RRAe         1
# RRAn         1
# Name: condition_2, dtype: int64

# %%
ames_train1.boxplot(by = 'bldg_type', column = ['saleprice'], grid=False)
# Out:
# <AxesSubplot:title={'center':'saleprice'}, xlabel='bldg_type'>

# %%
ames_train1['bldg_type'].value_counts()
# Out:
# 1Fam      1700
# TwnhsE     161
# Duplex      75
# Twnhs       69
# 2fmCon      46
# Name: bldg_type, dtype: int64

# %%
ames_train1.boxplot(by = 'house_style', column = ['saleprice'], grid=False)
# Out:
# <AxesSubplot:title={'center':'saleprice'}, xlabel='house_style'>

# %%
ames_train1['house_style'].value_counts()
# Out:
# 1Story    1059
# 2Story     598
# 1.5Fin     218
# SLvl        94
# SFoyer      50
# 2.5Unf      14
# 1.5Unf      12
# 2.5Fin       6
# Name: house_style, dtype: int64

# %%
ames_train1.boxplot(by = 'overall_qual', column = ['saleprice'], grid=False)
# Out:
# <AxesSubplot:title={'center':'saleprice'}, xlabel='overall_qual'>

# %%
ames_train1.boxplot(by = 'overall_cond', column = ['saleprice'], grid=False)
# Out:
# <AxesSubplot:title={'center':'saleprice'}, xlabel='overall_cond'>

# %% [markdown]
# For Overall_cond and overall_qual:
# - Can observe that higher condition and quality sell better

# %%
plt.figure(figsize=(8,5))
sns.regplot('saleprice', 'year_built', ames_train8, ci=None,
           scatter_kws = {'s':1},
           line_kws = {'color': 'red'})
plt.xlabel('Salesprice')
plt.ylabel('Year Built')
plt.title('Year Built against Sales Price')
# Out:
# /Users/khooqixiang/opt/anaconda3/lib/python3.9/site-packages/seaborn/_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y, data. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# Text(0.5, 1.0, 'Year Built against Sales Price')

# %%
plt.figure(figsize=(8,5))
sns.regplot('saleprice', 'year_remod/add', ames_train8, ci=None,
           scatter_kws = {'s':1},
           line_kws = {'color': 'red'})
plt.xlabel('Salesprice')
plt.ylabel('Year Remod/Add')
plt.title('Year Remod/Add against Sales Price')
# Out:
# /Users/khooqixiang/opt/anaconda3/lib/python3.9/site-packages/seaborn/_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y, data. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# Text(0.5, 1.0, 'Year Remod/Add against Sales Price')

# %%
ames_train1.boxplot(by = 'roof_style', column = ['saleprice'], grid=False)
# Out:
# <AxesSubplot:title={'center':'saleprice'}, xlabel='roof_style'>

# %%
ames_train1['roof_style'].value_counts()
# Out:
# Gable      1619
# Hip         397
# Flat         13
# Gambrel      12
# Mansard       7
# Shed          3
# Name: roof_style, dtype: int64

# %%
ames_train1.boxplot(by = 'roof_matl', column = ['saleprice'], grid=False)
# Out:
# <AxesSubplot:title={'center':'saleprice'}, xlabel='roof_matl'>

# %%
ames_train1['roof_matl'].value_counts()
# Out:
# CompShg    2025
# Tar&Grv      15
# WdShngl       5
# WdShake       4
# Membran       1
# ClyTile       1
# Name: roof_matl, dtype: int64

# %%
ames_train8.boxplot(by = 'exterior_1st', column = ['saleprice'], grid=False)
# Out:
# <AxesSubplot:title={'center':'saleprice'}, xlabel='exterior_1st'>

# %%
ames_train1['exterior_1st'].value_counts()
# Out:
# VinylSd    724
# MetalSd    331
# HdBoard    300
# Wd Sdng    276
# Plywood    152
# CemntBd     90
# BrkFace     64
# WdShing     45
# AsbShng     33
# Stucco      27
# BrkComm      3
# Stone        2
# CBlock       2
# ImStucc      1
# AsphShn      1
# Name: exterior_1st, dtype: int64

# %%
ames_train8.boxplot(by = 'exterior_2nd', column = ['saleprice'], grid=False)
# Out:
# <AxesSubplot:title={'center':'saleprice'}, xlabel='exterior_2nd'>

# %%
ames_train['exterior_1st'].value_counts()
# Out:
# VinylSd    724
# MetalSd    331
# HdBoard    300
# Wd Sdng    276
# Plywood    152
# CemntBd     90
# BrkFace     64
# WdShing     45
# AsbShng     33
# Stucco      27
# BrkComm      3
# Stone        2
# CBlock       2
# ImStucc      1
# AsphShn      1
# Name: exterior_1st, dtype: int64

# %%
ames_train1.boxplot(by = 'mas_vnr_type', column = ['saleprice'], grid=False)
# Out:
# <AxesSubplot:title={'center':'saleprice'}, xlabel='mas_vnr_type'>

# %%
ames_train1['mas_vnr_type'].value_counts()
# Out:
# None       1218
# BrkFace     630
# Stone       168
# BrkCmn       13
# Name: mas_vnr_type, dtype: int64

# %% [markdown]
# For Mas Vnr Type:
# - Better stone can sell higher generally.

# %%
plt.figure(figsize=(8,5))
sns.regplot('saleprice', 'mas_vnr_area', ames_train8, ci=None,
           scatter_kws = {'s':1},
           line_kws = {'color': 'red'})
plt.xlabel('Salesprice')
plt.ylabel('Mas Vnr Area')
plt.title('Mas Vnr Area against Sales Price')
# Out:
# /Users/khooqixiang/opt/anaconda3/lib/python3.9/site-packages/seaborn/_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y, data. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# Text(0.5, 1.0, 'Mas Vnr Area against Sales Price')

# %%
ames_train1.boxplot(by = 'exter_qual', column = ['saleprice'], grid=False)
# Out:
# <AxesSubplot:title={'center':'saleprice'}, xlabel='exter_qual'>

# %%
ames_train1.boxplot(by = 'exter_cond', column = ['saleprice'], grid=False)
# Out:
# <AxesSubplot:title={'center':'saleprice'}, xlabel='exter_cond'>

# %%
ames_train1.boxplot(by = 'foundation', column = ['saleprice'], grid=False)
# Out:
# <AxesSubplot:title={'center':'saleprice'}, xlabel='foundation'>

# %%
ames_train1['foundation'].value_counts()
# Out:
# PConc     926
# CBlock    863
# BrkTil    221
# Slab       34
# Stone       5
# Wood        2
# Name: foundation, dtype: int64

# %%
ames_train1.boxplot(by = 'bsmt_qual', column = ['saleprice'], grid=False)
# Out:
# <AxesSubplot:title={'center':'saleprice'}, xlabel='bsmt_qual'>

# %%
ames_train1.boxplot(by = 'bsmt_cond', column = ['saleprice'], grid=False)
# Out:
# <AxesSubplot:title={'center':'saleprice'}, xlabel='bsmt_cond'>

# %% [markdown]
# For foundation:
# - PConc Poured Contrete seems to be very popular and it fetch higher sale price
# - CBlock Cinder Block 2nd most popular with a mid range sale price.
#
# For Bsmt quality and conditional:
# - Higher quality and condition sells higher.
# - Thre are no data for condition so data might be slightly bias.

# %%
ames_train1.boxplot(by = 'bsmt_exposure', column = ['saleprice'], grid=False)
# Out:
# <AxesSubplot:title={'center':'saleprice'}, xlabel='bsmt_exposure'>

# %%
ames_train1.boxplot(by = 'bsmtfin_type_1', column = ['saleprice'], grid=False)
# Out:
# <AxesSubplot:title={'center':'saleprice'}, xlabel='bsmtfin_type_1'>

# %%
plt.figure(figsize=(8,5))
sns.regplot('saleprice', 'bsmtfin_sf_1', ames_train8, ci=None,
           scatter_kws = {'s':1},
           line_kws = {'color': 'red'})
plt.xlabel('Salesprice')
plt.ylabel('BsmtFin SF 1')
plt.title('BsmtFin SF 1 against Sales Price')
# Out:
# /Users/khooqixiang/opt/anaconda3/lib/python3.9/site-packages/seaborn/_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y, data. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# Text(0.5, 1.0, 'BsmtFin SF 1 against Sales Price')

# %%
ames_train1.boxplot(by = 'bsmtfin_type_2', column = ['saleprice'], grid=False)
# Out:
# <AxesSubplot:title={'center':'saleprice'}, xlabel='bsmtfin_type_2'>

# %%
ames_train1['bsmtfin_type_2'].value_counts()
# Out:
# Unf    1749
# Rec      80
# LwQ      60
# BLQ      48
# ALQ      35
# GLQ      23
# Name: bsmtfin_type_2, dtype: int64

# %%
plt.figure(figsize=(8,5))
sns.regplot('saleprice', 'bsmtfin_sf_2', ames_train8, ci=None,
           scatter_kws = {'s':1},
           line_kws = {'color': 'red'})
plt.xlabel('Salesprice')
plt.ylabel('BsmtFin SF 2')
plt.title('BsmtFin SF 2 against Sales Price')
# Out:
# /Users/khooqixiang/opt/anaconda3/lib/python3.9/site-packages/seaborn/_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y, data. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# Text(0.5, 1.0, 'BsmtFin SF 2 against Sales Price')

# %%
plt.figure(figsize=(8,5))
sns.regplot('saleprice', 'bsmt_unf_sf', ames_train8, ci=None,
           scatter_kws = {'s':1},
           line_kws = {'color': 'red'})
plt.xlabel('Salesprice')
plt.ylabel('Bsmt Unf SF')
plt.title('Bsmt Unf SF against Sales Price')
# Out:
# /Users/khooqixiang/opt/anaconda3/lib/python3.9/site-packages/seaborn/_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y, data. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# Text(0.5, 1.0, 'Bsmt Unf SF against Sales Price')

# %% [markdown]
# Price is likely to be higher when there is higher unfinished square feet of basement area

# %%
plt.figure(figsize=(8,5))
sns.regplot('saleprice', 'total_bsmt_sf', ames_train8, ci=None,
           scatter_kws = {'s':1},
           line_kws = {'color': 'red'})
plt.xlabel('Salesprice')
plt.ylabel('Total Bsmt SF')
plt.title('Total Bsmt SF against Sales Price')
# Out:
# /Users/khooqixiang/opt/anaconda3/lib/python3.9/site-packages/seaborn/_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y, data. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# Text(0.5, 1.0, 'Total Bsmt SF against Sales Price')

# %%
ames_train1.boxplot(by = 'heating', column = ['saleprice'], grid=False)
# Out:
# <AxesSubplot:title={'center':'saleprice'}, xlabel='heating'>

# %%
ames_train1.boxplot(by = 'heating_qc', column = ['saleprice'], grid=False)
# Out:
# <AxesSubplot:title={'center':'saleprice'}, xlabel='heating_qc'>

# %%
ames_train1.boxplot(by = 'central_air', column = ['saleprice'], grid=False)
# Out:
# <AxesSubplot:title={'center':'saleprice'}, xlabel='central_air'>

# %% [markdown]
# With central air, air conditioning, sale price is higher

# %%
ames_train1.boxplot(by = 'electrical', column = ['saleprice'], grid=False)
# Out:
# <AxesSubplot:title={'center':'saleprice'}, xlabel='electrical'>

# %%
ames_train1['electrical'].value_counts()
# Out:
# SBrkr    1868
# FuseA     140
# FuseF      35
# FuseP       7
# Mix         1
# Name: electrical, dtype: int64

# %%
plt.figure(figsize=(8,5))
sns.regplot('saleprice', '1st_flr_sf', ames_train8, ci=None,
           scatter_kws = {'s':1},
           line_kws = {'color': 'red'})
plt.xlabel('Salesprice')
plt.ylabel('1st Flr SF')
plt.title('1st Flr SF against Sales Price')
# Out:
# /Users/khooqixiang/opt/anaconda3/lib/python3.9/site-packages/seaborn/_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y, data. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# Text(0.5, 1.0, '1st Flr SF against Sales Price')

# %%
plt.figure(figsize=(8,5))
sns.regplot('saleprice', '2nd_flr_sf', ames_train8, ci=None,
           scatter_kws = {'s':1},
           line_kws = {'color': 'red'})
plt.xlabel('Salesprice')
plt.ylabel('2nd Flr SF')
plt.title('2nd Flr SF against Sales Price')
# Too much data of the value of 0
# Out:
# /Users/khooqixiang/opt/anaconda3/lib/python3.9/site-packages/seaborn/_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y, data. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# Text(0.5, 1.0, '2nd Flr SF against Sales Price')

# %%
plt.figure(figsize=(8,5))
sns.regplot('saleprice', 'low_qual_fin_sf', ames_train8, ci=None,
           scatter_kws = {'s':1},
           line_kws = {'color': 'red'})
plt.xlabel('Salesprice')
plt.ylabel('Low Qual Fin SF')
plt.title('Low Qual Fin SF against Sales Price')
# Out:
# /Users/khooqixiang/opt/anaconda3/lib/python3.9/site-packages/seaborn/_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y, data. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# Text(0.5, 1.0, 'Low Qual Fin SF against Sales Price')

# %%
plt.figure(figsize=(8,5))
sns.regplot('saleprice', 'gr_liv_area', ames_train8, ci=None,
           scatter_kws = {'s':1},
           line_kws = {'color': 'red'})
plt.xlabel('Salesprice')
plt.ylabel('Gr Liv Area')
plt.title('Gr Liv Area against Sales Price')
# Out:
# /Users/khooqixiang/opt/anaconda3/lib/python3.9/site-packages/seaborn/_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y, data. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# Text(0.5, 1.0, 'Gr Liv Area against Sales Price')

# %%
ames_train1.boxplot(by = 'bsmt_full_bath', column = ['saleprice'], grid=False)
# Generally have mmore basement full bathrooms would result in higher seller price but too little data for 3
# Out:
# <AxesSubplot:title={'center':'saleprice'}, xlabel='bsmt_full_bath'>

# %%
ames_train8['bsmt_full_bath'].value_counts()
# Out:
# 0.0    1187
# 1.0     813
# 2.0      22
# 3.0       2
# Name: bsmt_full_bath, dtype: int64

# %%
ames_train1.boxplot(by = 'bsmt_half_bath', column = ['saleprice'], grid=False)
# Out:
# <AxesSubplot:title={'center':'saleprice'}, xlabel='bsmt_half_bath'>

# %%
ames_train1.boxplot(by = 'full_bath', column = ['saleprice'], grid=False)
# Out:
# <AxesSubplot:title={'center':'saleprice'}, xlabel='full_bath'>

# %%
ames_train1.boxplot(by = 'half_bath', column = ['saleprice'], grid=False)
# Out:
# <AxesSubplot:title={'center':'saleprice'}, xlabel='half_bath'>

# %% [markdown]
#  For bathroom:
#  - Generally have more basement full bathrooms would result in higher seller price but there is too little data for 3.
#  - Half price doesnt seem to affect sale price much

# %%
ames_train1.boxplot(by = 'bedroom_abvgr', column = ['saleprice'], grid=False)
# Out:
# <AxesSubplot:title={'center':'saleprice'}, xlabel='bedroom_abvgr'>

# %%
ames_train1.boxplot(by = 'kitchen_abvgr', column = ['saleprice'], grid=False)
# Out:
# <AxesSubplot:title={'center':'saleprice'}, xlabel='kitchen_abvgr'>

# %%
ames_train1.boxplot(by = 'kitchen_qual', column = ['saleprice'], grid=False)
# Out:
# <AxesSubplot:title={'center':'saleprice'}, xlabel='kitchen_qual'>

# %% [markdown]
#  For kitchen quality:
#  - No data for fair and poor kitchen quality. But higher quality kitchen would have higher sale price.
#  - Seem like most property have 1 kitchen only hence the sale price for more than 1 kitchen might not be realiable.

# %%
ames_train1.boxplot(by = 'totrms_abvgrd', column = ['saleprice'], grid=False)
# Out:
# <AxesSubplot:title={'center':'saleprice'}, xlabel='totrms_abvgrd'>

# %% [markdown]
#  More rooms above ground would result in higher sales till 11. Generally more totrms, higher the sale price

# %%
ames_train1.boxplot(by = 'functional', column = ['saleprice'], grid=False)
# Out:
# <AxesSubplot:title={'center':'saleprice'}, xlabel='functional'>

# %%
ames_train8['functional'].value_counts()
# Out:
# 8    1889
# 6      42
# 7      42
# 5      29
# 4      11
# 3       7
# 2       2
# 1       2
# Name: functional, dtype: int64

# %%
ames_train8.boxplot(by = 'fireplaces', column = ['saleprice'], grid=False)
# Out:
# <AxesSubplot:title={'center':'saleprice'}, xlabel='fireplaces'>

# %%
ames_train1.boxplot(by = 'fireplace_qu', column = ['saleprice'], grid=False)
# Out:
# <AxesSubplot:title={'center':'saleprice'}, xlabel='fireplace_qu'>

# %% [markdown]
# For fireplace:
# - More fireplaces seems to have higher sale price but too little data for fireplaces
# - Higher quality fireplace result in higher sale price. Higher quality and more fireplaces would have higher sale price

# %%
ames_train8.boxplot(by = 'garage_type', column = ['saleprice'], grid=False)
# Out:
# <AxesSubplot:title={'center':'saleprice'}, xlabel='garage_type'>

# %%
display(ames_train1['garage_type'].value_counts())
display(ames_train8['garage_type'].value_counts())
# Out:
# Attchd     1213
# Detchd      536
# BuiltIn     132
# Basment      27
# 2Types       19
# CarPort      11
# Name: garage_type, dtype: int64
# 2    1192
# 6     534
# 4     129
# 7     112
# 3      27
# 1      19
# 5      11
# Name: garage_type, dtype: int64

# %%
plt.figure(figsize=(8,5))
sns.regplot('saleprice', 'garage_yr_blt', ames_train1, ci=None,
           scatter_kws = {'s':1},
           line_kws = {'color': 'red'})
plt.xlabel('Salesprice')
plt.ylabel('Garage Yr Blt')
plt.title('Garage Yr Blt against Sales Price')
# Out:
# /Users/khooqixiang/opt/anaconda3/lib/python3.9/site-packages/seaborn/_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y, data. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# Text(0.5, 1.0, 'Garage Yr Blt against Sales Price')

# %%
ames_train1.boxplot(by = 'garage_finish', column = ['saleprice'], grid=False)
# Out:
# <AxesSubplot:title={'center':'saleprice'}, xlabel='garage_finish'>

# %%
ames_train1.boxplot(by = 'garage_cars', column = ['saleprice'], grid=False)
# Out:
# <AxesSubplot:title={'center':'saleprice'}, xlabel='garage_cars'>

# %%
plt.figure(figsize=(8,5))
sns.regplot('saleprice', 'garage_area', ames_train1, ci=None,
           scatter_kws = {'s':1},
           line_kws = {'color': 'red'})
plt.xlabel('Salesprice')
plt.ylabel('Garage Area')
plt.title('Garage Area against Sales Price')
# Out:
# /Users/khooqixiang/opt/anaconda3/lib/python3.9/site-packages/seaborn/_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y, data. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# Text(0.5, 1.0, 'Garage Area against Sales Price')

# %%
ames_train1.boxplot(by = 'garage_qual', column = ['saleprice'], grid=False)
# Out:
# <AxesSubplot:title={'center':'saleprice'}, xlabel='garage_qual'>

# %%
ames_train1.boxplot(by = 'garage_cond', column = ['saleprice'], grid=False)
# Out:
# <AxesSubplot:title={'center':'saleprice'}, xlabel='garage_cond'>

# %% [markdown]
# For garage cond and qual:
# - Sales price increases generally with garage quality. There might be a lack of data for anything more than 'good'.
# - Both garage condition and quality will sell higher. Bigger garage will also sell higher.

# %%
ames_train1.boxplot(by = 'paved_drive', column = ['saleprice'], grid=False)
# Out:
# <AxesSubplot:title={'center':'saleprice'}, xlabel='paved_drive'>

# %%
plt.figure(figsize=(8,5))
sns.regplot('saleprice', 'wood_deck_sf', ames_train1, ci=None,
           scatter_kws = {'s':1},
           line_kws = {'color': 'red'})
plt.xlabel('Salesprice')
plt.ylabel('Wood Deck SF')
plt.title('Wood Deck SF against Sales Price')
# Out:
# /Users/khooqixiang/opt/anaconda3/lib/python3.9/site-packages/seaborn/_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y, data. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# Text(0.5, 1.0, 'Wood Deck SF against Sales Price')

# %%
plt.figure(figsize=(8,5))
sns.regplot('saleprice', 'open_porch_sf', ames_train1, ci=None,
           scatter_kws = {'s':1},
           line_kws = {'color': 'red'})
plt.xlabel('Salesprice')
plt.ylabel('Open Porch SF')
plt.title('Open Porch SF against Sales Price')
# Out:
# /Users/khooqixiang/opt/anaconda3/lib/python3.9/site-packages/seaborn/_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y, data. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# Text(0.5, 1.0, 'Open Porch SF against Sales Price')

# %%
plt.figure(figsize=(8,5))
sns.regplot('saleprice', 'enclosed_porch', ames_train1, ci=None,
           scatter_kws = {'s':1},
           line_kws = {'color': 'red'})
plt.xlabel('Salesprice')
plt.ylabel('Enclosed Porch ')
plt.title('Enclosed Porch against Sales Price')
# Out:
# /Users/khooqixiang/opt/anaconda3/lib/python3.9/site-packages/seaborn/_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y, data. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# Text(0.5, 1.0, 'Enclosed Porch against Sales Price')

# %% [markdown]
# Enclosed porch pattern has alot of 0 values which means many property does not have any enclosed porched.

# %%
plt.figure(figsize=(8,5))
sns.regplot('saleprice', '3ssn_porch', ames_train1, ci=None,
           scatter_kws = {'s':1},
           line_kws = {'color': 'red'})
plt.xlabel('Salesprice')
plt.ylabel('3Ssn Porch')
plt.title('3Ssn Porch against Sales Price')
# Out:
# /Users/khooqixiang/opt/anaconda3/lib/python3.9/site-packages/seaborn/_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y, data. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# Text(0.5, 1.0, '3Ssn Porch against Sales Price')

# %%
plt.figure(figsize=(8,5))
sns.regplot('saleprice', 'screen_porch', ames_train1, ci=None,
           scatter_kws = {'s':1},
           line_kws = {'color': 'red'})
plt.xlabel('Salesprice')
plt.ylabel('Screen Porch')
plt.title('Screen Porch against Sales Price')
# Out:
# /Users/khooqixiang/opt/anaconda3/lib/python3.9/site-packages/seaborn/_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y, data. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# Text(0.5, 1.0, 'Screen Porch against Sales Price')

# %%
ames_train1.boxplot(by = 'fence', column = ['saleprice'], grid=False)
# Out:
# <AxesSubplot:title={'center':'saleprice'}, xlabel='fence'>

# %%
ames_train1.boxplot(by = 'misc_feature', column = ['saleprice'], grid=False)
# Out:
# <AxesSubplot:title={'center':'saleprice'}, xlabel='misc_feature'>

# %% [markdown]
# For fence:
# - With or without fence doesnt affect the sale price
#
# For misc feature:
# - There isnt any data for elev and elevator

# %%
plt.figure(figsize=(8,5))
sns.regplot('saleprice', 'misc_val', ames_train8, ci=None,
           scatter_kws = {'s':1},
           line_kws = {'color': 'red'})
plt.xlabel('Salesprice')
plt.ylabel('Misc Val')
plt.title('Misc Val against Sales Price')
# Out:
# /Users/khooqixiang/opt/anaconda3/lib/python3.9/site-packages/seaborn/_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y, data. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# Text(0.5, 1.0, 'Misc Val against Sales Price')

# %%
ames_train1.boxplot(by = 'mo_sold', column = ['saleprice'], grid=False)
# Out:
# <AxesSubplot:title={'center':'saleprice'}, xlabel='mo_sold'>

# %%
ames_train1.boxplot(by = 'yr_sold', column = ['saleprice'], grid=False)
# Out:
# <AxesSubplot:title={'center':'saleprice'}, xlabel='yr_sold'>

# %% [markdown]
# For month and year:
# - Month sold, doesnt seems to have an impact on sales prices
# - Year sold similar to month, doesnt seems to have an impact on sales prices

# %%
ames_train1.boxplot(by = 'sale_type', column = ['saleprice'], grid=False)
# Out:
# <AxesSubplot:title={'center':'saleprice'}, xlabel='sale_type'>

# %%
ames_train1['sale_type'].value_counts()
# Out:
# WD       1781
# New       160
# COD        63
# ConLD      17
# CWD        10
# ConLI       7
# ConLw       5
# Con         4
# Oth         4
# Name: sale_type, dtype: int64

# %% [markdown]
# EDA Summary:
#
# Features that will be dropped:
# - Lot Shape
# - Ms zoning
# - Fence
# - Misc val
# - Misc feature
# - Utilities
# - Mo Sold
# - Garage Yr Blt
# - Lot Config
# - Bldg Type
# - Land Slope
# - House Style
# - Roof Style
# - Roof Matl
# - Land Contour
# - Half Bath
# - Bedroom AbvGr
# - Condition 1
# - Condition 2
# - Electrical
# - Central Air
# - Heating Mod
#
# Reasons for dropping these features could be:
# - Does not affect Sales Price much
# - Too little data to make feature distinct or no distinct trend against SalesPrice
#
#
# Features that we are interested to use or feature engineering:
# - Garage_type
# - Alley
# - Ms Subclass
# - Bsmt Half Bath
# - Low Qual Fin Sf
# - Exterior 1st
# - Exterior 2nd
# - Functional
# - Neighborhood
# - Lot Frontage
# - 2nd Flr Sf
# - Bsmt Full Bath
# - Paved Drive
# - Lot_area
# - Wood Deck Sf
# - Foundation
# - Totrms Abvgrd
# - Mas Vnr Area
# - Full Bath
# - 1st Flr Sf
# - Gr Liv Area
#
# Features that we are interested to feature engineer it to create a new correlation with sale price:
# - Overall Qual & Overall Cond ---> Overall Qual Cond
# - Exter Qual & Exter Cond ---> Exter Qual Cond
# - Bsmt Qual, Bsmt Cond and Bsmt Exposure ---> Bsmt Qual Cond Exposure
# - Bsmt Qual Cond Exposure, Bsmtfin type 1, Bsmtfin type 2, Bsmtfin sf 1, Bsmtfin sf 2,Bsmt unf sf, Total bsmt sf ---> Bsmt
# - Kitchen Qual & Kitchen Abvgr ---> Kitchen and Qual
# - Fireplaces, fireplace Qu ---> Fireplaces and Qual
# - Garge qual, garage area, garage finish and garage cars ---> Garage
# - Open Porch SF, 3Ssn Porch and screen Porch ---> Porch Total
# - Year built, yr sold ---> age

# %% [markdown]
# # Feature Engineering

# %%
#ames_train5
ames_train8.columns
# Out:
# Index(['ms_subclass', 'ms_zoning', 'lot_frontage', 'lot_area', 'street',
#        'alley', 'lot_shape', 'land_contour', 'utilities', 'lot_config',
#        'land_slope', 'neighborhood', 'condition_1', 'condition_2', 'bldg_type',
#        'house_style', 'overall_qual', 'overall_cond', 'year_built',
#        'year_remod/add', 'roof_style', 'roof_matl', 'exterior_1st',
#        'exterior_2nd', 'mas_vnr_type', 'mas_vnr_area', 'exter_qual',
#        'exter_cond', 'foundation', 'bsmt_qual', 'bsmt_cond', 'bsmt_exposure',
#        'bsmtfin_type_1', 'bsmtfin_sf_1', 'bsmtfin_type_2', 'bsmtfin_sf_2',
#        'bsmt_unf_sf', 'total_bsmt_sf', 'heating', 'heating_qc', 'central_air',
#        'electrical', '1st_flr_sf', '2nd_flr_sf', 'low_qual_fin_sf',
#        'gr_liv_area', 'bsmt_full_bath', 'bsmt_half_bath', 'full_bath',
#        'half_bath', 'bedroom_abvgr', 'kitchen_abvgr', 'kitchen_qual',
#        'totrms_abvgrd', 'functional', 'fireplaces', 'fireplace_qu',
#        'garage_type', 'garage_yr_blt', 'garage_finish', 'garage_cars',
#        'garage_area', 'garage_qual', 'garage_cond', 'paved_drive',
#        'wood_deck_sf', 'open_porch_sf', 'enclosed_porch', '3ssn_porch',
#        'screen_porch', 'fence', 'misc_feature', 'misc_val', 'mo_sold',
#        'yr_sold', 'sale_type', 'saleprice'],
#       dtype='object')

# %%
ames_train8 = ames_train9
ames_train9.columns
# Out:
# Index(['ms_subclass', 'ms_zoning', 'lot_frontage', 'lot_area', 'street',
#        'alley', 'lot_shape', 'land_contour', 'utilities', 'lot_config',
#        'land_slope', 'neighborhood', 'condition_1', 'condition_2', 'bldg_type',
#        'house_style', 'overall_qual', 'overall_cond', 'year_built',
#        'year_remod/add', 'roof_style', 'roof_matl', 'exterior_1st',
#        'exterior_2nd', 'mas_vnr_type', 'mas_vnr_area', 'exter_qual',
#        'exter_cond', 'foundation', 'bsmt_qual', 'bsmt_cond', 'bsmt_exposure',
#        'bsmtfin_type_1', 'bsmtfin_sf_1', 'bsmtfin_type_2', 'bsmtfin_sf_2',
#        'bsmt_unf_sf', 'total_bsmt_sf', 'heating', 'heating_qc', 'central_air',
#        'electrical', '1st_flr_sf', '2nd_flr_sf', 'low_qual_fin_sf',
#        'gr_liv_area', 'bsmt_full_bath', 'bsmt_half_bath', 'full_bath',
#        'half_bath', 'bedroom_abvgr', 'kitchen_abvgr', 'kitchen_qual',
#        'totrms_abvgrd', 'functional', 'fireplaces', 'fireplace_qu',
#        'garage_type', 'garage_yr_blt', 'garage_finish', 'garage_cars',
#        'garage_area', 'garage_qual', 'garage_cond', 'paved_drive',
#        'wood_deck_sf', 'open_porch_sf', 'enclosed_porch', '3ssn_porch',
#        'screen_porch', 'fence', 'misc_feature', 'misc_val', 'mo_sold',
#        'yr_sold', 'sale_type', 'saleprice'],
#       dtype='object')

# %%
# Safe guard
ames_train10 = ames_train9

# %%
ames_train10.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 2024 entries, 0 to 2050
# Data columns (total 77 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   ms_subclass      2024 non-null   int64
#  1   ms_zoning        2024 non-null   object
#  2   lot_frontage     2024 non-null   float64
#  3   lot_area         2024 non-null   int64
#  4   street           2024 non-null   object
#  5   alley            2024 non-null   object
#  6   lot_shape        2024 non-null   object
#  7   land_contour     2024 non-null   int64
#  8   utilities        2024 non-null   int64
#  9   lot_config       2024 non-null   int64
#  10  land_slope       2024 non-null   int64
#  11  neighborhood     2024 non-null   object
#  12  condition_1      2024 non-null   object
#  13  condition_2      2024 non-null   object
#  14  bldg_type        2024 non-null   object
#  15  house_style      2024 non-null   object
#  16  overall_qual     2024 non-null   int64
#  17  overall_cond     2024 non-null   int64
#  18  year_built       2024 non-null   int64
#  19  year_remod/add   2024 non-null   int64
#  20  roof_style       2024 non-null   object
#  21  roof_matl        2024 non-null   object
#  22  exterior_1st     2024 non-null   object
#  23  exterior_2nd     2024 non-null   object
#  24  mas_vnr_type     2024 non-null   object
#  25  mas_vnr_area     2024 non-null   float64
#  26  exter_qual       2024 non-null   int64
#  27  exter_cond       2024 non-null   int64
#  28  foundation       2024 non-null   object
#  29  bsmt_qual        2024 non-null   int64
#  30  bsmt_cond        2024 non-null   object
#  31  bsmt_exposure    2024 non-null   int64
#  32  bsmtfin_type_1   2024 non-null   int64
#  33  bsmtfin_sf_1     2024 non-null   float64
#  34  bsmtfin_type_2   2024 non-null   int64
#  35  bsmtfin_sf_2     2024 non-null   float64
#  36  bsmt_unf_sf      2024 non-null   float64
#  37  total_bsmt_sf    2024 non-null   float64
#  38  heating          2024 non-null   object
#  39  heating_qc       2024 non-null   int64
#  40  central_air      2024 non-null   object
#  41  electrical       2024 non-null   object
#  42  1st_flr_sf       2024 non-null   int64
#  43  2nd_flr_sf       2024 non-null   int64
#  44  low_qual_fin_sf  2024 non-null   int64
#  45  gr_liv_area      2024 non-null   int64
#  46  bsmt_full_bath   2024 non-null   float64
#  47  bsmt_half_bath   2024 non-null   float64
#  48  full_bath        2024 non-null   int64
#  49  half_bath        2024 non-null   int64
#  50  bedroom_abvgr    2024 non-null   int64
#  51  kitchen_abvgr    2024 non-null   int64
#  52  kitchen_qual     2024 non-null   int64
#  53  totrms_abvgrd    2024 non-null   int64
#  54  functional       2024 non-null   int64
#  55  fireplaces       2024 non-null   int64
#  56  fireplace_qu     2024 non-null   int64
#  57  garage_type      2024 non-null   object
#  58  garage_yr_blt    2024 non-null   object
#  59  garage_finish    2024 non-null   int64
#  60  garage_cars      2024 non-null   float64
#  61  garage_area      2024 non-null   float64
#  62  garage_qual      2024 non-null   int64
#  63  garage_cond      2024 non-null   object
#  64  paved_drive      2024 non-null   object
#  65  wood_deck_sf     2024 non-null   int64
#  66  open_porch_sf    2024 non-null   int64
#  67  enclosed_porch   2024 non-null   int64
#  68  3ssn_porch       2024 non-null   int64
#  69  screen_porch     2024 non-null   int64
#  70  fence            2024 non-null   object
#  71  misc_feature     2024 non-null   object
#  72  misc_val         2024 non-null   int64
#  73  mo_sold          2024 non-null   int64
#  74  yr_sold          2024 non-null   int64
#  75  sale_type        2024 non-null   object
#  76  saleprice        2024 non-null   int64
# dtypes: float64(10), int64(41), object(26)
# memory usage: 1.2+ MB

# %%
ames_train5.groupby('heating')['saleprice'].mean()
# Out:
# heating
# GasA    181869.200402
# GasW    151275.000000
# Grav     65180.000000
# OthW    125750.000000
# Wall     77150.000000
# Name: saleprice, dtype: float64

# %% [markdown]
# We would want to numarise 'heating' to perform the calculation between the column 'heating' and 'heating_qc':
# - Average saleprice / total average
# - GasA = 181869.200402/601224.2004018081
# - GasW = 151275/601224.2004018081
# - Grav = 65180/601224.2004018081
# - OthW = 125750.000000/601224.2004018081
# - Wall = 77150.000000/601224.2004018081
# Assigning back the value into 'heating'

# %%
assignindex = {
    181869.200402/601224.2004018081: 'GasA',
    151275/601224.2004018081: 'GasW',
    65180/601224.2004018081: 'Grav',
    125750.000000/601224.2004018081: 'OthW',
    77150.000000/601224.2004018081: 'Wall'}
assignindex = {v: k for k, v in assignindex.items()}
ames_train10 = ames_train10.replace({'heating': assignindex})

# %% [markdown]
# Using ames_train10 , we will attempt to combine some new columns feature by joining old features and removal of some old features. For example after we combined 'overall qual' and 'overall cond' , we must remove these features for the new feature (overall_qual_cond). And we would need to assign the relevant index to the relevant columns.

# %%
# Combining Exter Qual and Exter Cond data into 1 column
ames_train10['exter_qual_cond'] = ames_train10['exter_qual'] * ames_train10['exter_cond']
ames_train10 = ames_train10.drop(columns=['exter_qual','exter_cond'])

# Combining Bsmt Qual and Bsmt Cond and Bsmt Exposure into 1 column
ames_train10['bsmt_qual_exposure'] = ames_train10['bsmt_qual'] * ames_train10['bsmt_exposure']
ames_train10 = ames_train10.drop(columns=['bsmt_qual', 'bsmt_exposure'])

# Combining Overall Qual and Overall Cond data into 1 column
ames_train10['overall_qual_cond'] = ames_train10['overall_qual'] * ames_train10['overall_cond']
ames_train10 = ames_train10.drop(columns=['overall_qual','overall_cond'])

# Combining all basement values to 1 column
ames_train10['bsmt']=ames_train10['bsmtfin_type_1']*ames_train10['bsmtfin_sf_1']+ames_train10['bsmtfin_type_2']*ames_train10['bsmtfin_sf_2']+((ames_train10['bsmt_unf_sf']+ames_train10['total_bsmt_sf'])*ames_train10['bsmt_qual_exposure'])  
ames_train10 = ames_train10.drop(columns=['bsmt_qual_exposure','bsmtfin_type_1', 'bsmtfin_sf_1','bsmtfin_type_2', 'bsmtfin_sf_2','bsmt_unf_sf', 'total_bsmt_sf', 'bsmt_qual_exposure'])

# Combining Heating and Heating QC
ames_train10['heatingmod'] = ames_train10['heating'] * ames_train10['heating_qc']
ames_train10 = ames_train10.drop(columns=['heating','heating_qc'])

# Combining Kitchen and Kitchen Qual data into 1 column
ames_train10['kitchen_and_qual'] = ames_train10['kitchen_qual'] * ames_train10['kitchen_abvgr']
ames_train10 = ames_train10.drop(columns=['kitchen_abvgr','kitchen_qual'])

# Combining Fireplaces and Fireplace Qu data into 1 column
ames_train10['fireplaces_and_qual'] = ames_train10['fireplace_qu'] * ames_train10['fireplaces']
ames_train10 = ames_train10.drop(columns=['fireplaces','fireplace_qu'])

# Combining Garage Area, Garage Qual, Garage finish and Garage Cond data into 1 column
ames_train10['garage'] = ames_train10['garage_qual']* ames_train10['garage_area']*ames_train10['garage_finish'] *ames_train10['garage_cars'] 
ames_train10 = ames_train10.drop(columns=['garage_qual', 'garage_area', 'garage_finish', 'garage_cars'])

# Combining Open Porch SF, 3-Ssn Porch, Screen Porch data into 1 column
# Drop Enclosed Porch column
ames_train10['porch_total'] = ames_train10['open_porch_sf'] + ames_train10['3ssn_porch'] + ames_train10['screen_porch']
ames_train10 = ames_train10.drop(columns=['open_porch_sf','3ssn_porch','screen_porch', 'enclosed_porch'])

# Combining year built and year sold to age
ames_train10['age'] = ames_train10['yr_sold'] - ames_train10['year_built']
ames_train10 = ames_train10.drop(columns=['year_built','yr_sold'])

# %%
assignindex = {
    5: 'Ex',
    4: 'Gd',
    3: 'TA',
    2: 'Fa',
    1: 'Po'}
assignindex = {v: i for i, v in assignindex.items()}
ames_test = ames_test.replace({'exter_qual': assignindex})


assignindex = {
    5: 'Ex',
    4: 'Gd',
    3: 'TA',
    2: 'Fa',
    1: 'Po'}
assignindex = {v: i for i, v in assignindex.items()}
ames_test= ames_test.replace({'exter_cond': assignindex})

assignindex = {
    5: 'Ex',
    4: 'Gd',
    3: 'TA',
    2: 'Fa',
    1: 'Po',
    0: 'None'}

assignindex = {v: i for i, v in assignindex.items()}
ames_test= ames_test.replace({'bsmt_qual': assignindex})


assignindex = { 
    5: 'Ex',
    4: 'Gd',
    3: 'TA',
    2: 'Fa',
    1: 'Po',
    0: 'None',}
assignindex = {v: i for i, v in assignindex.items()}
ames_test = ames_test.replace({'bsmt_cond': assignindex})


assignindex = {
    4: 'Gd',
    3: 'Av',
    2: 'Mn',
    1: 'No',
    0: 'None',}
assignindex = {v: i for i, v in assignindex.items()}
ames_test = ames_test.replace({'bsmt_exposure': assignindex})

assignindex = {
    6: 'GLQ',
    5: 'ALQ',
    4: 'BLQ',
    3: 'Rec',
    2: 'LwQ',
    1: 'Unf',
    0: 'None',}
assignindex = {v: i for i, v in assignindex.items()}
ames_test = ames_test.replace({'bsmtfin_type_1': assignindex})


assignindex = {
    6: 'GLQ',
    5: 'ALQ',
    4: 'BLQ',
    3: 'Rec',
    2: 'LwQ',
    1: 'Unf',
    0: 'None',}
assignindex = {v: i for i, v in assignindex.items()}
ames_test= ames_test.replace({'bsmtfin_type_2': assignindex})


assignindex = {
    181869.200402/601224.2004018081: 'GasA',
    151275/601224.2004018081: 'GasW',
    65180/601224.2004018081: 'Grav',
    125750.000000/601224.2004018081: 'OthW',
    77150.000000/601224.2004018081: 'Wall'}
assignindex = {v: k for k, v in assignindex.items()}
ames_train10 = ames_train10.replace({'heating': assignindex})


assignindex = {
    5: 'Ex',
    4: 'Gd',
    3: 'TA',
    2: 'Fa',
    1: 'Po'}
assignindex = {v: i for i, v in assignindex.items()}
ames_test = ames_test.replace({'kitchen_qual': assignindex})

assignindex = {
    5: 'Ex',
    4: 'Gd',
    3: 'TA',
    2: 'Fa',
    1: 'Po',
    0: 'None'}
assignindex = {v: i for i, v in assignindex.items()}
ames_test = ames_test.replace({'fireplace_qu': assignindex})

assignindex = {
 3: 'Fin',
 2: 'RFn',
 1: 'Unf',
 0: 'None'}
assignindex = {v: i for i, v in assignindex.items()}
ames_test = ames_test.replace({'garage_finish': assignindex})

assignindex = {
    5: 'Ex',
    4: 'Gd',
    3: 'TA',
    2: 'Fa',
    1: 'Po',
    0: 'None'}
assignindex = {v: i for i, v in assignindex.items()}
ames_test= ames_test.replace({'garage_qual': assignindex})

assignindex = {
    5: 'Ex',
    4: 'Gd',
    3: 'TA',
    2: 'Fa',
    1: 'Po',
    0: 'None'}
assignindex = {v: i for i, v in assignindex.items()}
ames_test= ames_test.replace({'garage_cond': assignindex})

assignindex = {
    8: 'Typ',
    7: 'Min1',
    6: 'Min2',
    5: 'Mod',
    4: 'Maj1',
    3: 'Maj2',
    2: 'Sev',
    1: 'Sal'}
assignindex = {v: i for i, v in assignindex.items()}
ames_test= ames_test.replace({'functional': assignindex})

assignindex = {
    5: 'Ex',
    4: 'Gd',
    3: 'TA',
    2: 'Fa',
    1: 'Po',
    0: 'None'}
assignindex = {v: i for i, v in assignindex.items()}
ames_test= ames_test.replace({'heating_qc': assignindex})

# %%
ames_test.columns
# Out:
# Index(['id', 'pid', 'ms_subclass', 'ms_zoning', 'lot_frontage', 'lot_area',
#        'street', 'alley', 'lot_shape', 'land_contour', 'utilities',
#        'lot_config', 'land_slope', 'neighborhood', 'condition_1',
#        'condition_2', 'bldg_type', 'house_style', 'overall_qual',
#        'overall_cond', 'year_built', 'year_remod/add', 'roof_style',
#        'roof_matl', 'exterior_1st', 'exterior_2nd', 'mas_vnr_type',
#        'mas_vnr_area', 'exter_qual', 'exter_cond', 'foundation', 'bsmt_qual',
#        'bsmt_cond', 'bsmt_exposure', 'bsmtfin_type_1', 'bsmtfin_sf_1',
#        'bsmtfin_type_2', 'bsmtfin_sf_2', 'bsmt_unf_sf', 'total_bsmt_sf',
#        'heating', 'heating_qc', 'central_air', 'electrical', '1st_flr_sf',
#        '2nd_flr_sf', 'low_qual_fin_sf', 'gr_liv_area', 'bsmt_full_bath',
#        'bsmt_half_bath', 'full_bath', 'half_bath', 'bedroom_abvgr',
#        'kitchen_abvgr', 'kitchen_qual', 'totrms_abvgrd', 'functional',
#        'fireplaces', 'fireplace_qu', 'garage_type', 'garage_yr_blt',
#        'garage_finish', 'garage_cars', 'garage_area', 'garage_qual',
#        'garage_cond', 'paved_drive', 'wood_deck_sf', 'open_porch_sf',
#        'enclosed_porch', '3ssn_porch', 'screen_porch', 'pool_area', 'pool_qc',
#        'fence', 'misc_feature', 'misc_val', 'mo_sold', 'yr_sold', 'sale_type'],
#       dtype='object')

# %%
ames_test.fillna(0, inplace=True)

# %%
# Combining Exter Qual and Exter Cond data into 1 column
ames_test['exter_qual_cond'] = ames_test['exter_qual'] * ames_test['exter_cond']
ames_test = ames_test.drop(columns=['exter_qual','exter_cond'])

# Combining Bsmt Qual and Bsmt Cond and Bsmt Exposure into 1 column
ames_test['bsmt_qual_exposure'] = ames_test['bsmt_qual'] * ames_test['bsmt_exposure']
ames_test = ames_test.drop(columns=['bsmt_qual', 'bsmt_exposure'])

# Combining Overall Qual and Overall Cond data into 1 column
ames_test['overall_qual_cond'] = ames_test['overall_qual'] * ames_test['overall_cond']
ames_test = ames_test.drop(columns=['overall_qual','overall_cond'])

# Combining all basement values to 1 column
ames_test['bsmt']=ames_test['bsmtfin_type_1']*ames_test['bsmtfin_sf_1']+ames_test['bsmtfin_type_2']*ames_test['bsmtfin_sf_2']+((ames_test['bsmt_unf_sf']+ames_test['total_bsmt_sf'])*ames_test['bsmt_qual_exposure'])  
ames_test = ames_test.drop(columns=['bsmt_qual_exposure','bsmtfin_type_1', 'bsmtfin_sf_1','bsmtfin_type_2', 'bsmtfin_sf_2','bsmt_unf_sf', 'total_bsmt_sf', 'bsmt_qual_exposure'])

# Combining Heating and Heating QC
ames_test['heatingmod'] = ames_test['heating'] * ames_test['heating_qc']
ames_test = ames_test.drop(columns=['heating','heating_qc'])

# Combining Kitchen and Kitchen Qual data into 1 column
ames_test['kitchen_and_qual'] = ames_test['kitchen_qual'] * ames_test['kitchen_abvgr']
ames_test = ames_test.drop(columns=['kitchen_abvgr','kitchen_qual'])

# Combining Fireplaces and Fireplace Qu data into 1 column
ames_test['fireplaces_and_qual'] = ames_test['fireplace_qu'] * ames_test['fireplaces']
ames_test = ames_test.drop(columns=['fireplaces','fireplace_qu'])

# Combining Garage Area, Garage Qual, Garage finish and Garage Cond data into 1 column
ames_test['garage'] = ames_test['garage_qual']* ames_test['garage_area']*ames_test['garage_finish'] *ames_test['garage_cars'] 
ames_test = ames_test.drop(columns=['garage_qual', 'garage_area', 'garage_finish', 'garage_cars'])

# Combining Open Porch SF, 3-Ssn Porch, Screen Porch data into 1 column
# Drop Enclosed Porch column
ames_test['porch_total'] = ames_test['open_porch_sf'] + ames_test['3ssn_porch'] + ames_test['screen_porch']
ames_test = ames_test.drop(columns=['open_porch_sf','3ssn_porch','screen_porch', 'enclosed_porch'])

# Combining year built and year sold to age
ames_test['age'] = ames_test['yr_sold'] - ames_test['year_built']
ames_test = ames_test.drop(columns=['year_built','yr_sold'])

ames_test = ames_test.drop(columns=['pool_area','pool_qc'])

# %% [markdown]
# As discussed in EDA section, dropping features that does not affect Sales Price much or too little data to make feature distinct or no distinct trend against SalesPrice

# %%
ames_train11 = ames_train10

# %%
ames_train11 = ames_train11.drop(columns=['misc_val','misc_feature', 'utilities','mo_sold','garage_yr_blt', 'fence', 'bldg_type', 'lot_config', 'land_slope', 'house_style', 'roof_style', 'roof_matl', 'land_contour', 'lot_shape', 'half_bath','bedroom_abvgr', 'condition_1', 'condition_2', 'electrical', 'central_air' ], inplace=True)

# %%
ames_train10.columns
# Out:
# Index(['ms_subclass', 'ms_zoning', 'lot_frontage', 'lot_area', 'street',
#        'alley', 'neighborhood', 'year_remod/add', 'exterior_1st',
#        'exterior_2nd', 'mas_vnr_type', 'mas_vnr_area', 'foundation',
#        'bsmt_cond', '1st_flr_sf', '2nd_flr_sf', 'low_qual_fin_sf',
#        'gr_liv_area', 'bsmt_full_bath', 'bsmt_half_bath', 'full_bath',
#        'totrms_abvgrd', 'functional', 'garage_type', 'garage_cond',
#        'paved_drive', 'wood_deck_sf', 'sale_type', 'saleprice',
#        'exter_qual_cond', 'overall_qual_cond', 'bsmt', 'heatingmod',
#        'kitchen_and_qual', 'fireplaces_and_qual', 'garage', 'porch_total',
#        'age'],
#       dtype='object')

# %%
ames_train11 = ames_train10

# %%
ames_train10.to_csv('../datasets/ames_train10.csv')

# %%
ames_train11.to_csv('../datasets/ames_train11.csv')

# %%
ames_train11.shape
# Out:
# (2024, 38)

# %%
ames_test1 = ames_test

# %%
ames_test1= ames_test1.drop(columns=['id', 'pid', 'misc_val','misc_feature', 'utilities','mo_sold','garage_yr_blt', 'fence', 'bldg_type', 'lot_config', 'land_slope', 'house_style', 'roof_style', 'roof_matl', 'land_contour', 'lot_shape', 'half_bath','bedroom_abvgr', 'condition_1', 'condition_2', 'electrical', 'central_air'], inplace=True)

# %%
ames_test.shape
# Out:
# (878, 37)

# %%
ames_test.columns
# Out:
# Index(['ms_subclass', 'ms_zoning', 'lot_frontage', 'lot_area', 'street',
#        'alley', 'neighborhood', 'year_remod/add', 'exterior_1st',
#        'exterior_2nd', 'mas_vnr_type', 'mas_vnr_area', 'foundation',
#        'bsmt_cond', '1st_flr_sf', '2nd_flr_sf', 'low_qual_fin_sf',
#        'gr_liv_area', 'bsmt_full_bath', 'bsmt_half_bath', 'full_bath',
#        'totrms_abvgrd', 'functional', 'garage_type', 'garage_cond',
#        'paved_drive', 'wood_deck_sf', 'sale_type', 'exter_qual_cond',
#        'overall_qual_cond', 'bsmt', 'heatingmod', 'kitchen_and_qual',
#        'fireplaces_and_qual', 'garage', 'porch_total', 'age'],
#       dtype='object')

# %%
ames_test1 = ames_test

# %%
ames_test1.to_csv('../datasets/ames_test1.csv')

# %%
ames_train11.shape
# Out:
# (2024, 38)

# %% [markdown]
# Please refer to 'Part 2 Modelling & Prediction' for modeling workflow and prediction.
